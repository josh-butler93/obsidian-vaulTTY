# %% [markdown]
# # Python

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### 1. Welcome to Fantasy Quest

# %%
print("Welcome to Fantasy Quest!")
# Out:
# Welcome to Fantasy Quest!

# %% [markdown]
# ### 2. Fix Your Bug

# %%
sword_damage = 10 # Variable 1
start_health = 100 # Variable 2 --setup
end_health = start_health - sword_damage # Variable 3

# Don't touch below this line
print(f"Sam's health is: {start_health}")
print(f"Sam takes {sword_damage} damage...")
print(f"Sam's health is: {end_health}")
# Out:
# Sam's health is: 100
# Sam takes 10 damage...
# Sam's health is: 90

# %% [markdown]
# ### 3. Console

# %%
# function will print anything you put inside its parentheses, like this:

print("Greetings, adventurer!")
# Out:
# Greetings, adventurer!

# %% [markdown]
# ### 4. What Is “Code”?

# %% [markdown]
# 1. Code is just a series of instructions for a computer to follow one after another <br/>
# 2. Programs can have a lot of instructions

# %% [markdown]
# #### Numbers

# %%
# Numbers, unlike plain text strings, are not surrounded in quotes
# This prints the number 42

print(42)
# Out:
# 42

# %% [markdown]
# #### Adding Numbers

# %%
print(40 + 2)
# Out:
# 42

# %% [markdown]
# #### Assignment

# %%
# Calculate and print the result of 250 + 75

print(250 + 75)
# Out:
# 325

# %% [markdown]
# ### 5. Multiple Instructions

# %% [markdown]
# #### Assignment
#
# The dialogue in our game should display in the correct order! In the first level, our hero encounters a talking owl named Jax <br/>
#
# Remember: Code runs in order, starting at the top of the program. For example: <br/>
#
# Example: <br/>
#
# print("this prints first") <br/>
# print("this prints second") <br/>
# print("this prints last")

# %%
print("Jax: B-Kaw!")
print("Hero: ...")
print("Jax: Where are you off to this morning? Bkaw...")
print("Hero: Where did an owl learn to speak??")
# print("Jax: B-Kaw!")
# print("Jax: Where are you off to this morning? Bkaw...")
# Out:
# Jax: B-Kaw!
# Hero: ...
# Jax: Where are you off to this morning? Bkaw...
# Hero: Where did an owl learn to speak??

# %% [markdown]
# ### 6. Syntax Errors

# %% [markdown]
# #### Assignment
#
# The code was supposed to print Welcome to Fantasy Quest! to our users, but they get an error instead <br/>
# Find the syntax error in the code editor, and fix it <br/>
#
# Remember: <br/>
#
# "Syntax" is jargon for "valid code that the computer can understand." <br/>
# **Syntax:** The rules for how expressions and statements should be structured in a language <br/>
# **Bugs:** in your logic Your code is valid, and will run, but it does something unexpected <br/>
# **Slow Code:** Your code is valid and does what's expected, but it does it slowly
# For example, the following code has invalid syntax: <br/>
#
# print("hello world') <br/>
#
# It has mismatched quotes around the string hello world. One is a single quote ' and the other is a double quote "

# %%
print("Welcome to Fantasy Quest!")
# Out:
# Welcome to Fantasy Quest!

# %% [markdown]
# ### 7. Lesson Failure

# %% [markdown]
# #### Assignment
#
# Fantasy Quest has a bug in its server code <br/>
# The code is supposed to print messages indicating the game server has started successfully <br/>
#
# **Error** <br/>
# print("Starting up game server...') <br/>
# prnt("local game server is listening on port 8080") <br/>

# %%
# Fix

print("Starting up game server...")
print("local game server is listening on port 8080")
# Out:
# Starting up game server...
# local game server is listening on port 8080

# %% [markdown]
# ### 8. Game Statistics

# %% [markdown]
# #### Assignment
#
# The marketing team is asking for some stats about our Fantasy Quest game servers <br/>
# They'd like to know the average number of players across our 4 servers <br/>
#
# **To Do:** <br/>
# Debug the code so that it correctly prints the solution to the math problem
#
# **Tip** <br/>
# Strings (plain text) are surrounded in quotations but integers (numbers) are not!
#
# Debug <br/>
# print("(250 + 241 + 244 + 255) / 4")

# %%
# Solution

print((250 + 241 + 244 + 255) / 4)
# Out:
# 247.5

# %% [markdown]
# ### 9. Shop Response

# %% [markdown]
# #### Assignment
#
# Our dev team has been making updates to Fantasy Quest's innkeeper shop, but there's a problem! The Innkeeper's dialogue is blank! </br>
#
# **Add 2 separate print statements to complete the Innkeeper's response** <br/>
#
# They should output the following to the console in that order: <br/>
# Ah! Great choices... <br/>
# Is there anything else I can help you with?

# %%
# Solution

print("Ah! Great choices...")
print("Is there anything else I can help you with?")
# Out:
# Ah! Great choices...
# Is there anything else I can help you with?

# %% [markdown]
# ## Variables

# %% [markdown]
# Coogle Colab Test
