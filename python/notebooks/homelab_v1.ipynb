# %% [markdown]
# ## VSCode Code Space setup

# %% [markdown]
# ### Setup

# %% [markdown]
# Similar to google colab vscode has a codespace that you can use in the browser to spin up a dev environment
#
# Video Link: https://www.youtube.com/watch?v=fnuVw9TeYmA
#
# 1. Go to the dashboard
# 2. Click Codespace
# 3. Open the repo you want to do coding in and select how many cores you want for the machine
# 4. Once in there install the jupyter extension as well as the google colab extension as well --ensure it is the extension from google

# %% [markdown]
# Codespaces can use a config file called:
#
#       ─ text
#       .devcontainer/devcontainer.json
#
#     This tells GitHub how to build your cloud dev environment.
#
#     Example:
#
#       ─ json
#       {
#         "name": "Learning Lab",
#         "image": "mcr.microsoft.com/devcontainers/base:ubuntu",
#         "features": {
#           "ghcr.io/devcontainers/features/node:1": {
#             "version": "lts"
#           },
#           "ghcr.io/devcontainers/features/python:1": {
#             "version": "3.12"
#           }
#         },
#         "customizations": {
#           "vscode": {
#             "extensions": [
#               "ms-python.python",
#               "ms-toolsai.jupyter",
#               "dbaeumer.vscode-eslint",
#               "esbenp.prettier-vscode"
#             ]
#           }
#         }
#       }
#
#     That means every time you create a Codespace, it can automatically have:
#
#     • Python
#     • Node.js
#     • VS Code extensions
#     • project dependencies
#     • terminal tools
#
#     That’s very DevOps-like: environment as code.

# %% [markdown]
# ## Jupyter Initalization

# %% [markdown]
# Jupyter Labs <br/>
#
# source ~/.venvs/jupyter/bin/activate.fish <br/>
# python -m pip install -U ipykernel jupyterlab <br/>
# *jupyter lab --leave the terminal running <br/>
# deactivate <br/>
#
# import sys <br/>
# print(sys.executable) <br/>
# this will print out the location of the venvs <br/>
#
# pip Installations
# !/home/sysadmin/.venvs/jupyter/bin/python -m pip install ipywidgets
#
# --Test Collab Setup

# %% [markdown]
# ## Jupyter Learning

# %% [markdown]
# Jupyter Keyboard shortcuts <br/>
#
# press a > to create a new cell above <br/>
# press b > to create a new cell above <br/>
# press m > for markdown <br/>
# press y > vor python <br/>
# press enter > to enter the cell <br/>
# press dd > to delete the cell <br/>
#
# ctrl + enter > run cell and stay on cell <br/>
# shift + enter > run cell and move on to the next cell
#
# Creating Slideshow <br/>
# view --> cell toolbar -->slideshow <br/>
# Slides - Main option</br>
# Sub-slide - fill full screen <br/>
# Fragments - underneat slide/sub-slide and additional information <br/>
# Notes - don't include cell

# %% [markdown]
# ## Hermes Agent Dashboard Setup

# %% [markdown]
# Hermes
#
# hermes dashboard --it should auto pull up a windows or url for you to use
# hermes dashboard --status
# hermes dashboard --stop
# hermes dashboard --no-open
#
# And if the web UI was already built successfully once, this can sometimes help avoid a rebuild:
#
#     bash
#     hermes dashboard --skip-build --no-open

# %% [markdown]
# ## Coding Snippets

# %% [markdown]
# ### Hello World Snippet

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Elif Else Test Statemnt

# %%
# if elif statement with options
age = 15 # int(input("Age?"))

if age < 13:
    print("Child")
elif age < 20:
    print("Teen")
elif age < 35:
    print("Prime timer")
elif age < 55:
    print("The Wise")
else:
    print("golden")
# Out:
# Teen

# %% [markdown]
# ## Running Commands

# %%
To run commands usel the ! followed by the command

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
# !ls -l
# Out:
# total 16
# -rw-r--r-- 1 sysadmin sysadmin 4341 Jul 26 15:51 homelab_v1.ipynb
# -rw-r--r-- 1 sysadmin sysadmin 3392 Jul 26 15:28 july_tasking.ipynb
# -rw-r--r-- 1 sysadmin sysadmin 3501 Jul 26 14:36 Untitled.ipynb

# %%
# !pwd
# Out:
# /home/sysadmin/Documents/jupyter

# %% [markdown]
# ## Monthly Calendar

# %% [markdown]
# ### Static Calendar

# %%
import calendar
from IPython.display import HTML, display

year = 2026
month = 7

cal = calendar.HTMLCalendar()
display(HTML(cal.formatmonth(year, month)))
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="month">
# <tr><th colspan="7" class="month">July 2026</th></tr>
# <tr><th class="mon">Mon</th><th class="tue">Tue</th><th class="wed">Wed</th><th class="thu">Thu</th><th class="fri">Fri</th><th class="sat">Sat</th><th class="sun">Sun</th></tr>
# <tr><td class="noday">&nbsp;</td><td class="noday">&nbsp;</td><td class="wed">1</td><td class="thu">2</td><td class="fri">3</td><td class="sat">4</td><td class="sun">5</td></tr>
# <tr><td class="mon">6</td><td class="tue">7</td><td class="wed">8</td><td class="thu">9</td><td class="fri">10</td><td class="sat">11</td><td class="sun">12</td></tr>
# <tr><td class="mon">13</td><td class="tue">14</td><td class="wed">15</td><td class="thu">16</td><td class="fri">17</td><td class="sat">18</td><td class="sun">19</td></tr>
# <tr><td class="mon">20</td><td class="tue">21</td><td class="wed">22</td><td class="thu">23</td><td class="fri">24</td><td class="sat">25</td><td class="sun">26</td></tr>
# ...

# %% [markdown]
# ### Dynamic Calendar

# %%
# Still needs work

from ipywidgets import DatePicker, Text, VBox

date = DatePicker(description="Date:")
event = Text(description="Event:")
calendar_entry = VBox([date, event])

calendar_entry
