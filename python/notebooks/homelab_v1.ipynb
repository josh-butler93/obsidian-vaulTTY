# %% [markdown]
# # Homelab Notes

# %% [markdown]
# ## Jupyter Initalization

# %% [markdown]
# Jupyter Labs
#
# source ~/.venvs/jupyter/bin/activate.fish
# python -m pip install -U ipykernel jupyterlab
# *jupyter lab --leave the terminal running
# deactivate

# %% [markdown]
# ## Jupyter Learning

# %% [markdown]
# Jupyter Keyboard shortcuts
#
# press a > to create a new cell above
# press b > to create a new cell above
# press m > for markdown
# press y > vor python
# press enter > to enter the cell
# press dd > to delete the cell

# %% [markdown]
# ## Hermes Agent Dashboard Setup

# %% [markdown]
# Hermes
#
# hermes dashboard --it should auto pull up a windows or url for you to use
# hermes dashboard --status
# hermes dashboard --stop
# hermes dashboard --no-open
#
# And if the web UI was already built successfully once, this can sometimes help avoid a rebuild:
#
#     bash
#     hermes dashboard --skip-build --no-open

# %% [markdown]
# ## Coding Snippets

# %%
print("Hello World")
# Out:
# Hello World

# %%
# if elif statement with options
age = 15 # int(input("Age?"))

if age < 13:
    print("Child")
elif age < 20:
    print("Teen")
elif age < 35:
    print("Prime timer")
elif age < 55:
    print("The Wise")
else:
    print("golden")
# Out:
# Teen

# %% [markdown]
# Test WebUI testing

# %% [markdown]
# Testing v2

# %% [markdown]
# ## Running Commands

# %%
To run commands usel the ! followed by the command

# %%
# !ls -l
# Out:
# total 16
# -rw-r--r-- 1 sysadmin sysadmin 4341 Jul 26 15:51 homelab_v1.ipynb
# -rw-r--r-- 1 sysadmin sysadmin 3392 Jul 26 15:28 july_tasking.ipynb
# -rw-r--r-- 1 sysadmin sysadmin 3501 Jul 26 14:36 Untitled.ipynb

# %%
# !pwd
# Out:
# /home/sysadmin/Documents/jupyter
