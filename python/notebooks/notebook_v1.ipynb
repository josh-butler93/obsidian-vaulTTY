# %% [markdown]
# # First Notebook for the vaulTTY

# %% [markdown]
# ## Elif Else Statements Below

# %%
# if elif statement with options
age = int(input("Age?"))

if age < 13:
    print("Child")
elif age < 20:
    print("Teen")
elif age < 35:
    print("Prime timer")
elif age < 55:
    print("The Wise")
else:
    print("golden")
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 # if elif statement with options
# ----> 2 age = int(input("Age?"))
#       3
#       4 if age < 13:
#       5     print("Child")
#
# File ~/.venvs/jupyter/lib/python3.14/site-packages/ipykernel/kernelbase.py:1402, in Kernel.raw_input(self, prompt)
#    1400 if not self._allow_stdin:
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
# -> 1402     raise StdinNotImplementedError(msg)
#    1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# # Testing v_1
