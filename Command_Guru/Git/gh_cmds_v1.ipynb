# %% [markdown]
# # **Definitions**

# %% [markdown]
# **Staging Area**: The staging area is like your suitcase
#     -you can add items (changes) to it, remove items if you change your mind
#     -when you're happy with everything in the suitcase, you zip it up (make a commit)
#
# **.gitignore**: file is very powerful
#     -It can ignore specific files, entire directories, or use pattern matching to ignore files matching certain criteria
#
# **git diff**: is like a time machine's log book
#     -It allows you to see the exact changes you've made, which is incredibly useful when you're trying to remember what you've done or when you're reviewing changes before a commit
#
# **git commit**: creates a new commit (save point) with the staged changes
#     -This is like taking a snapshot of our current universe
#
# **master branch**: is the default branch that Git creates when you initialize a new repository
#
# **git switch**: is a newer command introduced in Git 2.23 that is specifically designed for branch switching, making it clearer and more intuitive
#     -Using -b with git checkout or -c with git switch combines branch creation and switching into a single step
#
# **git checkout**: is the older command for switching branches
#     -It's been around since the early days of Git and is still supported
#
# **"Fast-forward"**: means Git was able to simply move the master branch forward to where feature-dimension was, because there were no conflicting changes
#     -A fast-forward merge is the simplest type of merge, and occurs when the branch you are merging into hasn't changed since the branch you are merging from was created
#
# **git revert**: creates a new commit that undoes the changes introduced by a specific commit
#     -*It doesn't erase the original commit from history; instead, it adds a new commit that effectively reverses the effects of the unwanted commit*
#
# **git revert**: This is the command to revert changes
#
# **HEAD**: In Git, HEAD is a pointer to the *current* commit of your current branch
#     -In most cases, HEAD refers to the most recent commit
#     -So, git revert HEAD means "revert the most recent commit"
#     -**You can also specify a specific commit hash to revert an older commit**
#     -git revert doesn't rewrite history -- It adds a new commit to undo changes, making it safe for collaboration
#
# **git rebase -i**: git rebase is the command for rebasing
#     - The -i flag stands for "interactive", which tells Git we want to perform an interactive rebase
#
# **HEAD~3**: This specifies the range of commits we want to rebase
#     - HEAD refers to the current commit
#     - ~3 means "go back three commits from HEAD"
#         --So, HEAD~3 selects the last three commits
#         --You could also specify a commit hash instead of HEAD~3 to start the rebase from a specific point in history
#             --Commands: Below the commit list, Git provides a list of available commands that you can use to modify each commit
#                 - The most common ones are:
#                     --pick (or p): Use the commit as is. This is the default.
#                     --reword (or r): Use the commit, but allow you to change the commit message.
#                     --edit (or e): Use the commit, but stop the rebase process at this commit so you can make further changes (e.g., amend files, add more changes)
#                     --squash (or s): Combine this commit into the previous commit in the list
#                         --The commit message of this commit will be appended to the message of the previous commit (you'll get to edit the combined message later)
#                     --fixup (or f): Similar to squash, but discards the commit message of this commit and just uses the message of the previous commit
#                     --drop (or d): Remove this commit entirely from the history
#
# **git rebase --abort**: If you make a mistake during an interactive rebase, or if you get confused or encounter conflicts you can't resolve, you can always use git rebase --abort to cancel the rebase operation and return your branch to the state it was in before you started the rebase
#
# **git rebase -i --root**: allows you to interactively rebase all commits in your repository's history, starting from the very first (root) commit
#
# **git stash**: Imagine at this point you need to quickly switch to a different task, but you're not ready to commit these changes
#     - By default, git stash only stashes:
#         --Changes to tracked files (files that Git is already tracking)
#         --Staged changes
#         --Untracked files (like our notes.txt) are not included in the stash by default
#         --**The difference between apply and pop is that apply keeps the changes in your stash, while pop removes them from the stash after applying**
#
# **Lightweight tags**: are basically just a pointer to a specific commit - think of them as a branch that doesn't change
#     --They're simple to create and use, making them perfect for temporary or personal use
#     --Lightweight tags are great for temporary markers or for personal use
#
# **Annotated tags**: are stored as full objects in the Git database
#     --They contain the tagger's name, email, date, and a tagging message

# %% [markdown]
# # **Commands**

# %% [markdown]
# ### *Initial Git repo Setup*

# %% [markdown]
# * cd ~/project
# * mkdir my-time-machine
# * cd my-time-machine
# * *git init*
# * *git status*
# * *echo "Hello, Future Me" > message.txt*
# * *git status*
# * *git add message.txt*
# * *git commit -m "Send a message to the future"*
# * *git log*

# %% [markdown]
# ### *Git Config Management*

# %% [markdown]
# mkdir git-config-lab
# cd git-config-lab
# git init
# git config --list
# git config user.name
# git config --global user.name "Your Name"
# git config --global user.email "jane.doe@example.com"The
#     --global flag: tells your time machine to apply these settings to all your time travel experiments on this systemgit config
#     --global user.name
# git config --global user.email
# git config --global color.ui auto
#     --git config --global color.ui
#         -output should be auto
# git config --global core.editor nano
#     --git config --global core.editor
#         -You should see nano as the output
# git config --global core.autocrlf input
#     --This tells your time machine to convert CRLF to LF when you commit (add events to your timeline), but not the other way around when you checkout (view events from the timeline)
# git config --global alias.st status
#     --This creates an alias st for the status command
#     --Now, instead of typing git status, you can simply type git st
#             ** git st
#  git config --global alias.lg "log --color --graph --pretty=format:'%Cred%h%Creset -%C(yellow)%d%Creset %s %Cgreen(%cr) %C(bold blue)<%an>%Creset' --abbrev-commit"
#     --What it does is create an alias lg that shows your time travel history in a colorful and informative way
# git config --global alias.st
# git config --global alias.lg
# git config user.name "Lab User"
#     --Notice that we didn't use the --global flag this time
#         --This means the setting will only apply to this specific experiment
#             * git config user.name

# %% [markdown]
# ### *Staging Area*

# %% [markdown]
# mkdir git-staging-lab
# cd git-staging-lab
# git init
# echo "print('Hello, Git!')" > hello.py
# git add hello.py
#             * git rm hello.py --this will unstage the file
# git status
#
# * **Ignoring Files with .gitignore**
# *echo "*.log" > .gitignore*
#     --This command creates a .gitignore file that tells Git to ignore any file with a *.log* extension
# echo "This is a log file" > debug.log
# git status
#     --You should see that debug.log is not listed in the output, but .gitignore is:
# *git add .gitignore*
# git commit -m "Initial commit with hello.py and .gitignore"
#
# * **Viewing Changes with git Diff**
# echo "print('Hello, Git! Welcome to the staging area.')" > hello.py
# *git diff*
#     --This output shows us exactly what changed in our file
#         -The - line shows what was removed
#         -The + line shows what was added
# *git diff --staged*
#     --This command shows the changes you've staged but haven't committed yet
#
# * **Unstaging Changes**
# *git restore --staged hello.py*
# *git rm hello.py*
#     --this will unstage the file
# git status

# %% [markdown]
# ### *Git Basic Operations*

# %% [markdown]
# mkdir git-branch-lab
# cd git-branch-lab
# git init
# echo "# Git Branch Lab" > README.md
# echo "This is my hub for multiversal Git branch experiments" >> README.md
#     --git add README.md tells Git to start tracking changes to README.md
#     --git commit creates a new commit (save point) with the staged changes
#         -This is like taking a snapshot of our current universe
#     --The -m flag allows you to provide a commit message directly
# git add README.md
# git commit -m "Initial commit: Create the multiverse hub"
#
# **Creating a New Branch**
# git branch feature-dimension
#     --This command creates a new branch, but doesn't switch to it yet
#     --Think of it as creating a new parallel universe, but you're still in the original one
# git branch
#     --The * shows which reality you're currently in
# git branch -a
#     --If you ever want to see all branches, including remote branches
#     --This can be helpful when working on projects with multiple contributors
#     --Remote branches are copies of branches on other repositories
# git checkout feature-dimension
#     --This command does two things
#         1. It switches your current working directory to the feature-dimension branch
#         2. It updates the files in your working directory to match the state of the feature-dimension branch
#             -It's like stepping through a portal into the new reality
# git checkout master --to go back to the master branch
# git switch feature-dimension (Alternate way of Switching Branches)
# git branch
# git checkout -b feature-dimension
#     --create a new branch and jump to it in one command
# git switch -c feature-dimension
#     --create a new branch and jump to it in one command
#
# **Branch Operations**
# echo "This is a powerful artifact from another dimension" > dimensional-artifact.txt
# git add dimensional-artifact.txt
# git commit -m "Create a powerful interdimensional artifact"
#     --if you run the git switch master the new file after the commit will not be there
# echo "#### Feature Dimension" >> README.md
# echo "We've discovered a powerful artifact in this reality" >> README.md
# git add README.md
# git commit -m "Document the discovery of the artifact"
# git diff master
# git merge feature-dimension
#     --This command tells Git to take all the changes from feature-dimension and apply them to master
# git branch -d feature-dimension
#     --The -d flag tells Git to delete the branch, but only if it's been fully merged
#         -If you try to delete a branch that hasn't been fully merged, Git will give you a warning
# git branch -D feature-dimension
#     --This force-deletes the branch regardless of its merge status
# git branch

# %% [markdown]
# ### *Git Commit Operations*

# %% [markdown]
# cd ~/project
# mkdir git-advanced-lab
# cd git-advanced-lab
# git init
# echo "Hello, Advanced Git" > hello.txt
# git add hello.txt
# git commit -m "Initial commit"
# git status
# git log
# echo "This is an important file." >> hello.txt
# git add hello.txt
# *git commit --amend -m "Initial commit with important note"*
#                -git commit --amend: The --amend flag tells Git that instead of creating a new commit, we want to modify the last commit
#     --Instead of creating a new commit in your Git history, Git has effectively replaced the previous "Initial commit" with a new, improved version
# * *git log*
#    --This will help you see the amended first commit
# * *git log --oneline*
#
# * **Reverting a Commit**
# * echo "This line will be reverted" >> hello.txt
# * git commit -m "Add line to be reverted"
# * *git revert HEAD*
#         --You should see three commits in your log, in reverse chronological order (newest first):
#             -A commit starting with "Revert" (the revert commit we just created).
#             -"Add line to be reverted" (the commit we reverted).
#             -"Initial commit with important note" (our original amended commit).
#             -If you look at the content of hello.txt now, the line "This line will be reverted" should be gone, effectively undoing the changes from the "Add line to be reverted" commit
#
# **Cherry-picking Commits**
# * --Cherry-pick always creates a new commit
# * git checkout -b feature-branch
#         -git checkout -b feature-branch:
#             -git checkout: This command is used to switch branches or create new branches
#             --b feature-branch: The -b flag tells git checkout to create a new branch named "feature-branch" and immediately switch to it
#               -So, this command creates a new branch and makes it your active branch
# * echo "This is a new feature" >> feature.txt
# * git checkout master
#   -This command simply switches your active branch back to "master"
# * *git cherry-pick feature-branch*
#       -you would use the commit hash of that specific commit instead
# * *git log feature-branch --oneline*
# * *git cherry-pick <commit_hash>*
# * git log --oneline
#     -You should see a new commit on your master branch with the message "Add new feature"
#
# **Interactive Rebasing**
# * echo "First change" >> hello.txt
# * git commit -am "First change"
#     - The -am shorthand in git commit
#         - -am combines staging all modified and deleted files (-a) with committing (-m)
# * echo "Second change" >> hello.txt
# * git commit -am "Second change"
# * echo "Third change" >> hello.txt
# * git commit -am "Third change"
# * git rebase -i HEAD~3
#     - When you run this command, Git will open your default text editor with a list of the last three commits
#         - Commit List: The top part of the file lists the commits that are part of the rebase operation
#             - By default, they are listed in chronological order
# * *git rebase --abort*
#     - You can always use git rebase --abort to cancel the rebase operation and return your branch to the state it was in before you started the rebase
#
# **Rebasing from the Root**
# * *git rebase -i --root*
#     --This command is very similar to the previous rebase, but instead of HEAD~3, we use --root
#         - --root tells Git to consider all commits from the very beginning of the repository's history for the interactive rebase
# * git log --oneline

# %% [markdown]
# ### *Stashing*

# %% [markdown]
# **Setting Up the Workspace**
# cd ~/project
# mkdir git-stash-lab
# cd git-stash-lab
# git init
# echo "# Git Stash Lab" > README.md
# git add README.md
# git commit -m "Initial commit"
# git status
# echo "This is a work in progress" >> README.md
# echo "Some important notes" > notes.txt
# git stash
#         --By default, git stash only stashes:
#             - Changes to tracked files (files that Git is already tracking)
#             - Staged changes
# git stash -u
#         --If you want to include untracked files in your stash, you can use the -u (or --include-untracked) option
# git stash list
# git stash apply
#         --to bring them back there are two main commands for this:
#             --git stash apply
#             --git stash pop
# git stash apply
#         --When we apply the stash, Git applies the most recent stash
# git status
# git stash apply stash@{1} -- git stash list to get the stash number you want
# git stash clear
# git stash -u
# git stash list
# git stash pop
#         --if you run git stash list now, you'll see that your stash is empty
#         --pop is more commonly used when you're just resuming work on the same branch
# echo "Feature in progress" >> README.md
# echo "More notes" >> notes.txt
# git stash -u
# git branch --should be on branch master or main then run the below command
# git stash branch feature-branch
#         --This command creates a new branch named "feature-branch", checks it out, and then applies the stashed changes to it
#
# **Managing Multiple Stashes**
# *First stash*
# echo "Change 1" >> README.md
# *git stash push -m "First change"*
#         --push subcommand is the modern, preferred way to create stashes, especially when you want to add custom messages with the -m flag
# *Second stash with untracked file*
# echo "Change 2" >> README.md
# echo "Note 2" >> notes.txt
# *git stash push -u -m "Second change"*
#         -Used the -m flag to add descriptive messages
#         -Used the -u flag for the second stash to include the untracked file
# *Third stash*
# echo "Change 3" >> README.md
# git stash push -m "Third change"
# git stash list
# *git stash show stash@{1}*
# *git stash show -p stash@{1}*
# *Fourth stash*
# echo "Change 4" >> README.md
# git stash push -m "Fourth change"
# *Fifth stash*
# echo "Change 5" >> README.md
# git stash push -m "Fifth change"
# git stash list
# *git stash drop stash@{2}*
#         --This removes the third stash (with "Third change") from our list
# *git stash clear*
#         --If you want to remove all your stashes at once, you can use

# %% [markdown]
# ### *Git Tags*

# %% [markdown]
# cd ~/project
# mkdir git-tags-lab
# cd git-tags-lab
# git init
# echo "# My Awesome Project" > README.md
# git add README.md
# git commit -m "Initial commit"
# echo "function greet(name) { console.log('Hello, ' + name + '!'); }" > app.js
# git add app.js
# git commit -m "Add greeting function"
# echo "const PI = 3.14159;" >> app.js
# git add app.js
# git commit -m "Add PI constant"
# echo "function calculateArea(radius) { return PI * radius * radius; }" >> app.js
# git add app.js
# git commit -m "Add area calculation function"
#
# **Creating Lightweight Tags**
# *git tag v0.1*
#     --This creates a tag named v0.1 pointing to the current commit (HEAD)
# git log --oneline
#     --This will show you a list of your commits
#     --Copy the hash of the "Add greeting function" commit
# *git tag v0.0.1 <commit-hash>*
#     --git tag v0.0.1 d7c67ff--
# *git tag*
#     --This will display all your tags in alphabetical order
# *git tag -n*
#     --This lists your tags along with the first line of their annotation message (or the commit message for lightweight tags)
#
# **Creating Annotated Tags**
# *git tag -a v1.0 -m "First major release"*
#     --Thi creates an annotated tag named v1.0 with the message "First major release"
# git show
#     --You can see the details of an annotated tag using the above command
# *git show v1.0*
#     --This will display the tagger information, the date the commit was tagged, the annotation message, and the commit information
# git tag -l "v1.*"
#     --If you want to search for tags matching a particular pattern, you can use the -l (or --list) option with a wildcard
#     --This will list all tags that start with "v1."
#
# **Checking Out Tags**
# *git checkout v1.0*
#     --To check out a tag, you can use the git checkout command:
#     --This will put your repository in a "detached HEAD" state at the commit that v1.0 points to
#         -This means you can look around, make experimental changes and commit them, and discard any commits you make in this state without impacting any branches
# git status
# *git checkout -b branch-name v1.0*
#     --This creates a new branch named branch-name based on the state of your project at the v1.0 tag
#     --Be cautious when in a detached HEAD state
#         --**Any commits you make will be orphaned (not on any branch) when you check out a different branch, unless you explicitly create a new branch to retain them**
# git checkout master --run this to switch back to the master branch
#
# **Deleting Tags**
# git tag
# *git tag -d v0.0.1*
#     --This removes the tag v0.0.1 from your local repository
