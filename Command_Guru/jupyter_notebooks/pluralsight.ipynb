# %% [markdown]
# # **Linux Grep Command**

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Finding objects anywhere within a Linux file system
# cd /usr/share/doc && ls
# grep copyright --command will FAIL
# grep -r copyright
# grep -rl copyright
# grep -r copyright | wc
# grep -R copyright | wc
# grep -r copyright > ~/lowercase.txt
# grep -R copyright > ~/uppercase.txt
# grep -rl  copyright > ~/lowercase_1.txt
# grep -Rl copyright > ~/uppercase_1.txt
# diff ~/lowercase.txt ~/uppercase.txt
# ls -l /usr/share/doc/ | grep debconf
# *The output should include something like this (note the -> characters that identify symbolic link relationships)*
#
# #### **Interacting with text streams**
# cd /usr/share/doc && ls
# ls git
# cat git/README.source | grep extracted
# cat git/README.source | grep -A 2 extracted
# cat git/README.source | grep -B 5 extracted
# cat git/README.source | grep -C 4 extracted
#
# ##### Using ps aux
# ps aux
# ps aux | grep root
# ps aux | grep ^root
# ps aux | grep d$

# %% [markdown]
# # **~~Java SE App with Docker~~**

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Compiling and Running Java Application
# cd src/main/java/com/example/
# Compile the code: javac src/main/java/com/example/SimpleWebServer.java
# Run the application: java -cp src/main/java com.example.SimpleWebServer
#
# #### Creating a Basic Dockerfile
# TBD

# %% [markdown]
# ### Java Webserver

# %% [markdown]
# package com.example;
#
# import com.sun.net.httpserver.HttpServer;
# import com.sun.net.httpserver.HttpHandler;
# import com.sun.net.httpserver.HttpExchange;
# import java.io.IOException;
# import java.io.OutputStream;
# import java.net.InetSocketAddress;
#
# public class SimpleWebServer {
#
#     public static void main(String[] args) throws IOException {
#         int port = 8080;
#         HttpServer server = HttpServer.create(new InetSocketAddress(port), 0);
#         server.createContext("/", new MyHandler());
#         server.setExecutor(null); // creates a default executor
#         System.out.println("Server is listening on port " + port);
#         server.start();
#     }
#
#     static class MyHandler implements HttpHandler {
#         @Override
#         public void handle(HttpExchange t) throws IOException {
#             String response = "Hello from a Java application running in Docker!";
#             t.sendResponseHeaders(200, response.length());
#             OutputStream os = t.getResponseBody();
#             os.write(response.getBytes());
#             os.close();
#         }
#     }
# }

# %% [markdown]
# # **DevOps Containerization**

# %% [markdown]
# ## Setup

# %% [markdown]
# *The docker command is the client -- the Docker Engine service is the server -- Together these form a client-server architecture*
#
# #### **Running a Jenkins Container**
# docker --version
# sudo systemctl start docker
# docker version
# newgrp docker --if above command fails
# docker image ls
# docker image pull jenkins/jenkins
# docker container run -p 8080:8080 --name jenkins1 jenkins/jenkins
# http://localhost:8080
# [LF]> Please use the following password to proceed to installation:
# [LF]>
# [LF]> a6d40914346d4442a24214a547a17587
# [LF]>
# [LF]> This may also be found at: /var/jenkins_home/secrets/initialAdminPassword
# Press Contrl + c to stop the container
# docker container ps -a
#
# #### **Restarting the Jenkins Container**
# docker container start jenkins1
# docker container ps || docker ps
# *Now, when you run docker container ps you will see the STATUS has Up followed by the uptime*
# docker container logs jenkins1
# docker container logs jenkins1
# docker container logs jenkins1 --follow
# docker container run --rm jrottenberg/ffmpeg -version
# *ffmpeg is a command line app, and can be run as well*
# *jrottenberg is the user/organization that owns the image*
# *After running the ffmpeg container with --rm, if you run docker container ps -a you won't see an ffmpeg container. That's because --rm removes the container once its stopped. So, after ffmpeg printed its version information, the process ended and the container was removed*
#
# #### **Port conflict -- Running 2nd Jenkins Instance**
# docker container run -p 8080:8080 --name jenkins2 jenkins/jenkins
#     --should error out because of port conflicts
#     --*-p HOST_PORT:CONTAINER_PORT - the left side (before the colon) specifies the host port, the right side (after the colon) is the container port. So, if you want to connect to http://localhost:9000 instead of http://localhost:8080 then use -p 9000:8080 which will take traffic to the host port 9000 and forward it to the container port 8080*
# docker container rm jenkins2
# docker container run -p 9000:8080 --name jenkins2 jenkins/jenkins
# http://localhost:9000
#
# #### **Cleaning up Containers**
# docker container stop jenkins2
# docker container rm jenkins2
# docker container rm -f jenkins1 --this both stops and removes the container
# docker container ps -a
#
# #### **Build and Deploy Containerized Applications**
# *Bundling a website into an existing nginx image*
# docker container run --rm -p 80:80 nginx
# http://localhost:80
# Control + c --to kill the container
#
# ##### **Dockerfile Build**
# *The goal here is to replace the welcome page in a new image. Then, when you run a container based on it, you will see your custom page. You can think of this as bundling a custom website into an image. The image becomes a deployment package*
# code ~/lab
#
# FROM nginx
# COPY custom.html /usr/share/nginx/html/index.html
#
# *The nginx directory also has a custom.html file. This will take the custom.html file and write it over the top of the default welcome page*
#
# *Switch back to the terminal*
# cd ~/lab/nginx
# docker image build -t custom .
# docker image ls
# docker image ls custom
# docker container run --rm -p 80:80 custom
# Control + c
#
# #### **Running the dotnet command in a container**
# dotnet
#     --should error out because dotnet is not install on the machine
# docker image ls
#     --should see a dotnet container
# *The dotnet/sdk image has the dotnet command and SDK tools installed. To try it out, run a container based on it using below container*
#
# cd ~/lab/api
# docker container run --rm -it mcr.microsoft.com/dotnet/sdk:8.0-alpine
# dotnet --version
# exit
#
# docker container run --rm -it -v .:/source -w /source mcr.microsoft.com/dotnet/sdk:8.0-alpine
# dotnet build
# exit
# *-v .:/source mounts the source code in the current directory (.) into the container at /source - -w /source sets the working directory to /source which means you will automatically be placed into the /source directory*
#
# #### **Building an image with the Web API application**
# cd ~/lab/api
# docker image build -t api .
# docker container run --rm -p 8080:80 api
# http://localhost:8080 --This will return a fake list of weather data
#
# #### **Use Docker Compose for Multi-container Applications**
# cd ~/lab/api
# touch ~/lab/api/compose.yaml
# docker container rm -f $(docker container ps -a -q)
# docker-compose up
# http://localhost:8080
# docker container ps -a
#     --you will see a container named api-web-1
# docker-compose down
# docker image rm api
# docker-compose build
# docker-compose up
# Control + c
# docker-compose up --build
# docker-compose exec db bash
# mysql --version
# mysql -u root -p --passowrd:root
# use mysql;
# show tables;
# select User, Host from user;
# exit;
# exit
# docker-compose down
# testing

# %% [markdown]
# # **Managing Amazon Linux**

# %% [markdown]
# ### Setup

# %% [markdown]
# ssh cloud-user@public-IP>
# cloud_user
# USmT8bC-
# 32.*.*.*
#
# #### **SSH Key Setup**
# * ssh ec2-user@public-IP>
# * ssh-keygen -t ed25519 -C "lab-key" --accept default for all options by pressing enter
# * cat ~/.ssh/id_ed25519.pub >> ~/.ssh/authorized_keys
# * chmod 700 ~/.ssh
# * chmod 600 ~/.ssh/authorized_keys
# * cat ~/.ssh/id_ed25519 --copy the entire private key
# -----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACA+SYELbidgxsE0fskVBlC3ZJ/r/nT0SeqybZ7Odzjs3AAAAJAcf1ilHH9Y
# pQAAAAtzc2gtZWQyNTUxOQAAACA+SYELbidgxsE0fskVBlC3ZJ/r/nT0SeqybZ7Odzjs3A
# AAAEDNZgeDJQHhhKAkT0TVBIk1WP9kUzpodRiK7uUuQ5hJJj5JgQtuJ2DGwTR+yRUGULdk
# n+v+dPRJ6rJtns53OOzcAAAAB2xhYi1rZXkBAgMEBQY=
# -----END OPENSSH PRIVATE KEY-----
# *Type exit and press Enter to disconnect from the EC2 instance*
#
# *On the other server run the below commands*
# * mkdir -p ~/.ssh
# * ssh -i /home/cloud_user/.ssh/id_dropbear ec2-user@<public-IP>
# * sudo dnf update -y
# * sudo dnf install git -y
#
# #### **Filesystem navigation and Management tasks**
# * cd /srv
# *sudo git clone https://github.com/ps-interactive/lab_navigating-and-managing-amazon-linux.git
# * pwd && ls
# * cd lab_navigating-and-managing-amazon-linux/
# * cd Frontend/ && ls
# * find . -name "health.html"
# *The output should resemble the following:./public/health.html*
# * cd public/ && ls
# * cd .. && pwd
# * grep -R "DB_NAME"
# * cat database.conf
# * cd /srv/lab_navigating-and-managing-amazon-linux/
# * sudo mkdir Backend && cd Backend/
# * sudo touch server.js
#
# #### **Configure users, groups, and sudo access**
#
# ##### **Group Creation**
# * sudo groupadd frontend_group
# * sudo groupadd backend_group
# * sudo groupadd admin_group
# * getent group frontend_group
#
# ##### **User Creation**
# * sudo useradd -m frontend1
# * sudo useradd -m frontend1
# * sudo useradd -m backend1
# * sudo useradd -m backend2
# * sudo useradd -m admin1
#
# ##### **Adding Users to groups**
# * sudo usermod -aG frontend_group frontend1
# * sudo usermod -aG frontend_group frontend2
# * sudo usermod -aG backend_group backend1
# * sudo usermod -aG backend_group backend2
# * sudo usermod -aG admin_group admin1
# * groups frontend1
#
# ##### **Changing File permissions**
# * sudo chown -R root:frontend_group Frontend
# * sudo chown -R root:backend_group Backend
# * ls -ld Frontend Backend
# * sudo chmod -R 770 Frontend
# * sudo chmod -R 777 Backend
# * sudo usermod -aG frontend_group admin1
# * sudo usermod -aG backend_group admin1
# * sudo visudo
# *Add the following line to the bottom of the file*
# %admin_group ALL=(ALL) ALL
# This allows members of the admin_group to run commands with sudo
#
# ##### **Password Creations**
# * sudo passwd frontend1
# * sudo passwd frontend2
# * sudo passwd backend1
# * sudo passwd admin1
#
# ##### **Testing Permissions and Access**
# * su - frontend1 --Learner123
# * touch /srv/lab_navigating-and-managing-amazon-linux/Frontend/test.txt
# exit
#
# * su - backend1 --Learner123
# * touch /srv/lab_navigating-and-managing-amazon-linux/Frontend/permission_test.txt
# *Should get permission denied*
# exit
#
# * su - admin1 --Learner123
# * sudo whoami --Learner123
# *The command should return, root -- confirming that admin1 can run commands with administrative privileges*
# * touch /srv/lab_navigating-and-managing-amazon-linux/Frontend/admin.txt
# *You should be able to do it as admin1 has access to both directories*
# exit
#
# #### **Implement and audit file permissions**
# * sudo chmod g+s Frontend
# * sudo chmod +t Frontend
# * ls -ld Frontend
# *In the permission string, verify that you see an s and a T, indicating that the setgid and sticky bits are enabled*
#
# *Switch to the frontend1 user*
# * su - frontend1
# * touch /srv/lab_navigating-and-managing-amazon-linux/Frontend/app.js
# * ls -l /srv/lab_navigating-and-managing-amazon-linux/Frontend/app.js
# * touch /srv/lab_navigating-and-managing-amazon-linux/Frontend/style.css
# exit
#
# *Switch to the frontend2 user*
# * su - frontend2
# *Attempt to remove the file created by frontend1*
#
# *Audit directory Permissons*
# * find . -type d -perm -002
# * ls -ld Backend
# * sudo chmod 770 Backend
# * ls -ld Backend
# * find . -type d -perm -002

# %% [markdown]
# # **Jenkins Setup and Configuration**

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Start Jenkins
#
# * sudo docker run --name jenkins-docker -v /home/pslearner/jenkins-lab:/var/jenkins_home -p 8081:8080 --restart unless-stopped jenkins/jenkins:lts

# %% [markdown]
# # **Amazon Linux LAMP Install**

# %% [markdown]
# ## Index.php

# %% [markdown]
# <?php
#
# $config = require '/etc/todo-app/database.php';
#
# try {
#     $database = new PDO(
#         sprintf(
#             'mysql:host=%s;dbname=%s;charset=utf8mb4',
#             $config['host'],
#             $config['database']
#         ),
#         $config['username'],
#         $config['password'],
#         [
#             PDO::ATTR_ERRMODE => PDO::ERRMODE_EXCEPTION,
#             PDO::ATTR_DEFAULT_FETCH_MODE => PDO::FETCH_ASSOC,
#         ]
#     );
#
#     $todos = $database
#         ->query('SELECT id, task, completed FROM todos ORDER BY id')
#         ->fetchAll();
# } catch (PDOException $error) {
#     http_response_code(500);
#     $todos = [];
#     $databaseError = 'The application could not connect to the database.';
# }
#
# ?>
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta
#         name="viewport"
#         content="width=device-width, initial-scale=1.0"
#     >
#     <title>Operations To-Do List</title>
#
#     <style>
#         body {
#             background: #f4f6f8;
#             color: #1f2933;
#             font-family: Arial, sans-serif;
#             margin: 0;
#         }
#
#         main {
#             background: white;
#             border-radius: 10px;
#             box-shadow: 0 4px 18px rgba(0, 0, 0, 0.08);
#             margin: 60px auto;
#             max-width: 700px;
#             padding: 40px;
#         }
#
#         h1 {
#             margin-bottom: 8px;
#         }
#
#         .subtitle {
#             color: #52606d;
#             margin-bottom: 30px;
#         }
#
#         ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         li {
#             align-items: center;
#             border-bottom: 1px solid #e4e7eb;
#             display: flex;
#             gap: 12px;
#             padding: 16px 4px;
#         }
#
#         .complete {
#             color: #52606d;
#             text-decoration: line-through;
#         }
#
#         .error {
#             background: #fff0f0;
#             border: 1px solid #d64545;
#             border-radius: 5px;
#             color: #a61b1b;
#             padding: 14px;
#         }
#
#         footer {
#             color: #7b8794;
#             font-size: 0.9rem;
#             margin-top: 30px;
#         }
#     </style>
# </head>
#
# <body>
#     <main>
#         >Welcome</h1> #other header is needed
#
#         <p class="subtitle">
#             Here is your operations to-do list.
#         </p>
#
#         <?php if (isset($databaseError)): ?>
#
#             <p class="error">
#                 <?= htmlspecialchars($databaseError) ?>
#             </p>
#
#         <?php elseif (count($todos) === 0): ?>
#
#             <p>No to-do items were found.</p>
#
#         <?php else: ?>
#
#             <ul>
#                 <?php foreach ($todos as $todo): ?>
#
#                     <li class="<?= $todo['completed'] ? 'complete' : '' ?>">
#                         <span>
#                             <?= $todo['completed'] ? '☑' : '☐' ?>
#                         </span>
#
#                         <span>
#                             <?= htmlspecialchars($todo['task']) ?>
#                         </span>
#                     </li>
#
#                 <?php endforeach; ?>
#             </ul>
#
#         <?php endif; ?>
#
#         <footer>
#             Data retrieved from the MariaDB <strong>todo_app</strong> database.
#         </footer>
#     </main>
# </body>
# </html><?php
#
# $config = require '/etc/todo-app/database.php';
#
# try {
#     $database = new PDO(
#         sprintf(
#             'mysql:host=%s;dbname=%s;charset=utf8mb4',
#             $config['host'],
#             $config['database']
#         ),
#         $config['username'],
#         $config['password'],
#         [
#             PDO::ATTR_ERRMODE => PDO::ERRMODE_EXCEPTION,
#             PDO::ATTR_DEFAULT_FETCH_MODE => PDO::FETCH_ASSOC,
#         ]
#     );
#
#     $todos = $database
#         ->query('SELECT id, task, completed FROM todos ORDER BY id')
#         ->fetchAll();
# } catch (PDOException $error) {
#     http_response_code(500);
#     $todos = [];
#     $databaseError = 'The application could not connect to the database.';
# }
#
# ?>
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta
#         name="viewport"
#         content="width=device-width, initial-scale=1.0"
#     >
#     <title>Operations To-Do List</title>
#
#     <style>
#         body {
#             background: #f4f6f8;
#             color: #1f2933;
#             font-family: Arial, sans-serif;
#             margin: 0;
#         }
#
#         main {
#             background: white;
#             border-radius: 10px;
#             box-shadow: 0 4px 18px rgba(0, 0, 0, 0.08);
#             margin: 60px auto;
#             max-width: 700px;
#             padding: 40px;
#         }
#
#         h1 {
#             margin-bottom: 8px;
#         }
#
#         .subtitle {
#             color: #52606d;
#             margin-bottom: 30px;
#         }
#
#         ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         li {
#             align-items: center;
#             border-bottom: 1px solid #e4e7eb;
#             display: flex;
#             gap: 12px;
#             padding: 16px 4px;
#         }
#
#         .complete {
#             color: #52606d;
#             text-decoration: line-through;
#         }
#
#         .error {
#             background: #fff0f0;
#             border: 1px solid #d64545;
#             border-radius: 5px;
#             color: #a61b1b;
#             padding: 14px;
#         }
#
#         footer {
#             color: #7b8794;
#             font-size: 0.9rem;
#             margin-top: 30px;
#         }
#     </style>
# </head>
#
#  <body>
#     <main>
#
#         <p class="subtitle">
#             Here is your operations to-do list.
#         </p>
#
#         <?php if (isset($databaseError)): ?>
#
#             <p class="error">
#                 <?= htmlspecialchars($databaseError) ?>
#             </p>
#
#         <?php elseif (count($todos) === 0): ?>
#
#             <p>No to-do items were found.</p>
#
#         <?php else: ?>
#
#             <ul>
#                 <?php foreach ($todos as $todo): ?>
#
#                     <li class="<?= $todo['completed'] ? 'complete' : '' ?>">
#                         <span>
#                             <?= $todo['completed'] ? '☑' : '☐' ?>
#                         </span>
#
#                         <span>
#                             <?= htmlspecialchars($todo['task']) ?>
#                         </span>
#                     </li>
#
#                 <?php endforeach; ?>
#             </ul>
#
#         <?php endif; ?>
#
#         <footer>
#             Data retrieved from the MariaDB <strong>todo_app</strong> database.
#         </footer>
#     </main>
# </body>
# </html>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install and Configure an Amazon Linux LAMP Environment
#
# *LAMP (Linux, Apache, MariaDB, and PHP)*
#
# **Login**
# cloud_user
# RnH!7Go!
# 32.197.194.80
#
# #### Refresh the package metadata and install available updates:
# * **whoami**
# * sudo dnf upgrade -y
# * dnf --version
# * sudo dnf install -y httpd php php-fpm php-mysqli php-json git
# * sudo dnf install -y mariadb105-server --installing mariadb server
#
# #### Start these services manually for now
# * sudo systemctl start mariadb
# * sudo systemctl start php-fpm
# * sudo systemctl start httpd
# * http://PUBLIC-IP> --to test the web server --ip used from above
#
# #### secure MariaDB installation
# * sudo mysql_secure_installation
# When asked for the current root password, press Enter because a new MariaDB installation does not initially have one configured
# * For the remaining prompts enter the following:
# a. Switch to unix_socket authentication? Y
# b. Change root password: n
# c. Remove anonymous users? Y
# d. Disallow root login remotely? Y
# e. Remove test database and access to it? Y
# f. Reload privilege tables now? Y
# * Confirm that you can access MariaDB administratively:
# * sudo mariadb
#
# #### Creating Application Database
# * sudo mariadb
#
# * *Create the application*
# CREATE DATABASE todo_app
#     CHARACTER SET utf8mb4
#     COLLATE utf8mb4_unicode_ci;
# Expected Output: Query OK, 1 row affected (0.001 sec)
#
# * *Create a database account for the PHP application:*
# CREATE USER 'todo_user'@'localhost'
# IDENTIFIED BY 'TodoAppLab2026!';
#
# * *Grant the application account access to the database:*
# GRANT SELECT, INSERT, UPDATE, DELETE
# ON todo_app.*
# TO 'todo_user'@'localhost';
#
# * *Apply the updated privileges:*
# FLUSH PRIVILEGES;
#
# * *Select the application database:*
# USE todo_app;
#
# * *Create the todos table:*
# CREATE TABLE todos (
#     id INT UNSIGNED NOT NULL AUTO_INCREMENT,
#     task VARCHAR(255) NOT NULL,
#     completed BOOLEAN NOT NULL DEFAULT FALSE,
#     created_at TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP,
#     PRIMARY KEY (id) );
#
# * *Insert the initial to-do items:*
# INSERT INTO todos (task, completed)
# VALUES
#     ('Verify the Apache service', FALSE),
#     ('Secure the MariaDB installation', TRUE),
#     ('Configure automatic service startup', FALSE),
#     ('Review application service logs', FALSE);
#
# * *Display the inserted records:*
# SELECT id, task, completed FROM todos;
# EXIT;
#
# #### Create the directories and pages for web app
# * git clone https://github.com/ps-interactive/lab_amazon-linux-package-management-service-configuration.git
# * sudo mkdir -p /var/www/todo/public
# * sudo mkdir -p /etc/todo-app
# * sudo chown -R cloud_user:apache /var/www/todo
# * sudo find /var/www/todo -type d -exec chmod 2775 {} \;
# * sudo cp lab_amazon-linux-package-management-service-configuration/database.php /etc/todo-app/database.php
# * sudo chown root:apache /etc/todo-app/database.php
# * sudo chmod 640 /etc/todo-app/database.php
#     Expected permissions: -rw-r-----
# * sudo nano /var/www/todo/public/index.php
# * sudo chown cloud_user:apache /var/www/todo/public/index.php
# * chmod 664 /var/www/todo/public/index.php
# * php -l /var/www/todo/public/index.php
#     Expected output: No syntax errors detected in /var/www/todo/public/index.php
#
# #### Create the virtual host
# * sudo cp lab_amazon-linux-package-management-service-configuration/todo.conf /etc/httpd/conf.d/todo.conf
# *This creates Create an Apache virtual host configuration:*
# * sudo apachectl configtest --Test the Apache configuration:
# *Expected output: Syntax OK*
# * http://PUBLIC-IP --to see the changes
#
# #### Configure systemd Services for Automatic Startup
# *configure Apache, PHP-FPM, and MariaDB to start automatically when the instance boots*
#
# * systemctl is-enabled httpd
# * sudo systemctl enable httpd
# * sudo systemctl enable mariadb
# * sudo systemctl enable php-fpm
# * systemctl is-enabled httpd
#
# #### Create an application initialization script
# * sudo cp lab_amazon-linux-package-management-service-configuration/todo-init.sh /usr/local/bin/todo-init.sh
# * sudo cp lab_amazon-linux-package-management-service-configuration/todo-init.service /etc/systemd/system/todo-init.service
# *Systemd must reload its configuration before it can recognize a newly created unit file so that's what you will do now*
# * sudo systemctl daemon-reload
# * systemctl list-unit-files | grep todo-init
# * sudo systemctl start todo-init.service
#
# #### Diagnose and Resolve a Failed systemd Service
# *Use journalctl and systemctl to investigate the failed todo-init.service*
#
# * systemctl is-active todo-init.service
# * sudo journalctl -u todo-init.service
# * ls -l /usr/local/bin/todo-init.sh
# *Confirming if the file has execute permissions*
# * sudo chmod 755 /usr/local/bin/todo-init.sh
# * ls -l /usr/local/bin/todo-init.sh
# *Expected permissions: -rwxr-xr-x*
# * sudo systemctl restart todo-init.service
# * systemctl status todo-init.service --no-pager
# *Expected output: Active: active (exited)*
# * sudo journalctl -u todo-init.service -n 20
