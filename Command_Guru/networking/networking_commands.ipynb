# %% [markdown]
# # **Commands**

# %% [markdown]
# # **Networking Scripts**

# %% [markdown]
# ### *Networking Script 1*

# %%
import ipaddress

net = ipaddress.ip_network("192.168.10.0/27")

print("Network:", net.network_address)
print("Broadcast:", net.broadcast_address)
print("Usable hosts:", net.num_addresses - 2)
# Out:
# Network: 192.168.10.0
# Broadcast: 192.168.10.31
# Usable hosts: 30

# %% [markdown]
# ### *Networking Script 2*

# %%
def wildcard(mask):
    parts = [255 - int(x) for x in mask.split(".")]
    return ".".join(map(str, parts))

wildcard("255.255.255.0")

# %% [markdown]
# ### *Networking Command 1*

# %%
# !ip addr

# %% [markdown]
# ### *Networking Command 2*

# %%
# !ip route

# %% [markdown]
# ### *Networking Command 3*

# %%
# !ss -tulpn

# %% [markdown]
# ### *Networking Quiz 2*

# %%
questions = {
    "What port does SSH use?": "22",
    "What protocol does OSPF use?": "89",
    "What port does HTTPS use?": "443"
}

for question, answer in questions.items():
    print(question)

# %% [markdown]
# ### *Networking Quiz 2*

# %%
import random
import ipaddress

prefix = random.randint(24, 30)
network = ipaddress.ip_network(f"192.168.{random.randint(0,255)}.0/{prefix}", strict=False)

print(network)
